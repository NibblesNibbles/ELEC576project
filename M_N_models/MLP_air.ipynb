# %%
import os
import numpy as np
from keras.preprocessing import image
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
import pandas as pd
import skrf as rf

#define the targeted max frequency
fmax = 196
#define function for loading images and s-parameters
#"path" is the path for images of transformer layout
#"label" is the path for labels. In this case, labels are S-parameter associated with each images 
def load_images_from_path(path, label,length):
    images = []
    labels = []
    
    for i in range(length):
        #load images
        img = image.load_img(path+str(i)+'.png', target_size=(500, 500, 3))
        images.append(image.img_to_array(img)[138:362,138:362,:])#trim the ground margin

        #load S-parameters
        #According to symmerty, only S11,S12,S13,S14,S33,S34 are considered
        #Each S-parameter has real and imaginary parts, and hence 12 real values in total.
        results = []
        datafile = label+str(i)+".s4p"
        spt = rf.Network(datafile)
        for i in range(fmax+1):
            results.append([spt.s[i][0][0].real,spt.s[i][0][0].imag,
                            spt.s[i][0][1].real,spt.s[i][0][1].imag,
                            spt.s[i][0][2].real,spt.s[i][0][2].imag,
                            spt.s[i][0][3].real,spt.s[i][0][3].imag,
                            spt.s[i][2][2].real,spt.s[i][2][2].imag,
                            spt.s[i][2][3].real,spt.s[i][2][3].imag])      
        labels.append(results) 
    return images, labels

def show_images(images):
    fig, axes = plt.subplots(1, 8, figsize=(20, 20), subplot_kw={'xticks': [], 'yticks': []})

    for i, ax in enumerate(axes.flat):
        ax.imshow(images[i] / 255)
# Out:
# 2024-12-03 03:49:41.282888: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#load data
#geometrical parameters stored in log.txt
#order of geopara (radiusA,radiusB,turnsA,turnsB,openA,openB,outA,outB,extA,extB,ratio,outbound)
logfile = open("/rdf/shared/design_automation/Data/2409Air/log.txt","r")
listall = list(map(lambda item: list(map(lambda jtem: eval(jtem.strip()), item[1:-1].split(','))), logfile.read().strip().split('\n')))
tabular_data = np.array(listall)

#load images and s-parameters
length = 4000
images, labels = load_images_from_path('/rdf/shared/design_automation/Data/2409Air/PNG/', '/rdf/shared/design_automation/Data/2409Air/SPData/',length)
show_images(images)
geoparas = []
images11 = []
labels11 = []

for kk in range(length):
    #select 1 turn and 1 turn transformers
   if((tabular_data[kk,2] !=1) or (tabular_data[kk,3]!=1)):
       #geoparas only includes the variable parameters in our designs. 
       #Constants at this design stages are excluded 
        geoparas.append(tabular_data[kk,(0,1,2,3,4,5,4,5,6,7,12,13)])
        images11.append(images[kk])
        labels11.append(labels[kk])
print(np.shape(geoparas))
# Out:
# (1202, 12)

# %%
#load data from the second folder
#geometrical parameters stored in log.txt
#order of geopara (radiusA,radiusB,turnsA,turnsB,openA,openB,outA,outB,extA,extB,ratio,outbound)
logfile = open("/rdf/shared/design_automation/Data/2409Air_2/log.txt","r")
listall = list(map(lambda item: list(map(lambda jtem: eval(jtem.strip()), item[1:-1].split(','))), logfile.read().strip().split('\n')))
tabular_data = np.array(listall)

#load images and s-parameters
#length = len(listall)-3
length = 900
images, labels = load_images_from_path('/rdf/shared/design_automation/Data/2409Air_2/PNG/', '/rdf/shared/design_automation/Data/2409Air_2/SPData/',length)


for kk in range(length):
    #select 1 turn and 1 turn transformers
   if((tabular_data[kk,2] !=1) or (tabular_data[kk,3]!=1)):
       #geoparas only includes the variable parameters in our designs. 
       #Constants at this design stages are excluded 
        geoparas.append(tabular_data[kk,(0,1,2,3,4,5,4,5,6,7,12,13)])
        images11.append(images[kk])
        labels11.append(labels[kk])
print(np.shape(geoparas))
# Out:
# (1478, 12)

# %%
#normalize geometrical inputs
geoparas_temp = np.array(geoparas)
geoparas = np.zeros(np.shape(geoparas_temp))
for i in range(len(geoparas)):
    for j in range(12):
        geoparas[i,j]= (geoparas_temp[i,j]-np.mean(geoparas_temp[:,j]))/np.std(geoparas_temp[:,j])

# %%
#construct the datasets
class item:
  def __init__(self, image,geopara,label ):
    self.image = image
    self.geopara = geopara
    self.label = label

data = []
for i in range(len(images11)):
    data.append(item(images11[i],geoparas[i],labels11[i]))

np.random.shuffle(data)

# %%
#define the split length for training, validation and test datasets
length = len(images11)
split1 = int(0.6*length)
split2 = int(0.8*length)
data_train = data[0:split1]
data_valid = data[split1:split2]
data_test = data[split2:]

# %%
#Separate the training, validation and test datasets 
train_images = []
train_labels = []
train_geoparas = []
valid_images = []
valid_labels = []
valid_geoparas = []
test_images = []
test_labels = []
test_geoparas = []


#The targeted frequency span up to fmax, with 1GHz step
s_max = np.zeros((fmax,12))
s_min = np.zeros((fmax,12))
srange = np.zeros((fmax,12))


for i in range(len(data_train)):
    train_images.append(data_train[i].image)
    train_geoparas.append(data_train[i].geopara)
    train_labels.append(data_train[i].label)
x_train_img = np.array(train_images) / 255
x_train_geopara = np.array(train_geoparas)
y_train_encoded = np.array(train_labels)[:,1:fmax+1,:]


for i in range(len(data_valid)):
    valid_images.append(data_valid[i].image)
    valid_geoparas.append(data_valid[i].geopara)
    valid_labels.append(data_valid[i].label)
x_valid_img = np.array(valid_images) / 255
x_valid_geopara = np.array(valid_geoparas)
y_valid_encoded = np.array(valid_labels)[:,1:fmax+1,:]


for i in range(len(data_test)):
    test_images.append(data_test[i].image)
    test_geoparas.append(data_test[i].geopara)
    test_labels.append(data_test[i].label)
x_test_img = np.array(test_images) / 255
x_test_geopara = np.array(test_geoparas)
y_test_encoded = np.array(test_labels)[:,1:fmax+1,:]

#normalize the s-parameters for each frequency point
for z in range(fmax):
    for i in range(12):
        s_max[z,i] = max(max(y_train_encoded[:,z,i]),max(y_valid_encoded[:,z,i]),max(y_test_encoded[:,z,i]))
        s_min[z,i] = min(min(y_train_encoded[:,z,i]),min(y_valid_encoded[:,z,i]),min(y_test_encoded[:,z,i]))
        srange[z,i] = s_max[z,i]-s_min[z,i]
    
    for i in range(12):
        y_train_encoded[:,z,i] = 2*(y_train_encoded[:,z,i]-s_min[z,i])/srange[z,i]-1

    for i in range(12):
        y_valid_encoded[:,z,i] = 2*(y_valid_encoded[:,z,i]-s_min[z,i])/srange[z,i]-1
    
    for i in range(12):
        y_test_encoded[:,z,i] = 2*(y_test_encoded[:,z,i]-s_min[z,i])/srange[z,i]-1

# %%
def custom_loss(y_true, y_pred):
    Lf = tf.math.sqrt(tf.reduce_mean(tf.square(y_true - y_pred),axis=1))
    return (tf.reduce_mean(Lf))

# %%
from keras import Sequential, Input, Model, regularizers
from keras.layers import Conv2D, MaxPooling2D,Dropout, Reshape, BatchNormalization,Conv1DTranspose,Conv1D
from keras.layers import Flatten, Dense, Concatenate
learning_rate = 1e-4
n_unet = 8

models = []

inp1 = Input((224,224,3),)
'''
model1 = (Conv2D(n_unet,(3,3),padding='same', activation='relu', input_shape=(224, 224, 3), kernel_regularizer=regularizers.l2(0.01)))(inp1)
model1 = (MaxPooling2D(2, 2))(model1)
model1 = (Conv2D(n_unet*2, (3, 3), padding='same',activation='relu'))(model1)

model1 = (MaxPooling2D(2, 2))(model1)
#model1 = BatchNormalization()(model1)
model1 = (Conv2D(n_unet*2, (3, 3),  padding='same',activation='relu'))(model1)

model1 = (MaxPooling2D(2, 2))(model1)
#model1 = BatchNormalization()(model1)
model1 = (Conv2D(n_unet*4, (3, 3), padding='same', activation='relu'))(model1)

layer1 = (MaxPooling2D(2, 2))(model1)
#model1 = Dropout(0.3)(model1)
#model1 = BatchNormalization()(model1)
layer2 = (Conv2D(n_unet*8, (3, 3),padding='same', activation='relu'))(layer1)
layer2 = (MaxPooling2D(2, 2))(layer2)

layer3 = (Conv2D(n_unet*16, (3, 3),padding='same', activation='relu'))(layer2)
layer3 = (MaxPooling2D(2, 2))(layer3)

layer4 = (Conv2D(n_unet*32, (3, 3),padding='same', activation='relu'))(layer3)
layer4 = (MaxPooling2D(2, 2))(layer4)


#backward
layer4 = Reshape((1,n_unet*32))(layer4)
layer4 = (Conv1DTranspose(n_unet*16,9,1, activation='relu'))(layer4)

layer3 = Reshape((9,n_unet*16))(layer3)
layer3 = Concatenate()([layer3,layer4])
layer3 = (Conv1D(n_unet*16,3,padding='same', activation='relu'))(layer3)
layer3 = (Conv1DTranspose(n_unet*8,9,5, activation='relu'))(layer3)


layer2 = Reshape((49,n_unet*8))(layer2)
layer2 = Concatenate()([layer2,layer3])
layer2 = (Conv1D(n_unet*8,3,padding='same', activation='relu'))(layer2)
layer2 = (Conv1DTranspose(n_unet*4,3,4, activation='relu'))(layer2)

layer1 = Reshape((196,n_unet*4))(layer1)
layer1 = Concatenate()([layer1,layer2])
layer1 = (Conv1D(n_unet*4,3,padding='same', activation='relu'))(layer2)
model1 = Flatten()(layer1)
models.append(model1)
'''
inp2 = Input(12,)

model2=(Dense(512,activation='relu',input_shape = (10,),kernel_regularizer=regularizers.l2(0.010)))(inp2)
model2=(Dense(512,activation='relu'))(model2)
model2=(Dense(512,activation='relu'))(model2)
model2=(Dense(512,activation='relu'))(model2)
model2=(Dense(512,activation='relu'))(model2)
models.append(model2)
'''
model3 = (Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3), kernel_regularizer=regularizers.l2(0.05)))(inp1)
model3 = (MaxPooling2D(2, 2))(model3)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = BatchNormalization()(model1)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = BatchNormalization()(model1)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = Dropout(0.3)(model1)
#model1 = BatchNormalization()(model1)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = BatchNormalization()(model1)
#model1 = Dropout(0.3)(model1)
model3 = Flatten()(model3)
model3 = Dense(512,activation='relu')(model3)

models.append(model3)
'''
out = Concatenate()(models)

out = (Dense(fmax*12, activation='tanh'))(out)
out = Reshape((fmax,12))(out)
model = Model([inp1,inp2],out)
model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=learning_rate), loss=custom_loss, metrics=['mae',custom_loss])
model.summary()
# Out:
# 2024-12-03 03:54:12.107302: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13397 MB memory:  -> device: 0, name: NVIDIA A2, pci bus id: 0000:21:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 12)]                 0         []
#
#  dense (Dense)               (None, 512)                  6656      ['input_2[0][0]']
#
#  dense_1 (Dense)             (None, 512)                  262656    ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 512)                  262656    ['dense_1[0][0]']
#
#  dense_3 (Dense)             (None, 512)                  262656    ['dense_2[0][0]']
#
#  dense_4 (Dense)             (None, 512)                  262656    ['dense_3[0][0]']
#
#  concatenate (Concatenate)   (None, 512)                  0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 2352)                 1206576   ['concatenate[0][0]']
#
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  reshape (Reshape)           (None, 196, 12)              0         ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 2263856 (8.64 MB)
# Trainable params: 2263856 (8.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
EPOCHS = 300
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: learning_rate * 0.95**(epoch/20))
hist = model.fit([x_train_img,x_train_geopara], y_train_encoded, validation_data=([x_valid_img,x_valid_geopara], y_valid_encoded), batch_size=30, epochs = EPOCHS,callbacks=[lr_schedule])
# Out:
# Epoch 1/300
# 2024-12-03 03:54:15.086385: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-12-03 03:54:15.419212: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55a41e1f92c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-12-03 03:54:15.419267: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A2, Compute Capability 8.6
# 2024-12-03 03:54:15.426207: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-03 03:54:15.463285: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8907
# 2024-12-03 03:54:15.529345: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-12-03 03:54:15.596839: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 30/30 [==============================] - 3s 16ms/step - loss: 0.6614 - mae: 0.3709 - custom_loss: 0.4335 - val_loss: 0.6316 - val_mae: 0.3501 - val_custom_loss: 0.4142 - lr: 1.0000e-04
# Epoch 2/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.6047 - mae: 0.3332 - custom_loss: 0.3958 - val_loss: 0.5868 - val_mae: 0.3251 - val_custom_loss: 0.3871 - lr: 9.9744e-05
# Epoch 3/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.5618 - mae: 0.3096 - custom_loss: 0.3693 - val_loss: 0.5386 - val_mae: 0.2954 - val_custom_loss: 0.3549 - lr: 9.9488e-05
# Epoch 4/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.5157 - mae: 0.2801 - custom_loss: 0.3391 - val_loss: 0.4977 - val_mae: 0.2700 - val_custom_loss: 0.3287 - lr: 9.9234e-05
# Epoch 5/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.4832 - mae: 0.2625 - custom_loss: 0.3208 - val_loss: 0.4700 - val_mae: 0.2562 - val_custom_loss: 0.3145 - lr: 9.8979e-05
# Epoch 6/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.4537 - mae: 0.2469 - custom_loss: 0.3040 - val_loss: 0.4391 - val_mae: 0.2390 - val_custom_loss: 0.2959 - lr: 9.8726e-05
# Epoch 7/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.4221 - mae: 0.2287 - custom_loss: 0.2841 - val_loss: 0.4073 - val_mae: 0.2204 - val_custom_loss: 0.2753 - lr: 9.8473e-05
# Epoch 8/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3942 - mae: 0.2127 - custom_loss: 0.2672 - val_loss: 0.3842 - val_mae: 0.2086 - val_custom_loss: 0.2622 - lr: 9.8221e-05
# Epoch 9/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3735 - mae: 0.2029 - custom_loss: 0.2556 - val_loss: 0.3661 - val_mae: 0.2007 - val_custom_loss: 0.2533 - lr: 9.7969e-05
# Epoch 10/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.3566 - mae: 0.1956 - custom_loss: 0.2477 - val_loss: 0.3510 - val_mae: 0.1943 - val_custom_loss: 0.2466 - lr: 9.7718e-05
# Epoch 11/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3417 - mae: 0.1895 - custom_loss: 0.2408 - val_loss: 0.3374 - val_mae: 0.1889 - val_custom_loss: 0.2406 - lr: 9.7468e-05
# Epoch 12/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3295 - mae: 0.1855 - custom_loss: 0.2364 - val_loss: 0.3264 - val_mae: 0.1856 - val_custom_loss: 0.2366 - lr: 9.7218e-05
# Epoch 13/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3173 - mae: 0.1807 - custom_loss: 0.2304 - val_loss: 0.3124 - val_mae: 0.1790 - val_custom_loss: 0.2289 - lr: 9.6969e-05
# Epoch 14/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3049 - mae: 0.1753 - custom_loss: 0.2243 - val_loss: 0.3027 - val_mae: 0.1753 - val_custom_loss: 0.2250 - lr: 9.6721e-05
# Epoch 15/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2940 - mae: 0.1707 - custom_loss: 0.2188 - val_loss: 0.2912 - val_mae: 0.1703 - val_custom_loss: 0.2188 - lr: 9.6473e-05
# Epoch 16/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2847 - mae: 0.1672 - custom_loss: 0.2146 - val_loss: 0.2833 - val_mae: 0.1678 - val_custom_loss: 0.2158 - lr: 9.6226e-05
# Epoch 17/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2748 - mae: 0.1628 - custom_loss: 0.2094 - val_loss: 0.2718 - val_mae: 0.1616 - val_custom_loss: 0.2087 - lr: 9.5980e-05
# Epoch 18/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2662 - mae: 0.1589 - custom_loss: 0.2049 - val_loss: 0.2649 - val_mae: 0.1591 - val_custom_loss: 0.2058 - lr: 9.5734e-05
# Epoch 19/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2588 - mae: 0.1560 - custom_loss: 0.2019 - val_loss: 0.2581 - val_mae: 0.1566 - val_custom_loss: 0.2028 - lr: 9.5489e-05
# Epoch 20/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2526 - mae: 0.1539 - custom_loss: 0.1989 - val_loss: 0.2525 - val_mae: 0.1549 - val_custom_loss: 0.2006 - lr: 9.5244e-05
# Epoch 21/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2465 - mae: 0.1514 - custom_loss: 0.1960 - val_loss: 0.2476 - val_mae: 0.1531 - val_custom_loss: 0.1988 - lr: 9.5000e-05
# Epoch 22/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2410 - mae: 0.1493 - custom_loss: 0.1936 - val_loss: 0.2420 - val_mae: 0.1508 - val_custom_loss: 0.1961 - lr: 9.4757e-05
# Epoch 23/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2358 - mae: 0.1472 - custom_loss: 0.1909 - val_loss: 0.2376 - val_mae: 0.1492 - val_custom_loss: 0.1943 - lr: 9.4514e-05
# Epoch 24/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2316 - mae: 0.1459 - custom_loss: 0.1898 - val_loss: 0.2329 - val_mae: 0.1474 - val_custom_loss: 0.1921 - lr: 9.4272e-05
# Epoch 25/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2279 - mae: 0.1448 - custom_loss: 0.1882 - val_loss: 0.2295 - val_mae: 0.1463 - val_custom_loss: 0.1910 - lr: 9.4030e-05
# Epoch 26/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2238 - mae: 0.1430 - custom_loss: 0.1861 - val_loss: 0.2263 - val_mae: 0.1454 - val_custom_loss: 0.1898 - lr: 9.3790e-05
# Epoch 27/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2201 - mae: 0.1416 - custom_loss: 0.1846 - val_loss: 0.2235 - val_mae: 0.1448 - val_custom_loss: 0.1890 - lr: 9.3549e-05
# Epoch 28/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2173 - mae: 0.1407 - custom_loss: 0.1837 - val_loss: 0.2208 - val_mae: 0.1439 - val_custom_loss: 0.1880 - lr: 9.3310e-05
# Epoch 29/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2134 - mae: 0.1389 - custom_loss: 0.1814 - val_loss: 0.2178 - val_mae: 0.1423 - val_custom_loss: 0.1866 - lr: 9.3071e-05
# Epoch 30/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2105 - mae: 0.1378 - custom_loss: 0.1801 - val_loss: 0.2146 - val_mae: 0.1412 - val_custom_loss: 0.1850 - lr: 9.2832e-05
# Epoch 31/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2082 - mae: 0.1371 - custom_loss: 0.1795 - val_loss: 0.2119 - val_mae: 0.1399 - val_custom_loss: 0.1837 - lr: 9.2595e-05
# Epoch 32/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2060 - mae: 0.1363 - custom_loss: 0.1782 - val_loss: 0.2101 - val_mae: 0.1392 - val_custom_loss: 0.1831 - lr: 9.2357e-05
# Epoch 33/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2028 - mae: 0.1346 - custom_loss: 0.1762 - val_loss: 0.2080 - val_mae: 0.1383 - val_custom_loss: 0.1822 - lr: 9.2121e-05
# Epoch 34/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2010 - mae: 0.1341 - custom_loss: 0.1760 - val_loss: 0.2052 - val_mae: 0.1373 - val_custom_loss: 0.1806 - lr: 9.1885e-05
# Epoch 35/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1987 - mae: 0.1331 - custom_loss: 0.1744 - val_loss: 0.2033 - val_mae: 0.1365 - val_custom_loss: 0.1797 - lr: 9.1650e-05
# Epoch 36/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1969 - mae: 0.1322 - custom_loss: 0.1735 - val_loss: 0.2010 - val_mae: 0.1355 - val_custom_loss: 0.1784 - lr: 9.1415e-05
# Epoch 37/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1943 - mae: 0.1310 - custom_loss: 0.1725 - val_loss: 0.1995 - val_mae: 0.1347 - val_custom_loss: 0.1778 - lr: 9.1181e-05
# Epoch 38/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1930 - mae: 0.1306 - custom_loss: 0.1719 - val_loss: 0.1985 - val_mae: 0.1347 - val_custom_loss: 0.1776 - lr: 9.0947e-05
# Epoch 39/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1913 - mae: 0.1299 - custom_loss: 0.1714 - val_loss: 0.1967 - val_mae: 0.1336 - val_custom_loss: 0.1766 - lr: 9.0714e-05
# Epoch 40/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1896 - mae: 0.1290 - custom_loss: 0.1698 - val_loss: 0.1961 - val_mae: 0.1338 - val_custom_loss: 0.1767 - lr: 9.0482e-05
# Epoch 41/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1878 - mae: 0.1280 - custom_loss: 0.1685 - val_loss: 0.1936 - val_mae: 0.1323 - val_custom_loss: 0.1750 - lr: 9.0250e-05
# Epoch 42/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1869 - mae: 0.1280 - custom_loss: 0.1687 - val_loss: 0.1929 - val_mae: 0.1320 - val_custom_loss: 0.1748 - lr: 9.0019e-05
# Epoch 43/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1855 - mae: 0.1272 - custom_loss: 0.1677 - val_loss: 0.1910 - val_mae: 0.1309 - val_custom_loss: 0.1736 - lr: 8.9788e-05
# Epoch 44/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1834 - mae: 0.1258 - custom_loss: 0.1665 - val_loss: 0.1902 - val_mae: 0.1310 - val_custom_loss: 0.1733 - lr: 8.9558e-05
# Epoch 45/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1822 - mae: 0.1254 - custom_loss: 0.1656 - val_loss: 0.1894 - val_mae: 0.1308 - val_custom_loss: 0.1730 - lr: 8.9329e-05
# Epoch 46/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1810 - mae: 0.1247 - custom_loss: 0.1650 - val_loss: 0.1877 - val_mae: 0.1298 - val_custom_loss: 0.1718 - lr: 8.9100e-05
# Epoch 47/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1804 - mae: 0.1247 - custom_loss: 0.1650 - val_loss: 0.1868 - val_mae: 0.1294 - val_custom_loss: 0.1714 - lr: 8.8872e-05
# Epoch 48/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1789 - mae: 0.1237 - custom_loss: 0.1636 - val_loss: 0.1854 - val_mae: 0.1285 - val_custom_loss: 0.1703 - lr: 8.8644e-05
# Epoch 49/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1774 - mae: 0.1228 - custom_loss: 0.1628 - val_loss: 0.1851 - val_mae: 0.1286 - val_custom_loss: 0.1704 - lr: 8.8417e-05
# Epoch 50/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1767 - mae: 0.1226 - custom_loss: 0.1625 - val_loss: 0.1842 - val_mae: 0.1280 - val_custom_loss: 0.1700 - lr: 8.8191e-05
# Epoch 51/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1759 - mae: 0.1222 - custom_loss: 0.1622 - val_loss: 0.1838 - val_mae: 0.1278 - val_custom_loss: 0.1700 - lr: 8.7965e-05
# Epoch 52/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1746 - mae: 0.1214 - custom_loss: 0.1605 - val_loss: 0.1828 - val_mae: 0.1274 - val_custom_loss: 0.1693 - lr: 8.7740e-05
# Epoch 53/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1739 - mae: 0.1211 - custom_loss: 0.1605 - val_loss: 0.1818 - val_mae: 0.1267 - val_custom_loss: 0.1685 - lr: 8.7515e-05
# Epoch 54/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1728 - mae: 0.1205 - custom_loss: 0.1598 - val_loss: 0.1804 - val_mae: 0.1260 - val_custom_loss: 0.1675 - lr: 8.7291e-05
# Epoch 55/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1719 - mae: 0.1200 - custom_loss: 0.1592 - val_loss: 0.1802 - val_mae: 0.1259 - val_custom_loss: 0.1676 - lr: 8.7067e-05
# Epoch 56/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1707 - mae: 0.1192 - custom_loss: 0.1585 - val_loss: 0.1793 - val_mae: 0.1256 - val_custom_loss: 0.1669 - lr: 8.6844e-05
# Epoch 57/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1702 - mae: 0.1191 - custom_loss: 0.1581 - val_loss: 0.1785 - val_mae: 0.1251 - val_custom_loss: 0.1664 - lr: 8.6622e-05
# Epoch 58/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1697 - mae: 0.1189 - custom_loss: 0.1579 - val_loss: 0.1794 - val_mae: 0.1258 - val_custom_loss: 0.1676 - lr: 8.6400e-05
# Epoch 59/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1685 - mae: 0.1180 - custom_loss: 0.1567 - val_loss: 0.1769 - val_mae: 0.1241 - val_custom_loss: 0.1653 - lr: 8.6178e-05
# Epoch 60/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1681 - mae: 0.1179 - custom_loss: 0.1567 - val_loss: 0.1772 - val_mae: 0.1244 - val_custom_loss: 0.1658 - lr: 8.5958e-05
# Epoch 61/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1671 - mae: 0.1172 - custom_loss: 0.1556 - val_loss: 0.1761 - val_mae: 0.1236 - val_custom_loss: 0.1650 - lr: 8.5737e-05
# Epoch 62/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1663 - mae: 0.1167 - custom_loss: 0.1554 - val_loss: 0.1765 - val_mae: 0.1240 - val_custom_loss: 0.1656 - lr: 8.5518e-05
# Epoch 63/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1658 - mae: 0.1164 - custom_loss: 0.1550 - val_loss: 0.1751 - val_mae: 0.1232 - val_custom_loss: 0.1643 - lr: 8.5299e-05
# Epoch 64/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1654 - mae: 0.1163 - custom_loss: 0.1548 - val_loss: 0.1752 - val_mae: 0.1235 - val_custom_loss: 0.1647 - lr: 8.5080e-05
# Epoch 65/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1645 - mae: 0.1156 - custom_loss: 0.1539 - val_loss: 0.1745 - val_mae: 0.1228 - val_custom_loss: 0.1641 - lr: 8.4862e-05
# Epoch 66/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1641 - mae: 0.1155 - custom_loss: 0.1536 - val_loss: 0.1753 - val_mae: 0.1238 - val_custom_loss: 0.1650 - lr: 8.4645e-05
# Epoch 67/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1633 - mae: 0.1149 - custom_loss: 0.1533 - val_loss: 0.1732 - val_mae: 0.1221 - val_custom_loss: 0.1632 - lr: 8.4428e-05
# Epoch 68/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1625 - mae: 0.1144 - custom_loss: 0.1529 - val_loss: 0.1729 - val_mae: 0.1221 - val_custom_loss: 0.1630 - lr: 8.4212e-05
# Epoch 69/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1623 - mae: 0.1143 - custom_loss: 0.1525 - val_loss: 0.1724 - val_mae: 0.1217 - val_custom_loss: 0.1626 - lr: 8.3996e-05
# Epoch 70/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1619 - mae: 0.1142 - custom_loss: 0.1525 - val_loss: 0.1723 - val_mae: 0.1217 - val_custom_loss: 0.1627 - lr: 8.3781e-05
# Epoch 71/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1616 - mae: 0.1141 - custom_loss: 0.1519 - val_loss: 0.1722 - val_mae: 0.1216 - val_custom_loss: 0.1627 - lr: 8.3567e-05
# Epoch 72/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1612 - mae: 0.1138 - custom_loss: 0.1517 - val_loss: 0.1715 - val_mae: 0.1211 - val_custom_loss: 0.1621 - lr: 8.3353e-05
# Epoch 73/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1600 - mae: 0.1130 - custom_loss: 0.1512 - val_loss: 0.1705 - val_mae: 0.1203 - val_custom_loss: 0.1612 - lr: 8.3139e-05
# Epoch 74/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1594 - mae: 0.1125 - custom_loss: 0.1501 - val_loss: 0.1716 - val_mae: 0.1213 - val_custom_loss: 0.1625 - lr: 8.2926e-05
# Epoch 75/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1590 - mae: 0.1122 - custom_loss: 0.1503 - val_loss: 0.1701 - val_mae: 0.1206 - val_custom_loss: 0.1611 - lr: 8.2714e-05
# Epoch 76/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1588 - mae: 0.1122 - custom_loss: 0.1496 - val_loss: 0.1694 - val_mae: 0.1198 - val_custom_loss: 0.1606 - lr: 8.2502e-05
# Epoch 77/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1579 - mae: 0.1117 - custom_loss: 0.1489 - val_loss: 0.1696 - val_mae: 0.1200 - val_custom_loss: 0.1608 - lr: 8.2290e-05
# Epoch 78/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1574 - mae: 0.1112 - custom_loss: 0.1487 - val_loss: 0.1695 - val_mae: 0.1203 - val_custom_loss: 0.1609 - lr: 8.2080e-05
# Epoch 79/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1572 - mae: 0.1112 - custom_loss: 0.1489 - val_loss: 0.1690 - val_mae: 0.1197 - val_custom_loss: 0.1605 - lr: 8.1869e-05
# Epoch 80/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1564 - mae: 0.1106 - custom_loss: 0.1478 - val_loss: 0.1687 - val_mae: 0.1195 - val_custom_loss: 0.1602 - lr: 8.1660e-05
# Epoch 81/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1563 - mae: 0.1105 - custom_loss: 0.1481 - val_loss: 0.1686 - val_mae: 0.1196 - val_custom_loss: 0.1603 - lr: 8.1451e-05
# Epoch 82/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1557 - mae: 0.1103 - custom_loss: 0.1475 - val_loss: 0.1675 - val_mae: 0.1186 - val_custom_loss: 0.1592 - lr: 8.1242e-05
# Epoch 83/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1556 - mae: 0.1102 - custom_loss: 0.1473 - val_loss: 0.1670 - val_mae: 0.1185 - val_custom_loss: 0.1588 - lr: 8.1034e-05
# Epoch 84/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1549 - mae: 0.1097 - custom_loss: 0.1467 - val_loss: 0.1676 - val_mae: 0.1191 - val_custom_loss: 0.1595 - lr: 8.0826e-05
# Epoch 85/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1547 - mae: 0.1096 - custom_loss: 0.1468 - val_loss: 0.1683 - val_mae: 0.1197 - val_custom_loss: 0.1603 - lr: 8.0619e-05
# Epoch 86/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1542 - mae: 0.1092 - custom_loss: 0.1469 - val_loss: 0.1666 - val_mae: 0.1183 - val_custom_loss: 0.1587 - lr: 8.0413e-05
# Epoch 87/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1538 - mae: 0.1090 - custom_loss: 0.1458 - val_loss: 0.1659 - val_mae: 0.1179 - val_custom_loss: 0.1581 - lr: 8.0207e-05
# Epoch 88/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1533 - mae: 0.1087 - custom_loss: 0.1459 - val_loss: 0.1661 - val_mae: 0.1180 - val_custom_loss: 0.1584 - lr: 8.0001e-05
# Epoch 89/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1528 - mae: 0.1083 - custom_loss: 0.1449 - val_loss: 0.1656 - val_mae: 0.1176 - val_custom_loss: 0.1579 - lr: 7.9797e-05
# Epoch 90/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1527 - mae: 0.1083 - custom_loss: 0.1450 - val_loss: 0.1660 - val_mae: 0.1179 - val_custom_loss: 0.1584 - lr: 7.9592e-05
# Epoch 91/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1521 - mae: 0.1078 - custom_loss: 0.1446 - val_loss: 0.1659 - val_mae: 0.1179 - val_custom_loss: 0.1584 - lr: 7.9388e-05
# Epoch 92/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1517 - mae: 0.1075 - custom_loss: 0.1441 - val_loss: 0.1654 - val_mae: 0.1178 - val_custom_loss: 0.1579 - lr: 7.9185e-05
# Epoch 93/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1514 - mae: 0.1074 - custom_loss: 0.1437 - val_loss: 0.1649 - val_mae: 0.1174 - val_custom_loss: 0.1574 - lr: 7.8982e-05
# Epoch 94/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1515 - mae: 0.1076 - custom_loss: 0.1441 - val_loss: 0.1644 - val_mae: 0.1169 - val_custom_loss: 0.1570 - lr: 7.8780e-05
# Epoch 95/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1507 - mae: 0.1069 - custom_loss: 0.1434 - val_loss: 0.1639 - val_mae: 0.1166 - val_custom_loss: 0.1566 - lr: 7.8578e-05
# Epoch 96/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1504 - mae: 0.1067 - custom_loss: 0.1433 - val_loss: 0.1644 - val_mae: 0.1171 - val_custom_loss: 0.1572 - lr: 7.8377e-05
# Epoch 97/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1499 - mae: 0.1064 - custom_loss: 0.1435 - val_loss: 0.1635 - val_mae: 0.1163 - val_custom_loss: 0.1563 - lr: 7.8176e-05
# Epoch 98/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1500 - mae: 0.1065 - custom_loss: 0.1428 - val_loss: 0.1639 - val_mae: 0.1166 - val_custom_loss: 0.1568 - lr: 7.7976e-05
# Epoch 99/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1491 - mae: 0.1058 - custom_loss: 0.1421 - val_loss: 0.1639 - val_mae: 0.1166 - val_custom_loss: 0.1569 - lr: 7.7776e-05
# Epoch 100/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1491 - mae: 0.1058 - custom_loss: 0.1424 - val_loss: 0.1630 - val_mae: 0.1159 - val_custom_loss: 0.1560 - lr: 7.7577e-05
# Epoch 101/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1486 - mae: 0.1054 - custom_loss: 0.1415 - val_loss: 0.1626 - val_mae: 0.1157 - val_custom_loss: 0.1557 - lr: 7.7378e-05
# Epoch 102/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1480 - mae: 0.1050 - custom_loss: 0.1414 - val_loss: 0.1631 - val_mae: 0.1161 - val_custom_loss: 0.1562 - lr: 7.7180e-05
# Epoch 103/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1479 - mae: 0.1051 - custom_loss: 0.1414 - val_loss: 0.1626 - val_mae: 0.1159 - val_custom_loss: 0.1558 - lr: 7.6982e-05
# Epoch 104/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1479 - mae: 0.1051 - custom_loss: 0.1412 - val_loss: 0.1630 - val_mae: 0.1160 - val_custom_loss: 0.1562 - lr: 7.6785e-05
# Epoch 105/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1474 - mae: 0.1047 - custom_loss: 0.1404 - val_loss: 0.1623 - val_mae: 0.1156 - val_custom_loss: 0.1556 - lr: 7.6588e-05
# Epoch 106/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1471 - mae: 0.1044 - custom_loss: 0.1402 - val_loss: 0.1624 - val_mae: 0.1157 - val_custom_loss: 0.1557 - lr: 7.6392e-05
# Epoch 107/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1470 - mae: 0.1044 - custom_loss: 0.1404 - val_loss: 0.1630 - val_mae: 0.1160 - val_custom_loss: 0.1563 - lr: 7.6197e-05
# Epoch 108/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1468 - mae: 0.1044 - custom_loss: 0.1400 - val_loss: 0.1613 - val_mae: 0.1148 - val_custom_loss: 0.1547 - lr: 7.6001e-05
# Epoch 109/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1463 - mae: 0.1040 - custom_loss: 0.1396 - val_loss: 0.1610 - val_mae: 0.1148 - val_custom_loss: 0.1545 - lr: 7.5807e-05
# Epoch 110/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1461 - mae: 0.1038 - custom_loss: 0.1396 - val_loss: 0.1609 - val_mae: 0.1146 - val_custom_loss: 0.1544 - lr: 7.5613e-05
# Epoch 111/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1457 - mae: 0.1036 - custom_loss: 0.1394 - val_loss: 0.1605 - val_mae: 0.1143 - val_custom_loss: 0.1541 - lr: 7.5419e-05
# Epoch 112/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1452 - mae: 0.1032 - custom_loss: 0.1388 - val_loss: 0.1610 - val_mae: 0.1148 - val_custom_loss: 0.1546 - lr: 7.5226e-05
# Epoch 113/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1449 - mae: 0.1029 - custom_loss: 0.1387 - val_loss: 0.1604 - val_mae: 0.1143 - val_custom_loss: 0.1540 - lr: 7.5033e-05
# Epoch 114/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1447 - mae: 0.1028 - custom_loss: 0.1381 - val_loss: 0.1603 - val_mae: 0.1144 - val_custom_loss: 0.1540 - lr: 7.4841e-05
# Epoch 115/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1444 - mae: 0.1026 - custom_loss: 0.1380 - val_loss: 0.1596 - val_mae: 0.1137 - val_custom_loss: 0.1533 - lr: 7.4649e-05
# Epoch 116/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1442 - mae: 0.1025 - custom_loss: 0.1379 - val_loss: 0.1606 - val_mae: 0.1146 - val_custom_loss: 0.1543 - lr: 7.4458e-05
# Epoch 117/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1441 - mae: 0.1025 - custom_loss: 0.1374 - val_loss: 0.1601 - val_mae: 0.1142 - val_custom_loss: 0.1539 - lr: 7.4267e-05
# Epoch 118/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1440 - mae: 0.1023 - custom_loss: 0.1380 - val_loss: 0.1605 - val_mae: 0.1145 - val_custom_loss: 0.1543 - lr: 7.4077e-05
# Epoch 119/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1437 - mae: 0.1022 - custom_loss: 0.1378 - val_loss: 0.1596 - val_mae: 0.1137 - val_custom_loss: 0.1534 - lr: 7.3887e-05
# Epoch 120/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1435 - mae: 0.1021 - custom_loss: 0.1380 - val_loss: 0.1592 - val_mae: 0.1135 - val_custom_loss: 0.1531 - lr: 7.3698e-05
# Epoch 121/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1432 - mae: 0.1019 - custom_loss: 0.1370 - val_loss: 0.1586 - val_mae: 0.1131 - val_custom_loss: 0.1525 - lr: 7.3509e-05
# Epoch 122/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1431 - mae: 0.1018 - custom_loss: 0.1371 - val_loss: 0.1591 - val_mae: 0.1136 - val_custom_loss: 0.1531 - lr: 7.3321e-05
# Epoch 123/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1427 - mae: 0.1016 - custom_loss: 0.1369 - val_loss: 0.1592 - val_mae: 0.1136 - val_custom_loss: 0.1532 - lr: 7.3133e-05
# Epoch 124/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1424 - mae: 0.1013 - custom_loss: 0.1362 - val_loss: 0.1581 - val_mae: 0.1128 - val_custom_loss: 0.1521 - lr: 7.2946e-05
# Epoch 125/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1422 - mae: 0.1011 - custom_loss: 0.1363 - val_loss: 0.1596 - val_mae: 0.1140 - val_custom_loss: 0.1537 - lr: 7.2759e-05
# Epoch 126/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1423 - mae: 0.1013 - custom_loss: 0.1363 - val_loss: 0.1585 - val_mae: 0.1132 - val_custom_loss: 0.1526 - lr: 7.2573e-05
# Epoch 127/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1417 - mae: 0.1008 - custom_loss: 0.1359 - val_loss: 0.1579 - val_mae: 0.1127 - val_custom_loss: 0.1521 - lr: 7.2387e-05
# Epoch 128/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1413 - mae: 0.1005 - custom_loss: 0.1360 - val_loss: 0.1581 - val_mae: 0.1128 - val_custom_loss: 0.1522 - lr: 7.2201e-05
# Epoch 129/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1412 - mae: 0.1005 - custom_loss: 0.1352 - val_loss: 0.1589 - val_mae: 0.1137 - val_custom_loss: 0.1531 - lr: 7.2016e-05
# Epoch 130/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1413 - mae: 0.1006 - custom_loss: 0.1356 - val_loss: 0.1576 - val_mae: 0.1127 - val_custom_loss: 0.1519 - lr: 7.1832e-05
# Epoch 131/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1406 - mae: 0.1000 - custom_loss: 0.1351 - val_loss: 0.1579 - val_mae: 0.1127 - val_custom_loss: 0.1521 - lr: 7.1648e-05
# Epoch 132/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1408 - mae: 0.1002 - custom_loss: 0.1350 - val_loss: 0.1576 - val_mae: 0.1127 - val_custom_loss: 0.1519 - lr: 7.1464e-05
# Epoch 133/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1406 - mae: 0.1000 - custom_loss: 0.1352 - val_loss: 0.1565 - val_mae: 0.1118 - val_custom_loss: 0.1508 - lr: 7.1281e-05
# Epoch 134/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1398 - mae: 0.0994 - custom_loss: 0.1338 - val_loss: 0.1571 - val_mae: 0.1121 - val_custom_loss: 0.1515 - lr: 7.1099e-05
# Epoch 135/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1397 - mae: 0.0994 - custom_loss: 0.1339 - val_loss: 0.1578 - val_mae: 0.1127 - val_custom_loss: 0.1521 - lr: 7.0917e-05
# Epoch 136/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1396 - mae: 0.0992 - custom_loss: 0.1340 - val_loss: 0.1570 - val_mae: 0.1122 - val_custom_loss: 0.1515 - lr: 7.0735e-05
# Epoch 137/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1393 - mae: 0.0991 - custom_loss: 0.1336 - val_loss: 0.1569 - val_mae: 0.1120 - val_custom_loss: 0.1513 - lr: 7.0554e-05
# Epoch 138/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1389 - mae: 0.0987 - custom_loss: 0.1333 - val_loss: 0.1564 - val_mae: 0.1116 - val_custom_loss: 0.1508 - lr: 7.0373e-05
# Epoch 139/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1387 - mae: 0.0986 - custom_loss: 0.1332 - val_loss: 0.1569 - val_mae: 0.1122 - val_custom_loss: 0.1514 - lr: 7.0193e-05
# Epoch 140/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1389 - mae: 0.0989 - custom_loss: 0.1335 - val_loss: 0.1564 - val_mae: 0.1116 - val_custom_loss: 0.1509 - lr: 7.0013e-05
# Epoch 141/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1390 - mae: 0.0989 - custom_loss: 0.1336 - val_loss: 0.1566 - val_mae: 0.1120 - val_custom_loss: 0.1511 - lr: 6.9834e-05
# Epoch 142/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1385 - mae: 0.0985 - custom_loss: 0.1333 - val_loss: 0.1560 - val_mae: 0.1115 - val_custom_loss: 0.1506 - lr: 6.9655e-05
# Epoch 143/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1383 - mae: 0.0984 - custom_loss: 0.1334 - val_loss: 0.1566 - val_mae: 0.1118 - val_custom_loss: 0.1512 - lr: 6.9476e-05
# Epoch 144/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1380 - mae: 0.0982 - custom_loss: 0.1328 - val_loss: 0.1556 - val_mae: 0.1112 - val_custom_loss: 0.1502 - lr: 6.9298e-05
# Epoch 145/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1379 - mae: 0.0981 - custom_loss: 0.1327 - val_loss: 0.1566 - val_mae: 0.1118 - val_custom_loss: 0.1512 - lr: 6.9121e-05
# Epoch 146/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1375 - mae: 0.0978 - custom_loss: 0.1323 - val_loss: 0.1553 - val_mae: 0.1108 - val_custom_loss: 0.1499 - lr: 6.8944e-05
# Epoch 147/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1371 - mae: 0.0976 - custom_loss: 0.1320 - val_loss: 0.1555 - val_mae: 0.1110 - val_custom_loss: 0.1502 - lr: 6.8767e-05
# Epoch 148/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1373 - mae: 0.0977 - custom_loss: 0.1318 - val_loss: 0.1548 - val_mae: 0.1106 - val_custom_loss: 0.1495 - lr: 6.8591e-05
# Epoch 149/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1368 - mae: 0.0972 - custom_loss: 0.1317 - val_loss: 0.1548 - val_mae: 0.1107 - val_custom_loss: 0.1495 - lr: 6.8416e-05
# Epoch 150/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1364 - mae: 0.0969 - custom_loss: 0.1309 - val_loss: 0.1550 - val_mae: 0.1106 - val_custom_loss: 0.1497 - lr: 6.8240e-05
# Epoch 151/300
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1364 - mae: 0.0970 - custom_loss: 0.1312 - val_loss: 0.1553 - val_mae: 0.1111 - val_custom_loss: 0.1501 - lr: 6.8065e-05
# Epoch 152/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1365 - mae: 0.0971 - custom_loss: 0.1316 - val_loss: 0.1551 - val_mae: 0.1110 - val_custom_loss: 0.1499 - lr: 6.7891e-05
# Epoch 153/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1362 - mae: 0.0969 - custom_loss: 0.1311 - val_loss: 0.1555 - val_mae: 0.1114 - val_custom_loss: 0.1503 - lr: 6.7717e-05
# Epoch 154/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1360 - mae: 0.0968 - custom_loss: 0.1308 - val_loss: 0.1544 - val_mae: 0.1103 - val_custom_loss: 0.1491 - lr: 6.7544e-05
# Epoch 155/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1355 - mae: 0.0963 - custom_loss: 0.1302 - val_loss: 0.1547 - val_mae: 0.1104 - val_custom_loss: 0.1495 - lr: 6.7371e-05
# Epoch 156/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1356 - mae: 0.0964 - custom_loss: 0.1308 - val_loss: 0.1550 - val_mae: 0.1106 - val_custom_loss: 0.1499 - lr: 6.7198e-05
# Epoch 157/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1355 - mae: 0.0963 - custom_loss: 0.1304 - val_loss: 0.1544 - val_mae: 0.1104 - val_custom_loss: 0.1493 - lr: 6.7026e-05
# Epoch 158/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1353 - mae: 0.0963 - custom_loss: 0.1299 - val_loss: 0.1555 - val_mae: 0.1111 - val_custom_loss: 0.1504 - lr: 6.6854e-05
# Epoch 159/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1352 - mae: 0.0962 - custom_loss: 0.1300 - val_loss: 0.1542 - val_mae: 0.1101 - val_custom_loss: 0.1490 - lr: 6.6683e-05
# Epoch 160/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1350 - mae: 0.0960 - custom_loss: 0.1302 - val_loss: 0.1545 - val_mae: 0.1106 - val_custom_loss: 0.1494 - lr: 6.6512e-05
# Epoch 161/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1346 - mae: 0.0957 - custom_loss: 0.1297 - val_loss: 0.1535 - val_mae: 0.1097 - val_custom_loss: 0.1484 - lr: 6.6342e-05
# Epoch 162/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1345 - mae: 0.0955 - custom_loss: 0.1296 - val_loss: 0.1537 - val_mae: 0.1098 - val_custom_loss: 0.1486 - lr: 6.6172e-05
# Epoch 163/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1342 - mae: 0.0955 - custom_loss: 0.1293 - val_loss: 0.1535 - val_mae: 0.1098 - val_custom_loss: 0.1485 - lr: 6.6003e-05
# Epoch 164/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1342 - mae: 0.0954 - custom_loss: 0.1292 - val_loss: 0.1534 - val_mae: 0.1094 - val_custom_loss: 0.1483 - lr: 6.5834e-05
# Epoch 165/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1337 - mae: 0.0950 - custom_loss: 0.1287 - val_loss: 0.1530 - val_mae: 0.1093 - val_custom_loss: 0.1480 - lr: 6.5665e-05
# Epoch 166/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1335 - mae: 0.0949 - custom_loss: 0.1287 - val_loss: 0.1532 - val_mae: 0.1096 - val_custom_loss: 0.1483 - lr: 6.5497e-05
# Epoch 167/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1336 - mae: 0.0949 - custom_loss: 0.1286 - val_loss: 0.1534 - val_mae: 0.1098 - val_custom_loss: 0.1485 - lr: 6.5329e-05
# Epoch 168/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1338 - mae: 0.0951 - custom_loss: 0.1289 - val_loss: 0.1537 - val_mae: 0.1099 - val_custom_loss: 0.1488 - lr: 6.5162e-05
# Epoch 169/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1334 - mae: 0.0949 - custom_loss: 0.1282 - val_loss: 0.1529 - val_mae: 0.1093 - val_custom_loss: 0.1480 - lr: 6.4995e-05
# Epoch 170/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1331 - mae: 0.0946 - custom_loss: 0.1285 - val_loss: 0.1531 - val_mae: 0.1095 - val_custom_loss: 0.1482 - lr: 6.4828e-05
# Epoch 171/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1329 - mae: 0.0945 - custom_loss: 0.1280 - val_loss: 0.1531 - val_mae: 0.1095 - val_custom_loss: 0.1482 - lr: 6.4662e-05
# Epoch 172/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1327 - mae: 0.0943 - custom_loss: 0.1277 - val_loss: 0.1524 - val_mae: 0.1089 - val_custom_loss: 0.1475 - lr: 6.4497e-05
# Epoch 173/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1325 - mae: 0.0942 - custom_loss: 0.1273 - val_loss: 0.1530 - val_mae: 0.1093 - val_custom_loss: 0.1481 - lr: 6.4331e-05
# Epoch 174/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1326 - mae: 0.0942 - custom_loss: 0.1277 - val_loss: 0.1528 - val_mae: 0.1092 - val_custom_loss: 0.1479 - lr: 6.4167e-05
# Epoch 175/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1323 - mae: 0.0940 - custom_loss: 0.1276 - val_loss: 0.1527 - val_mae: 0.1091 - val_custom_loss: 0.1478 - lr: 6.4002e-05
# Epoch 176/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1321 - mae: 0.0938 - custom_loss: 0.1272 - val_loss: 0.1523 - val_mae: 0.1091 - val_custom_loss: 0.1475 - lr: 6.3838e-05
# Epoch 177/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1319 - mae: 0.0937 - custom_loss: 0.1276 - val_loss: 0.1521 - val_mae: 0.1087 - val_custom_loss: 0.1473 - lr: 6.3675e-05
# Epoch 178/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1317 - mae: 0.0936 - custom_loss: 0.1268 - val_loss: 0.1526 - val_mae: 0.1090 - val_custom_loss: 0.1478 - lr: 6.3512e-05
# Epoch 179/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1314 - mae: 0.0933 - custom_loss: 0.1268 - val_loss: 0.1525 - val_mae: 0.1089 - val_custom_loss: 0.1477 - lr: 6.3349e-05
# Epoch 180/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1316 - mae: 0.0936 - custom_loss: 0.1269 - val_loss: 0.1522 - val_mae: 0.1088 - val_custom_loss: 0.1474 - lr: 6.3187e-05
# Epoch 181/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1312 - mae: 0.0932 - custom_loss: 0.1267 - val_loss: 0.1514 - val_mae: 0.1082 - val_custom_loss: 0.1467 - lr: 6.3025e-05
# Epoch 182/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1311 - mae: 0.0931 - custom_loss: 0.1264 - val_loss: 0.1520 - val_mae: 0.1086 - val_custom_loss: 0.1473 - lr: 6.2864e-05
# Epoch 183/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1310 - mae: 0.0931 - custom_loss: 0.1263 - val_loss: 0.1517 - val_mae: 0.1085 - val_custom_loss: 0.1470 - lr: 6.2702e-05
# Epoch 184/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1306 - mae: 0.0927 - custom_loss: 0.1265 - val_loss: 0.1515 - val_mae: 0.1083 - val_custom_loss: 0.1468 - lr: 6.2542e-05
# Epoch 185/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1304 - mae: 0.0926 - custom_loss: 0.1255 - val_loss: 0.1516 - val_mae: 0.1084 - val_custom_loss: 0.1469 - lr: 6.2382e-05
# Epoch 186/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1305 - mae: 0.0927 - custom_loss: 0.1258 - val_loss: 0.1516 - val_mae: 0.1085 - val_custom_loss: 0.1469 - lr: 6.2222e-05
# Epoch 187/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1305 - mae: 0.0927 - custom_loss: 0.1262 - val_loss: 0.1514 - val_mae: 0.1083 - val_custom_loss: 0.1467 - lr: 6.2063e-05
# Epoch 188/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1301 - mae: 0.0924 - custom_loss: 0.1253 - val_loss: 0.1516 - val_mae: 0.1085 - val_custom_loss: 0.1470 - lr: 6.1904e-05
# Epoch 189/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1299 - mae: 0.0922 - custom_loss: 0.1254 - val_loss: 0.1517 - val_mae: 0.1085 - val_custom_loss: 0.1471 - lr: 6.1745e-05
# Epoch 190/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1302 - mae: 0.0926 - custom_loss: 0.1256 - val_loss: 0.1522 - val_mae: 0.1088 - val_custom_loss: 0.1476 - lr: 6.1587e-05
# Epoch 191/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1299 - mae: 0.0923 - custom_loss: 0.1253 - val_loss: 0.1515 - val_mae: 0.1084 - val_custom_loss: 0.1469 - lr: 6.1429e-05
# Epoch 192/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1297 - mae: 0.0922 - custom_loss: 0.1252 - val_loss: 0.1508 - val_mae: 0.1077 - val_custom_loss: 0.1462 - lr: 6.1272e-05
# Epoch 193/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1294 - mae: 0.0919 - custom_loss: 0.1246 - val_loss: 0.1511 - val_mae: 0.1081 - val_custom_loss: 0.1465 - lr: 6.1115e-05
# Epoch 194/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1291 - mae: 0.0918 - custom_loss: 0.1246 - val_loss: 0.1511 - val_mae: 0.1082 - val_custom_loss: 0.1465 - lr: 6.0958e-05
# Epoch 195/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1292 - mae: 0.0919 - custom_loss: 0.1247 - val_loss: 0.1512 - val_mae: 0.1082 - val_custom_loss: 0.1466 - lr: 6.0802e-05
# Epoch 196/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1288 - mae: 0.0914 - custom_loss: 0.1240 - val_loss: 0.1505 - val_mae: 0.1076 - val_custom_loss: 0.1459 - lr: 6.0646e-05
# Epoch 197/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1288 - mae: 0.0914 - custom_loss: 0.1241 - val_loss: 0.1502 - val_mae: 0.1074 - val_custom_loss: 0.1457 - lr: 6.0491e-05
# Epoch 198/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1288 - mae: 0.0915 - custom_loss: 0.1244 - val_loss: 0.1507 - val_mae: 0.1080 - val_custom_loss: 0.1462 - lr: 6.0336e-05
# Epoch 199/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1288 - mae: 0.0915 - custom_loss: 0.1240 - val_loss: 0.1505 - val_mae: 0.1075 - val_custom_loss: 0.1460 - lr: 6.0182e-05
# Epoch 200/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1284 - mae: 0.0912 - custom_loss: 0.1237 - val_loss: 0.1501 - val_mae: 0.1073 - val_custom_loss: 0.1456 - lr: 6.0027e-05
# Epoch 201/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1284 - mae: 0.0911 - custom_loss: 0.1238 - val_loss: 0.1506 - val_mae: 0.1076 - val_custom_loss: 0.1461 - lr: 5.9874e-05
# Epoch 202/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1281 - mae: 0.0910 - custom_loss: 0.1234 - val_loss: 0.1503 - val_mae: 0.1075 - val_custom_loss: 0.1458 - lr: 5.9720e-05
# Epoch 203/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1280 - mae: 0.0909 - custom_loss: 0.1236 - val_loss: 0.1496 - val_mae: 0.1069 - val_custom_loss: 0.1452 - lr: 5.9567e-05
# Epoch 204/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1279 - mae: 0.0908 - custom_loss: 0.1236 - val_loss: 0.1503 - val_mae: 0.1074 - val_custom_loss: 0.1458 - lr: 5.9415e-05
# Epoch 205/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1278 - mae: 0.0907 - custom_loss: 0.1233 - val_loss: 0.1500 - val_mae: 0.1072 - val_custom_loss: 0.1455 - lr: 5.9263e-05
# Epoch 206/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1278 - mae: 0.0908 - custom_loss: 0.1231 - val_loss: 0.1501 - val_mae: 0.1073 - val_custom_loss: 0.1457 - lr: 5.9111e-05
# Epoch 207/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1279 - mae: 0.0908 - custom_loss: 0.1237 - val_loss: 0.1497 - val_mae: 0.1071 - val_custom_loss: 0.1453 - lr: 5.8959e-05
# Epoch 208/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1274 - mae: 0.0905 - custom_loss: 0.1229 - val_loss: 0.1500 - val_mae: 0.1073 - val_custom_loss: 0.1456 - lr: 5.8808e-05
# Epoch 209/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1275 - mae: 0.0905 - custom_loss: 0.1238 - val_loss: 0.1502 - val_mae: 0.1074 - val_custom_loss: 0.1458 - lr: 5.8658e-05
# Epoch 210/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1277 - mae: 0.0907 - custom_loss: 0.1235 - val_loss: 0.1505 - val_mae: 0.1078 - val_custom_loss: 0.1461 - lr: 5.8508e-05
# Epoch 211/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1271 - mae: 0.0903 - custom_loss: 0.1226 - val_loss: 0.1497 - val_mae: 0.1070 - val_custom_loss: 0.1453 - lr: 5.8358e-05
# Epoch 212/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1268 - mae: 0.0899 - custom_loss: 0.1223 - val_loss: 0.1494 - val_mae: 0.1067 - val_custom_loss: 0.1450 - lr: 5.8208e-05
# Epoch 213/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1269 - mae: 0.0900 - custom_loss: 0.1224 - val_loss: 0.1496 - val_mae: 0.1070 - val_custom_loss: 0.1452 - lr: 5.8059e-05
# Epoch 214/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1267 - mae: 0.0899 - custom_loss: 0.1228 - val_loss: 0.1497 - val_mae: 0.1069 - val_custom_loss: 0.1453 - lr: 5.7910e-05
# Epoch 215/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1267 - mae: 0.0899 - custom_loss: 0.1224 - val_loss: 0.1495 - val_mae: 0.1069 - val_custom_loss: 0.1451 - lr: 5.7762e-05
# Epoch 216/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1265 - mae: 0.0898 - custom_loss: 0.1220 - val_loss: 0.1496 - val_mae: 0.1069 - val_custom_loss: 0.1452 - lr: 5.7614e-05
# Epoch 217/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1263 - mae: 0.0896 - custom_loss: 0.1226 - val_loss: 0.1491 - val_mae: 0.1065 - val_custom_loss: 0.1447 - lr: 5.7467e-05
# Epoch 218/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1260 - mae: 0.0894 - custom_loss: 0.1221 - val_loss: 0.1494 - val_mae: 0.1068 - val_custom_loss: 0.1450 - lr: 5.7319e-05
# Epoch 219/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1261 - mae: 0.0895 - custom_loss: 0.1219 - val_loss: 0.1493 - val_mae: 0.1067 - val_custom_loss: 0.1450 - lr: 5.7173e-05
# Epoch 220/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1259 - mae: 0.0893 - custom_loss: 0.1217 - val_loss: 0.1490 - val_mae: 0.1066 - val_custom_loss: 0.1447 - lr: 5.7026e-05
# Epoch 221/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1258 - mae: 0.0893 - custom_loss: 0.1217 - val_loss: 0.1492 - val_mae: 0.1066 - val_custom_loss: 0.1449 - lr: 5.6880e-05
# Epoch 222/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1259 - mae: 0.0894 - custom_loss: 0.1219 - val_loss: 0.1491 - val_mae: 0.1066 - val_custom_loss: 0.1448 - lr: 5.6734e-05
# Epoch 223/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1257 - mae: 0.0892 - custom_loss: 0.1216 - val_loss: 0.1487 - val_mae: 0.1064 - val_custom_loss: 0.1444 - lr: 5.6589e-05
# Epoch 224/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1253 - mae: 0.0889 - custom_loss: 0.1214 - val_loss: 0.1486 - val_mae: 0.1063 - val_custom_loss: 0.1444 - lr: 5.6444e-05
# Epoch 225/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1251 - mae: 0.0887 - custom_loss: 0.1209 - val_loss: 0.1487 - val_mae: 0.1062 - val_custom_loss: 0.1444 - lr: 5.6299e-05
# Epoch 226/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1252 - mae: 0.0888 - custom_loss: 0.1209 - val_loss: 0.1490 - val_mae: 0.1065 - val_custom_loss: 0.1447 - lr: 5.6155e-05
# Epoch 227/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1251 - mae: 0.0887 - custom_loss: 0.1206 - val_loss: 0.1488 - val_mae: 0.1064 - val_custom_loss: 0.1445 - lr: 5.6011e-05
# Epoch 228/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1251 - mae: 0.0888 - custom_loss: 0.1209 - val_loss: 0.1489 - val_mae: 0.1065 - val_custom_loss: 0.1446 - lr: 5.5868e-05
# Epoch 229/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1247 - mae: 0.0885 - custom_loss: 0.1205 - val_loss: 0.1493 - val_mae: 0.1069 - val_custom_loss: 0.1451 - lr: 5.5725e-05
# Epoch 230/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1247 - mae: 0.0885 - custom_loss: 0.1206 - val_loss: 0.1483 - val_mae: 0.1060 - val_custom_loss: 0.1441 - lr: 5.5582e-05
# Epoch 231/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1249 - mae: 0.0886 - custom_loss: 0.1208 - val_loss: 0.1486 - val_mae: 0.1065 - val_custom_loss: 0.1444 - lr: 5.5440e-05
# Epoch 232/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1244 - mae: 0.0883 - custom_loss: 0.1204 - val_loss: 0.1485 - val_mae: 0.1062 - val_custom_loss: 0.1443 - lr: 5.5298e-05
# Epoch 233/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1243 - mae: 0.0881 - custom_loss: 0.1202 - val_loss: 0.1483 - val_mae: 0.1061 - val_custom_loss: 0.1441 - lr: 5.5156e-05
# Epoch 234/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1245 - mae: 0.0884 - custom_loss: 0.1205 - val_loss: 0.1482 - val_mae: 0.1060 - val_custom_loss: 0.1440 - lr: 5.5015e-05
# Epoch 235/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1242 - mae: 0.0881 - custom_loss: 0.1199 - val_loss: 0.1485 - val_mae: 0.1062 - val_custom_loss: 0.1443 - lr: 5.4874e-05
# Epoch 236/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1240 - mae: 0.0879 - custom_loss: 0.1197 - val_loss: 0.1482 - val_mae: 0.1059 - val_custom_loss: 0.1440 - lr: 5.4733e-05
# Epoch 237/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1238 - mae: 0.0877 - custom_loss: 0.1194 - val_loss: 0.1479 - val_mae: 0.1059 - val_custom_loss: 0.1438 - lr: 5.4593e-05
# Epoch 238/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1237 - mae: 0.0877 - custom_loss: 0.1193 - val_loss: 0.1480 - val_mae: 0.1058 - val_custom_loss: 0.1438 - lr: 5.4453e-05
# Epoch 239/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1236 - mae: 0.0877 - custom_loss: 0.1198 - val_loss: 0.1482 - val_mae: 0.1061 - val_custom_loss: 0.1441 - lr: 5.4314e-05
# Epoch 240/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1236 - mae: 0.0877 - custom_loss: 0.1194 - val_loss: 0.1480 - val_mae: 0.1058 - val_custom_loss: 0.1439 - lr: 5.4175e-05
# Epoch 241/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1233 - mae: 0.0874 - custom_loss: 0.1195 - val_loss: 0.1481 - val_mae: 0.1058 - val_custom_loss: 0.1439 - lr: 5.4036e-05
# Epoch 242/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1231 - mae: 0.0872 - custom_loss: 0.1192 - val_loss: 0.1479 - val_mae: 0.1057 - val_custom_loss: 0.1437 - lr: 5.3898e-05
# Epoch 243/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1230 - mae: 0.0872 - custom_loss: 0.1190 - val_loss: 0.1481 - val_mae: 0.1059 - val_custom_loss: 0.1440 - lr: 5.3760e-05
# Epoch 244/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1229 - mae: 0.0871 - custom_loss: 0.1188 - val_loss: 0.1481 - val_mae: 0.1058 - val_custom_loss: 0.1440 - lr: 5.3622e-05
# Epoch 245/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1228 - mae: 0.0870 - custom_loss: 0.1188 - val_loss: 0.1479 - val_mae: 0.1058 - val_custom_loss: 0.1438 - lr: 5.3485e-05
# Epoch 246/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1229 - mae: 0.0872 - custom_loss: 0.1189 - val_loss: 0.1483 - val_mae: 0.1060 - val_custom_loss: 0.1442 - lr: 5.3348e-05
# Epoch 247/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1231 - mae: 0.0873 - custom_loss: 0.1192 - val_loss: 0.1478 - val_mae: 0.1057 - val_custom_loss: 0.1437 - lr: 5.3211e-05
# Epoch 248/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1228 - mae: 0.0871 - custom_loss: 0.1191 - val_loss: 0.1480 - val_mae: 0.1058 - val_custom_loss: 0.1439 - lr: 5.3075e-05
# Epoch 249/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1225 - mae: 0.0868 - custom_loss: 0.1181 - val_loss: 0.1477 - val_mae: 0.1055 - val_custom_loss: 0.1436 - lr: 5.2939e-05
# Epoch 250/300
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1223 - mae: 0.0866 - custom_loss: 0.1182 - val_loss: 0.1478 - val_mae: 0.1057 - val_custom_loss: 0.1437 - lr: 5.2803e-05
# Epoch 251/300
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1225 - mae: 0.0868 - custom_loss: 0.1185 - val_loss: 0.1476 - val_mae: 0.1055 - val_custom_loss: 0.1435 - lr: 5.2668e-05
# Epoch 252/300
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1221 - mae: 0.0866 - custom_loss: 0.1179 - val_loss: 0.1471 - val_mae: 0.1052 - val_custom_loss: 0.1431 - lr: 5.2533e-05
# Epoch 253/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1219 - mae: 0.0863 - custom_loss: 0.1179 - val_loss: 0.1474 - val_mae: 0.1054 - val_custom_loss: 0.1434 - lr: 5.2398e-05
# Epoch 254/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1220 - mae: 0.0864 - custom_loss: 0.1182 - val_loss: 0.1481 - val_mae: 0.1059 - val_custom_loss: 0.1441 - lr: 5.2264e-05
# Epoch 255/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1221 - mae: 0.0866 - custom_loss: 0.1180 - val_loss: 0.1474 - val_mae: 0.1054 - val_custom_loss: 0.1433 - lr: 5.2130e-05
# Epoch 256/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1218 - mae: 0.0863 - custom_loss: 0.1176 - val_loss: 0.1470 - val_mae: 0.1051 - val_custom_loss: 0.1430 - lr: 5.1997e-05
# Epoch 257/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1218 - mae: 0.0862 - custom_loss: 0.1179 - val_loss: 0.1470 - val_mae: 0.1050 - val_custom_loss: 0.1429 - lr: 5.1864e-05
# Epoch 258/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1215 - mae: 0.0861 - custom_loss: 0.1179 - val_loss: 0.1472 - val_mae: 0.1053 - val_custom_loss: 0.1432 - lr: 5.1731e-05
# Epoch 259/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1214 - mae: 0.0859 - custom_loss: 0.1179 - val_loss: 0.1470 - val_mae: 0.1051 - val_custom_loss: 0.1430 - lr: 5.1598e-05
# Epoch 260/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1213 - mae: 0.0859 - custom_loss: 0.1175 - val_loss: 0.1469 - val_mae: 0.1050 - val_custom_loss: 0.1429 - lr: 5.1466e-05
# Epoch 261/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1213 - mae: 0.0860 - custom_loss: 0.1170 - val_loss: 0.1473 - val_mae: 0.1055 - val_custom_loss: 0.1433 - lr: 5.1334e-05
# Epoch 262/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1215 - mae: 0.0861 - custom_loss: 0.1182 - val_loss: 0.1473 - val_mae: 0.1053 - val_custom_loss: 0.1433 - lr: 5.1203e-05
# Epoch 263/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1211 - mae: 0.0859 - custom_loss: 0.1176 - val_loss: 0.1478 - val_mae: 0.1056 - val_custom_loss: 0.1438 - lr: 5.1072e-05
# Epoch 264/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1215 - mae: 0.0861 - custom_loss: 0.1180 - val_loss: 0.1476 - val_mae: 0.1056 - val_custom_loss: 0.1436 - lr: 5.0941e-05
# Epoch 265/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1212 - mae: 0.0859 - custom_loss: 0.1172 - val_loss: 0.1466 - val_mae: 0.1048 - val_custom_loss: 0.1426 - lr: 5.0810e-05
# Epoch 266/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1208 - mae: 0.0855 - custom_loss: 0.1167 - val_loss: 0.1470 - val_mae: 0.1051 - val_custom_loss: 0.1430 - lr: 5.0680e-05
# Epoch 267/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1207 - mae: 0.0855 - custom_loss: 0.1167 - val_loss: 0.1468 - val_mae: 0.1049 - val_custom_loss: 0.1429 - lr: 5.0550e-05
# Epoch 268/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1207 - mae: 0.0854 - custom_loss: 0.1168 - val_loss: 0.1469 - val_mae: 0.1050 - val_custom_loss: 0.1429 - lr: 5.0421e-05
# Epoch 269/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1205 - mae: 0.0853 - custom_loss: 0.1167 - val_loss: 0.1470 - val_mae: 0.1051 - val_custom_loss: 0.1431 - lr: 5.0292e-05
# Epoch 270/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1205 - mae: 0.0854 - custom_loss: 0.1166 - val_loss: 0.1466 - val_mae: 0.1047 - val_custom_loss: 0.1426 - lr: 5.0163e-05
# Epoch 271/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1203 - mae: 0.0852 - custom_loss: 0.1164 - val_loss: 0.1468 - val_mae: 0.1050 - val_custom_loss: 0.1429 - lr: 5.0034e-05
# Epoch 272/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1202 - mae: 0.0851 - custom_loss: 0.1166 - val_loss: 0.1463 - val_mae: 0.1045 - val_custom_loss: 0.1424 - lr: 4.9906e-05
# Epoch 273/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1202 - mae: 0.0851 - custom_loss: 0.1162 - val_loss: 0.1463 - val_mae: 0.1045 - val_custom_loss: 0.1423 - lr: 4.9778e-05
# Epoch 274/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1200 - mae: 0.0850 - custom_loss: 0.1161 - val_loss: 0.1461 - val_mae: 0.1044 - val_custom_loss: 0.1421 - lr: 4.9651e-05
# Epoch 275/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1199 - mae: 0.0849 - custom_loss: 0.1161 - val_loss: 0.1460 - val_mae: 0.1044 - val_custom_loss: 0.1421 - lr: 4.9524e-05
# Epoch 276/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1198 - mae: 0.0848 - custom_loss: 0.1160 - val_loss: 0.1461 - val_mae: 0.1046 - val_custom_loss: 0.1422 - lr: 4.9397e-05
# Epoch 277/300
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1196 - mae: 0.0846 - custom_loss: 0.1154 - val_loss: 0.1463 - val_mae: 0.1045 - val_custom_loss: 0.1423 - lr: 4.9270e-05
# Epoch 278/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1197 - mae: 0.0847 - custom_loss: 0.1158 - val_loss: 0.1467 - val_mae: 0.1050 - val_custom_loss: 0.1428 - lr: 4.9144e-05
# Epoch 279/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1196 - mae: 0.0847 - custom_loss: 0.1158 - val_loss: 0.1466 - val_mae: 0.1048 - val_custom_loss: 0.1427 - lr: 4.9018e-05
# Epoch 280/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1195 - mae: 0.0846 - custom_loss: 0.1156 - val_loss: 0.1466 - val_mae: 0.1048 - val_custom_loss: 0.1427 - lr: 4.8893e-05
# Epoch 281/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1193 - mae: 0.0844 - custom_loss: 0.1155 - val_loss: 0.1462 - val_mae: 0.1045 - val_custom_loss: 0.1423 - lr: 4.8767e-05
# Epoch 282/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1191 - mae: 0.0843 - custom_loss: 0.1157 - val_loss: 0.1459 - val_mae: 0.1042 - val_custom_loss: 0.1420 - lr: 4.8643e-05
# Epoch 283/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1192 - mae: 0.0844 - custom_loss: 0.1154 - val_loss: 0.1462 - val_mae: 0.1046 - val_custom_loss: 0.1424 - lr: 4.8518e-05
# Epoch 284/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1192 - mae: 0.0843 - custom_loss: 0.1153 - val_loss: 0.1464 - val_mae: 0.1046 - val_custom_loss: 0.1425 - lr: 4.8394e-05
# Epoch 285/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1192 - mae: 0.0844 - custom_loss: 0.1157 - val_loss: 0.1456 - val_mae: 0.1041 - val_custom_loss: 0.1417 - lr: 4.8270e-05
# Epoch 286/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1187 - mae: 0.0840 - custom_loss: 0.1150 - val_loss: 0.1457 - val_mae: 0.1042 - val_custom_loss: 0.1419 - lr: 4.8146e-05
# Epoch 287/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1189 - mae: 0.0841 - custom_loss: 0.1150 - val_loss: 0.1461 - val_mae: 0.1046 - val_custom_loss: 0.1422 - lr: 4.8023e-05
# Epoch 288/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1188 - mae: 0.0841 - custom_loss: 0.1151 - val_loss: 0.1460 - val_mae: 0.1044 - val_custom_loss: 0.1422 - lr: 4.7900e-05
# Epoch 289/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1188 - mae: 0.0841 - custom_loss: 0.1151 - val_loss: 0.1465 - val_mae: 0.1048 - val_custom_loss: 0.1426 - lr: 4.7777e-05
# Epoch 290/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1186 - mae: 0.0839 - custom_loss: 0.1152 - val_loss: 0.1457 - val_mae: 0.1042 - val_custom_loss: 0.1419 - lr: 4.7655e-05
# Epoch 291/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1186 - mae: 0.0840 - custom_loss: 0.1154 - val_loss: 0.1457 - val_mae: 0.1042 - val_custom_loss: 0.1419 - lr: 4.7533e-05
# Epoch 292/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1184 - mae: 0.0838 - custom_loss: 0.1153 - val_loss: 0.1456 - val_mae: 0.1042 - val_custom_loss: 0.1418 - lr: 4.7411e-05
# Epoch 293/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1185 - mae: 0.0839 - custom_loss: 0.1145 - val_loss: 0.1455 - val_mae: 0.1041 - val_custom_loss: 0.1416 - lr: 4.7289e-05
# Epoch 294/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1184 - mae: 0.0838 - custom_loss: 0.1144 - val_loss: 0.1458 - val_mae: 0.1042 - val_custom_loss: 0.1420 - lr: 4.7168e-05
# Epoch 295/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1181 - mae: 0.0835 - custom_loss: 0.1145 - val_loss: 0.1451 - val_mae: 0.1038 - val_custom_loss: 0.1413 - lr: 4.7048e-05
# Epoch 296/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1179 - mae: 0.0834 - custom_loss: 0.1139 - val_loss: 0.1450 - val_mae: 0.1036 - val_custom_loss: 0.1412 - lr: 4.6927e-05
# Epoch 297/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1178 - mae: 0.0833 - custom_loss: 0.1140 - val_loss: 0.1453 - val_mae: 0.1039 - val_custom_loss: 0.1415 - lr: 4.6807e-05
# Epoch 298/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1178 - mae: 0.0833 - custom_loss: 0.1141 - val_loss: 0.1456 - val_mae: 0.1042 - val_custom_loss: 0.1418 - lr: 4.6687e-05
# Epoch 299/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1178 - mae: 0.0834 - custom_loss: 0.1139 - val_loss: 0.1457 - val_mae: 0.1041 - val_custom_loss: 0.1419 - lr: 4.6567e-05
# Epoch 300/300
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1177 - mae: 0.0832 - custom_loss: 0.1145 - val_loss: 0.1456 - val_mae: 0.1041 - val_custom_loss: 0.1418 - lr: 4.6448e-05

# %%
np.shape(y_train_encoded)
# Out:
# (886, 196, 12)

# %%
test_prediction = model.predict([x_test_img,x_test_geopara])
# Out:
# 10/10 [==============================] - 0s 1ms/step

# %%
np.shape(test_prediction)
# Out:
# (296, 196, 12)

# %%
mae = hist.history['mae']
val_mae = hist.history['val_mae']
epochs = range(1, len(mae) + 1)

plt.plot(epochs, mae, '-', label='Training mae')
plt.plot(epochs, val_mae, ':', label='Validation mae')
plt.title('Training and Validation mae')
plt.xlabel('Epoch')
plt.ylabel('mae')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %%
from sklearn.metrics import r2_score
r2_result = []
for z in range(fmax):
    r2 = 0
    for i in range(12):
        temp = r2_score(y_test_encoded[:,z,i], test_prediction[:,z,i], force_finite=False)
        r2 = r2+temp
    r2_result.append(r2/12)
plt.plot(range(fmax),r2_result)

# %%
np.mean(r2_result)
# Out:
# 0.7856920307127679

# %%
mae_all = np.zeros((fmax,12))
mae_mean = np.zeros(fmax)
for z in range(fmax):
    for i in range(12):
        mae_all[z][i] = np.mean(abs(test_prediction[:,z,i]-y_test_encoded[:,z,i]))*0.5*srange[z,i]
    mae_mean[z] = np.mean(mae_all[z][:])

# %%
freq = range(fmax)
for i in range(12):
    if (i%2==0):
        plt.plot(freq,mae_all[:,i])
plt.legend(["Re[S11]","Re[S12]","Re[S13]","Re[S14]","Re[S33]","Re[S34]"])
plt.xlabel('Frequency/GHz')
plt.ylabel('S-parameter mae')
# Out:
# Text(0, 0.5, 'S-parameter mae')

# %%
mae_all = np.zeros((fmax,12))
mae_mean = np.zeros(fmax)
for z in range(fmax):
    for i in range(12):
        mae_all[z][i] = np.mean(abs(test_prediction[:,z,i]-y_test_encoded[:,z,i]))*0.5*srange[z,i]
    mae_mean[z] = np.mean(mae_all[z][:])

# %%
plt.plot(range(fmax),mae_mean)
plt.xlabel('Frequency/GHz')
plt.ylabel('Average S-parameter mae')
# Out:
# Text(0, 0.5, 'Average S-parameter mae')

# %%
freq = range(fmax)
for i in range(12):
    if (i%2==1):
        plt.plot(freq,mae_all[:,i])
plt.legend(["Im[S11]","Im[S12]","Im[S13]","Im[S14]","Im[S33]","Im[S34]"])        
plt.xlabel('Frequency/GHz')
plt.ylabel('S-parameter mae')
# Out:
# Text(0, 0.5, 'S-parameter mae')

# %%
np.mean(mae_mean)
# Out:
# 0.06513561161377217

# %%
def R_squared(y, y_pred):
  residual = tf.reduce_sum(tf.square(tf.subtract(y, y_pred)))
  total = tf.reduce_sum(tf.square(tf.subtract(y, tf.reduce_mean(y))))
  r2 = tf.subtract(1.0, tf.divide(residual, total))
  return r2
print(R_squared(y_test_encoded,test_prediction))
# Out:
# tf.Tensor(0.8656714552058521, shape=(), dtype=float64)

# %%
model.save('./models/air/mturn_196G_MLP.h5')
# Out:
# /home/hh68/.conda/envs/tensorflow/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
