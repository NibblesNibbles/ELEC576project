# %%
import os
import numpy as np
from keras.preprocessing import image
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
import pandas as pd
import skrf as rf

#define the targeted max frequency
fmax = 196
#define function for loading images and s-parameters
#"path" is the path for images of transformer layout
#"label" is the path for labels. In this case, labels are S-parameter associated with each images 
def load_images_from_path(path, label,length):
    images = []
    labels = []
    
    for i in range(length):
        #load images
        img = image.load_img(path+str(i)+'.png', target_size=(500, 500, 3))
        images.append(image.img_to_array(img)[138:362,138:362,:])#trim the ground margin

        #load S-parameters
        #According to symmerty, only S11,S12,S13,S14,S33,S34 are considered
        #Each S-parameter has real and imaginary parts, and hence 12 real values in total.
        results = []
        datafile = label+str(i)+".s4p"
        spt = rf.Network(datafile)
        for i in range(fmax+1):
            results.append([spt.s[i][0][0].real,spt.s[i][0][0].imag,
                            spt.s[i][0][1].real,spt.s[i][0][1].imag,
                            spt.s[i][0][2].real,spt.s[i][0][2].imag,
                            spt.s[i][0][3].real,spt.s[i][0][3].imag,
                            spt.s[i][2][2].real,spt.s[i][2][2].imag,
                            spt.s[i][2][3].real,spt.s[i][2][3].imag])      
        labels.append(results) 
    return images, labels

def show_images(images):
    fig, axes = plt.subplots(1, 8, figsize=(20, 20), subplot_kw={'xticks': [], 'yticks': []})

    for i, ax in enumerate(axes.flat):
        ax.imshow(images[i] / 255)
# Out:
# 2024-12-03 04:00:09.416718: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#load data
#geometrical parameters stored in log.txt
#order of geopara (radiusA,radiusB,turnsA,turnsB,openA,openB,outA,outB,extA,extB,ratio,outbound)
logfile = open("/rdf/shared/design_automation/Data/2409/log.txt","r")
listall = list(map(lambda item: list(map(lambda jtem: eval(jtem.strip()), item[1:-1].split(','))), logfile.read().strip().split('\n')))
tabular_data = np.array(listall)

#load images and s-parameters
length = 4100
images, labels = load_images_from_path('/rdf/shared/design_automation/Data/2409/PNG/', '/rdf/shared/design_automation/Data/2409/SPData/',length)
show_images(images)
geoparas = []
images11 = []
labels11 = []

for kk in range(length):
    #select 1 turn and 1 turn transformers
   if((tabular_data[kk,2] !=1) or (tabular_data[kk,3]!=1)):
       #geoparas only includes the variable parameters in our designs. 
       #Constants at this design stages are excluded 
        geoparas.append(tabular_data[kk,(0,1,2,3,4,5,4,5,6,7,12,13)])
        images11.append(images[kk])
        labels11.append(labels[kk])
print(np.shape(geoparas))
# Out:
# (1923, 12)

# %%
#load data from the second folder
#geometrical parameters stored in log.txt
#order of geopara (radiusA,radiusB,turnsA,turnsB,openA,openB,outA,outB,extA,extB,ratio,outbound)
logfile = open("/rdf/shared/design_automation/Data/2409_2/log.txt","r")
listall = list(map(lambda item: list(map(lambda jtem: eval(jtem.strip()), item[1:-1].split(','))), logfile.read().strip().split('\n')))
tabular_data = np.array(listall)

#load images and s-parameters
#length = len(listall)-3
length = 2500
images, labels = load_images_from_path('/rdf/shared/design_automation/Data/2409_2/PNG/', '/rdf/shared/design_automation/Data/2409_2/SPData/',length)


for kk in range(length):
    #select 1 turn and 1 turn transformers
   if((tabular_data[kk,2] !=1) or (tabular_data[kk,3]!=1)):
       #geoparas only includes the variable parameters in our designs. 
       #Constants at this design stages are excluded 
        geoparas.append(tabular_data[kk,(0,1,2,3,4,5,4,5,6,7,12,13)])
        images11.append(images[kk])
        labels11.append(labels[kk])
print(np.shape(geoparas))
# Out:
# (3949, 12)

# %%
#normalize geometrical inputs
geoparas_temp = np.array(geoparas)
geoparas = np.zeros(np.shape(geoparas_temp))
for i in range(len(geoparas)):
    for j in range(12):
        geoparas[i,j]= (geoparas_temp[i,j]-np.mean(geoparas_temp[:,j]))/np.std(geoparas_temp[:,j])

# %%
#construct the datasets
class item:
  def __init__(self, image,geopara,label ):
    self.image = image
    self.geopara = geopara
    self.label = label

data = []
for i in range(len(images11)):
    data.append(item(images11[i],geoparas[i],labels11[i]))

np.random.shuffle(data)

# %%
#define the split length for training, validation and test datasets
length = len(images11)
split1 = int(0.6*length)
split2 = int(0.8*length)
data_train = data[0:split1]
data_valid = data[split1:split2]
data_test = data[split2:]

# %%
#Separate the training, validation and test datasets 
train_images = []
train_labels = []
train_geoparas = []
valid_images = []
valid_labels = []
valid_geoparas = []
test_images = []
test_labels = []
test_geoparas = []


#The targeted frequency span up to fmax, with 1GHz step
s_max = np.zeros((fmax,12))
s_min = np.zeros((fmax,12))
srange = np.zeros((fmax,12))


for i in range(len(data_train)):
    train_images.append(data_train[i].image)
    train_geoparas.append(data_train[i].geopara)
    train_labels.append(data_train[i].label)
x_train_img = np.array(train_images) / 255
x_train_geopara = np.array(train_geoparas)
y_train_encoded = np.array(train_labels)[:,1:fmax+1,:]


for i in range(len(data_valid)):
    valid_images.append(data_valid[i].image)
    valid_geoparas.append(data_valid[i].geopara)
    valid_labels.append(data_valid[i].label)
x_valid_img = np.array(valid_images) / 255
x_valid_geopara = np.array(valid_geoparas)
y_valid_encoded = np.array(valid_labels)[:,1:fmax+1,:]


for i in range(len(data_test)):
    test_images.append(data_test[i].image)
    test_geoparas.append(data_test[i].geopara)
    test_labels.append(data_test[i].label)
x_test_img = np.array(test_images) / 255
x_test_geopara = np.array(test_geoparas)
y_test_encoded = np.array(test_labels)[:,1:fmax+1,:]

#normalize the s-parameters for each frequency point
for z in range(fmax):
    for i in range(12):
        s_max[z,i] = max(max(y_train_encoded[:,z,i]),max(y_valid_encoded[:,z,i]),max(y_test_encoded[:,z,i]))
        s_min[z,i] = min(min(y_train_encoded[:,z,i]),min(y_valid_encoded[:,z,i]),min(y_test_encoded[:,z,i]))
        srange[z,i] = s_max[z,i]-s_min[z,i]
    
    for i in range(12):
        y_train_encoded[:,z,i] = 2*(y_train_encoded[:,z,i]-s_min[z,i])/srange[z,i]-1

    for i in range(12):
        y_valid_encoded[:,z,i] = 2*(y_valid_encoded[:,z,i]-s_min[z,i])/srange[z,i]-1
    
    for i in range(12):
        y_test_encoded[:,z,i] = 2*(y_test_encoded[:,z,i]-s_min[z,i])/srange[z,i]-1

# %%
def custom_loss(y_true, y_pred):
    Lf = tf.math.sqrt(tf.reduce_mean(tf.square(y_true - y_pred),axis=1))
    return (tf.reduce_mean(Lf))

# %%
from keras import Sequential, Input, Model, regularizers
from keras.layers import Conv2D, MaxPooling2D,Dropout, Reshape, BatchNormalization,Conv1DTranspose,Conv1D
from keras.layers import Flatten, Dense, Concatenate
learning_rate = 1e-4
n_unet = 8

models = []

inp1 = Input((224,224,3),)
'''
model1 = (Conv2D(n_unet,(3,3),padding='same', activation='relu', input_shape=(224, 224, 3), kernel_regularizer=regularizers.l2(0.01)))(inp1)
model1 = (MaxPooling2D(2, 2))(model1)
model1 = (Conv2D(n_unet*2, (3, 3), padding='same',activation='relu'))(model1)

model1 = (MaxPooling2D(2, 2))(model1)
#model1 = BatchNormalization()(model1)
model1 = (Conv2D(n_unet*2, (3, 3),  padding='same',activation='relu'))(model1)

model1 = (MaxPooling2D(2, 2))(model1)
#model1 = BatchNormalization()(model1)
model1 = (Conv2D(n_unet*4, (3, 3), padding='same', activation='relu'))(model1)

layer1 = (MaxPooling2D(2, 2))(model1)
#model1 = Dropout(0.3)(model1)
#model1 = BatchNormalization()(model1)
layer2 = (Conv2D(n_unet*8, (3, 3),padding='same', activation='relu'))(layer1)
layer2 = (MaxPooling2D(2, 2))(layer2)

layer3 = (Conv2D(n_unet*16, (3, 3),padding='same', activation='relu'))(layer2)
layer3 = (MaxPooling2D(2, 2))(layer3)

layer4 = (Conv2D(n_unet*32, (3, 3),padding='same', activation='relu'))(layer3)
layer4 = (MaxPooling2D(2, 2))(layer4)


#backward
layer4 = Reshape((1,n_unet*32))(layer4)
layer4 = (Conv1DTranspose(n_unet*16,9,1, activation='relu'))(layer4)

layer3 = Reshape((9,n_unet*16))(layer3)
layer3 = Concatenate()([layer3,layer4])
layer3 = (Conv1D(n_unet*16,3,padding='same', activation='relu'))(layer3)
layer3 = (Conv1DTranspose(n_unet*8,9,5, activation='relu'))(layer3)


layer2 = Reshape((49,n_unet*8))(layer2)
layer2 = Concatenate()([layer2,layer3])
layer2 = (Conv1D(n_unet*8,3,padding='same', activation='relu'))(layer2)
layer2 = (Conv1DTranspose(n_unet*4,3,4, activation='relu'))(layer2)

layer1 = Reshape((196,n_unet*4))(layer1)
layer1 = Concatenate()([layer1,layer2])
layer1 = (Conv1D(n_unet*4,3,padding='same', activation='relu'))(layer2)
model1 = Flatten()(layer1)
models.append(model1)
'''
inp2 = Input(12,)

model2=(Dense(512,activation='relu',input_shape = (10,),kernel_regularizer=regularizers.l2(0.010)))(inp2)
model2=(Dense(512,activation='relu'))(model2)
model2=(Dense(512,activation='relu'))(model2)
model2=(Dense(512,activation='relu'))(model2)
model2=(Dense(512,activation='relu'))(model2)
models.append(model2)
'''
model3 = (Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3), kernel_regularizer=regularizers.l2(0.05)))(inp1)
model3 = (MaxPooling2D(2, 2))(model3)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = BatchNormalization()(model1)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = BatchNormalization()(model1)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = Dropout(0.3)(model1)
#model1 = BatchNormalization()(model1)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = BatchNormalization()(model1)
#model1 = Dropout(0.3)(model1)
model3 = Flatten()(model3)
model3 = Dense(512,activation='relu')(model3)

models.append(model3)
'''
out = Concatenate()(models)

out = (Dense(fmax*12, activation='tanh'))(out)
out = Reshape((fmax,12))(out)
model = Model([inp1,inp2],out)
model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=learning_rate), loss=custom_loss, metrics=['mae',custom_loss])
model.summary()
# Out:
# 2024-12-03 04:05:46.589706: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13397 MB memory:  -> device: 0, name: NVIDIA A2, pci bus id: 0000:21:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 12)]                 0         []
#
#  dense (Dense)               (None, 512)                  6656      ['input_2[0][0]']
#
#  dense_1 (Dense)             (None, 512)                  262656    ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 512)                  262656    ['dense_1[0][0]']
#
#  dense_3 (Dense)             (None, 512)                  262656    ['dense_2[0][0]']
#
#  dense_4 (Dense)             (None, 512)                  262656    ['dense_3[0][0]']
#
#  concatenate (Concatenate)   (None, 512)                  0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 2352)                 1206576   ['concatenate[0][0]']
#
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  reshape (Reshape)           (None, 196, 12)              0         ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 2263856 (8.64 MB)
# Trainable params: 2263856 (8.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.load_weights('./models/air/mturn_196G_MLP.h5')
EPOCHS = 300
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: learning_rate * 0.95**(epoch/20))
hist = model.fit([x_train_img,x_train_geopara], y_train_encoded, validation_data=([x_valid_img,x_valid_geopara], y_valid_encoded), batch_size=30, epochs = EPOCHS,callbacks=[lr_schedule])
# Out:
# Epoch 1/300
# 2024-12-03 04:05:48.998256: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-12-03 04:05:49.059099: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f5fa0123840 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-12-03 04:05:49.059155: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A2, Compute Capability 8.6
# 2024-12-03 04:05:49.066140: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-03 04:05:49.105444: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8907
# 2024-12-03 04:05:49.174724: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-12-03 04:05:49.242287: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 79/79 [==============================] - 3s 10ms/step - loss: 0.3195 - mae: 0.2573 - custom_loss: 0.3160 - val_loss: 0.2565 - val_mae: 0.2050 - val_custom_loss: 0.2535 - lr: 1.0000e-04
# Epoch 2/300
# 79/79 [==============================] - 0s 4ms/step - loss: 0.2411 - mae: 0.1919 - custom_loss: 0.2379 - val_loss: 0.2278 - val_mae: 0.1800 - val_custom_loss: 0.2247 - lr: 9.9744e-05
# Epoch 3/300
# 79/79 [==============================] - 0s 4ms/step - loss: 0.2182 - mae: 0.1727 - custom_loss: 0.2150 - val_loss: 0.2107 - val_mae: 0.1661 - val_custom_loss: 0.2076 - lr: 9.9488e-05
# Epoch 4/300
# 79/79 [==============================] - 0s 4ms/step - loss: 0.2030 - mae: 0.1600 - custom_loss: 0.1999 - val_loss: 0.1990 - val_mae: 0.1562 - val_custom_loss: 0.1958 - lr: 9.9234e-05
# Epoch 5/300
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1922 - mae: 0.1508 - custom_loss: 0.1892 - val_loss: 0.1904 - val_mae: 0.1486 - val_custom_loss: 0.1873 - lr: 9.8979e-05
# Epoch 6/300
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1838 - mae: 0.1435 - custom_loss: 0.1808 - val_loss: 0.1842 - val_mae: 0.1434 - val_custom_loss: 0.1811 - lr: 9.8726e-05
# Epoch 7/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1780 - mae: 0.1384 - custom_loss: 0.1749 - val_loss: 0.1785 - val_mae: 0.1384 - val_custom_loss: 0.1754 - lr: 9.8473e-05
# Epoch 8/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1734 - mae: 0.1345 - custom_loss: 0.1704 - val_loss: 0.1744 - val_mae: 0.1350 - val_custom_loss: 0.1713 - lr: 9.8221e-05
# Epoch 9/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1688 - mae: 0.1306 - custom_loss: 0.1658 - val_loss: 0.1713 - val_mae: 0.1322 - val_custom_loss: 0.1683 - lr: 9.7969e-05
# Epoch 10/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.
300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0835 - mae: 0.0617 - custom_loss: 0.0812 - val_loss: 0.1027 - val_mae: 0.0763 - val_custom_loss: 0.1003 - lr: 5.1997e-05
# Epoch 257/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0833 - mae: 0.0616 - custom_loss: 0.0810 - val_loss: 0.1027 - val_mae: 0.0763 - val_custom_loss: 0.1004 - lr: 5.1864e-05
# Epoch 258/300
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0835 - mae: 0.0617 - custom_loss: 0.0812 - val_loss: 0.1029 - val_mae: 0.0766 - val_custom_loss: 0.1006 - lr: 5.1731e-05
# Epoch 259/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0833 - mae: 0.0615 - custom_loss: 0.0810 - val_loss: 0.1025 - val_mae: 0.0763 - val_custom_loss: 0.1001 - lr: 5.1598e-05
# Epoch 260/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0832 - mae: 0.0615 - custom_loss: 0.0810 - val_loss: 0.1024 - val_mae: 0.0761 - val_custom_loss: 0.1000 - lr: 5.1466e-05
# Epoch 261/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0832 - mae: 0.0615 - custom_loss: 0.0810 - val_loss: 0.1029 - val_mae: 0.0766 - val_custom_loss: 0.1005 - lr: 5.1334e-05
# Epoch 262/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0831 - mae: 0.0615 - custom_loss: 0.0809 - val_loss: 0.1029 - val_mae: 0.0766 - val_custom_loss: 0.1006 - lr: 5.1203e-05
# Epoch 263/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0831 - mae: 0.0615 - custom_loss: 0.0809 - val_loss: 0.1026 - val_mae: 0.0763 - val_custom_loss: 0.1002 - lr: 5.1072e-05
# Epoch 264/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0829 - mae: 0.0612 - custom_loss: 0.0806 - val_loss: 0.1031 - val_mae: 0.0768 - val_custom_loss: 0.1007 - lr: 5.0941e-05
# Epoch 265/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0828 - mae: 0.0612 - custom_loss: 0.0805 - val_loss: 0.1024 - val_mae: 0.0762 - val_custom_loss: 0.1000 - lr: 5.0810e-05
# Epoch 266/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0827 - mae: 0.0611 - custom_loss: 0.0805 - val_loss: 0.1020 - val_mae: 0.0758 - val_custom_loss: 0.0996 - lr: 5.0680e-05
# Epoch 267/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0823 - mae: 0.0608 - custom_loss: 0.0801 - val_loss: 0.1023 - val_mae: 0.0762 - val_custom_loss: 0.1000 - lr: 5.0550e-05
# Epoch 268/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0825 - mae: 0.0610 - custom_loss: 0.0803 - val_loss: 0.1022 - val_mae: 0.0760 - val_custom_loss: 0.0998 - lr: 5.0421e-05
# Epoch 269/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0823 - mae: 0.0608 - custom_loss: 0.0800 - val_loss: 0.1021 - val_mae: 0.0759 - val_custom_loss: 0.0997 - lr: 5.0292e-05
# Epoch 270/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0827 - mae: 0.0612 - custom_loss: 0.0805 - val_loss: 0.1019 - val_mae: 0.0758 - val_custom_loss: 0.0995 - lr: 5.0163e-05
# Epoch 271/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0821 - mae: 0.0606 - custom_loss: 0.0799 - val_loss: 0.1022 - val_mae: 0.0760 - val_custom_loss: 0.0998 - lr: 5.0034e-05
# Epoch 272/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0820 - mae: 0.0606 - custom_loss: 0.0798 - val_loss: 0.1021 - val_mae: 0.0760 - val_custom_loss: 0.0997 - lr: 4.9906e-05
# Epoch 273/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0820 - mae: 0.0606 - custom_loss: 0.0798 - val_loss: 0.1020 - val_mae: 0.0758 - val_custom_loss: 0.0995 - lr: 4.9778e-05
# Epoch 274/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0821 - mae: 0.0607 - custom_loss: 0.0799 - val_loss: 0.1016 - val_mae: 0.0755 - val_custom_loss: 0.0992 - lr: 4.9651e-05
# Epoch 275/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0820 - mae: 0.0606 - custom_loss: 0.0798 - val_loss: 0.1027 - val_mae: 0.0764 - val_custom_loss: 0.1003 - lr: 4.9524e-05
# Epoch 276/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0823 - mae: 0.0609 - custom_loss: 0.0801 - val_loss: 0.1018 - val_mae: 0.0758 - val_custom_loss: 0.0995 - lr: 4.9397e-05
# Epoch 277/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0818 - mae: 0.0604 - custom_loss: 0.0795 - val_loss: 0.1018 - val_mae: 0.0758 - val_custom_loss: 0.0995 - lr: 4.9270e-05
# Epoch 278/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0816 - mae: 0.0603 - custom_loss: 0.0794 - val_loss: 0.1015 - val_mae: 0.0755 - val_custom_loss: 0.0992 - lr: 4.9144e-05
# Epoch 279/300
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0818 - mae: 0.0605 - custom_loss: 0.0796 - val_loss: 0.1021 - val_mae: 0.0760 - val_custom_loss: 0.0997 - lr: 4.9018e-05
# Epoch 280/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0818 - mae: 0.0604 - custom_loss: 0.0796 - val_loss: 0.1016 - val_mae: 0.0755 - val_custom_loss: 0.0992 - lr: 4.8893e-05
# Epoch 281/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0815 - mae: 0.0602 - custom_loss: 0.0793 - val_loss: 0.1014 - val_mae: 0.0754 - val_custom_loss: 0.0991 - lr: 4.8767e-05
# Epoch 282/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0814 - mae: 0.0601 - custom_loss: 0.0792 - val_loss: 0.1019 - val_mae: 0.0758 - val_custom_loss: 0.0995 - lr: 4.8643e-05
# Epoch 283/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0813 - mae: 0.0600 - custom_loss: 0.0791 - val_loss: 0.1016 - val_mae: 0.0755 - val_custom_loss: 0.0992 - lr: 4.8518e-05
# Epoch 284/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0813 - mae: 0.0601 - custom_loss: 0.0791 - val_loss: 0.1017 - val_mae: 0.0756 - val_custom_loss: 0.0994 - lr: 4.8394e-05
# Epoch 285/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0812 - mae: 0.0599 - custom_loss: 0.0790 - val_loss: 0.1019 - val_mae: 0.0759 - val_custom_loss: 0.0996 - lr: 4.8270e-05
# Epoch 286/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0813 - mae: 0.0601 - custom_loss: 0.0791 - val_loss: 0.1018 - val_mae: 0.0757 - val_custom_loss: 0.0994 - lr: 4.8146e-05
# Epoch 287/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0812 - mae: 0.0600 - custom_loss: 0.0790 - val_loss: 0.1013 - val_mae: 0.0753 - val_custom_loss: 0.0989 - lr: 4.8023e-05
# Epoch 288/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0812 - mae: 0.0600 - custom_loss: 0.0790 - val_loss: 0.1013 - val_mae: 0.0754 - val_custom_loss: 0.0990 - lr: 4.7900e-05
# Epoch 289/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0811 - mae: 0.0599 - custom_loss: 0.0789 - val_loss: 0.1013 - val_mae: 0.0753 - val_custom_loss: 0.0990 - lr: 4.7777e-05
# Epoch 290/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0808 - mae: 0.0597 - custom_loss: 0.0786 - val_loss: 0.1011 - val_mae: 0.0752 - val_custom_loss: 0.0987 - lr: 4.7655e-05
# Epoch 291/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0807 - mae: 0.0596 - custom_loss: 0.0785 - val_loss: 0.1011 - val_mae: 0.0752 - val_custom_loss: 0.0987 - lr: 4.7533e-05
# Epoch 292/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0808 - mae: 0.0597 - custom_loss: 0.0787 - val_loss: 0.1011 - val_mae: 0.0752 - val_custom_loss: 0.0988 - lr: 4.7411e-05
# Epoch 293/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0807 - mae: 0.0596 - custom_loss: 0.0785 - val_loss: 0.1007 - val_mae: 0.0749 - val_custom_loss: 0.0984 - lr: 4.7289e-05
# Epoch 294/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0805 - mae: 0.0594 - custom_loss: 0.0783 - val_loss: 0.1008 - val_mae: 0.0749 - val_custom_loss: 0.0985 - lr: 4.7168e-05
# Epoch 295/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0805 - mae: 0.0595 - custom_loss: 0.0783 - val_loss: 0.1013 - val_mae: 0.0753 - val_custom_loss: 0.0990 - lr: 4.7048e-05
# Epoch 296/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0805 - mae: 0.0594 - custom_loss: 0.0783 - val_loss: 0.1012 - val_mae: 0.0753 - val_custom_loss: 0.0988 - lr: 4.6927e-05
# Epoch 297/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0803 - mae: 0.0593 - custom_loss: 0.0781 - val_loss: 0.1008 - val_mae: 0.0750 - val_custom_loss: 0.0985 - lr: 4.6807e-05
# Epoch 298/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0804 - mae: 0.0594 - custom_loss: 0.0783 - val_loss: 0.1011 - val_mae: 0.0751 - val_custom_loss: 0.0988 - lr: 4.6687e-05
# Epoch 299/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0805 - mae: 0.0595 - custom_loss: 0.0783 - val_loss: 0.1006 - val_mae: 0.0748 - val_custom_loss: 0.0983 - lr: 4.6567e-05
# Epoch 300/300
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0802 - mae: 0.0592 - custom_loss: 0.0780 - val_loss: 0.1009 - val_mae: 0.0750 - val_custom_loss: 0.0985 - lr: 4.6448e-05

# %%
np.shape(y_train_encoded)
# Out:
# (2369, 196, 12)

# %%
test_prediction = model.predict([x_test_img,x_test_geopara])
# Out:
# 25/25 [==============================] - 0s 1ms/step

# %%
np.shape(test_prediction)
# Out:
# (790, 196, 12)

# %%
mae = hist.history['mae']
val_mae = hist.history['val_mae']
epochs = range(1, len(mae) + 1)

plt.plot(epochs, mae, '-', label='Training mae')
plt.plot(epochs, val_mae, ':', label='Validation mae')
plt.title('Training and Validation mae')
plt.xlabel('Epoch')
plt.ylabel('mae')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %%
from sklearn.metrics import r2_score
r2_result = []
for z in range(fmax):
    r2 = 0
    for i in range(12):
        temp = r2_score(y_test_encoded[:,z,i], test_prediction[:,z,i], force_finite=False)
        r2 = r2+temp
    r2_result.append(r2/12)
plt.plot(range(fmax),r2_result)

# %%
np.mean(r2_result)
# Out:
# 0.8801414769394864

# %%
mae_all = np.zeros((fmax,12))
mae_mean = np.zeros(fmax)
for z in range(fmax):
    for i in range(12):
        mae_all[z][i] = np.mean(abs(test_prediction[:,z,i]-y_test_encoded[:,z,i]))*0.5*srange[z,i]
    mae_mean[z] = np.mean(mae_all[z][:])

# %%
freq = range(fmax)
for i in range(12):
    if (i%2==0):
        plt.plot(freq,mae_all[:,i])
plt.legend(["Re[S11]","Re[S12]","Re[S13]","Re[S14]","Re[S33]","Re[S34]"])
plt.xlabel('Frequency/GHz')
plt.ylabel('S-parameter mae')
# Out:
# Text(0, 0.5, 'S-parameter mae')

# %%
mae_all = np.zeros((fmax,12))
mae_mean = np.zeros(fmax)
for z in range(fmax):
    for i in range(12):
        mae_all[z][i] = np.mean(abs(test_prediction[:,z,i]-y_test_encoded[:,z,i]))*0.5*srange[z,i]
    mae_mean[z] = np.mean(mae_all[z][:])

# %%
plt.plot(range(fmax),mae_mean)
plt.xlabel('Frequency/GHz')
plt.ylabel('Average S-parameter mae')
# Out:
# Text(0, 0.5, 'Average S-parameter mae')

# %%
freq = range(fmax)
for i in range(12):
    if (i%2==1):
        plt.plot(freq,mae_all[:,i])
plt.legend(["Im[S11]","Im[S12]","Im[S13]","Im[S14]","Im[S33]","Im[S34]"])        
plt.xlabel('Frequency/GHz')
plt.ylabel('S-parameter mae')
# Out:
# Text(0, 0.5, 'S-parameter mae')

# %%
np.mean(mae_mean)
# Out:
# 0.04629260586173285

# %%
def R_squared(y, y_pred):
  residual = tf.reduce_sum(tf.square(tf.subtract(y, y_pred)))
  total = tf.reduce_sum(tf.square(tf.subtract(y, tf.reduce_mean(y))))
  r2 = tf.subtract(1.0, tf.divide(residual, total))
  return r2
print(R_squared(y_test_encoded,test_prediction))
# Out:
# tf.Tensor(0.9253574140028133, shape=(), dtype=float64)

# %%
model.save('./models/substrate/mturn_196G_MLP.h5')
# Out:
# /home/hh68/.conda/envs/tensorflow/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
np.save('MAE_MLP.npy',mae_all)
