# %%
import os
import numpy as np
from keras.preprocessing import image
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
import pandas as pd
import skrf as rf

#define the targeted max frequency
fmax = 196
#define function for loading images and s-parameters
#"path" is the path for images of transformer layout
#"label" is the path for labels. In this case, labels are S-parameter associated with each images 
def load_images_from_path(path, label,length):
    images = []
    labels = []
    
    for i in range(length):
        #load images
        img = image.load_img(path+str(i)+'.png', target_size=(500, 500, 3))
        images.append(image.img_to_array(img)[138:362,138:362,:])#trim the ground margin

        #load S-parameters
        #According to symmerty, only S11,S12,S13,S14,S33,S34 are considered
        #Each S-parameter has real and imaginary parts, and hence 12 real values in total.
        results = []
        datafile = label+str(i)+".s4p"
        spt = rf.Network(datafile)
        for i in range(fmax+1):
            results.append([spt.s[i][0][0].real,spt.s[i][0][0].imag,
                            spt.s[i][0][1].real,spt.s[i][0][1].imag,
                            spt.s[i][0][2].real,spt.s[i][0][2].imag,
                            spt.s[i][0][3].real,spt.s[i][0][3].imag,
                            spt.s[i][2][2].real,spt.s[i][2][2].imag,
                            spt.s[i][2][3].real,spt.s[i][2][3].imag])      
        labels.append(results) 
    return images, labels

def show_images(images):
    fig, axes = plt.subplots(1, 8, figsize=(20, 20), subplot_kw={'xticks': [], 'yticks': []})

    for i, ax in enumerate(axes.flat):
        ax.imshow(images[i] / 255)
# Out:
# 2024-12-03 09:55:34.099692: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#load data
#geometrical parameters stored in log.txt
#order of geopara (radiusA,radiusB,turnsA,turnsB,openA,openB,outA,outB,extA,extB,ratio,outbound)
logfile = open("/rdf/shared/design_automation/Data/2409Air/log.txt","r")
listall = list(map(lambda item: list(map(lambda jtem: eval(jtem.strip()), item[1:-1].split(','))), logfile.read().strip().split('\n')))
tabular_data = np.array(listall)

#load images and s-parameters
length = 4000
images, labels = load_images_from_path('/rdf/shared/design_automation/Data/2409Air/PNG/', '/rdf/shared/design_automation/Data/2409Air/SPData/',length)
show_images(images)
geoparas = []
images11 = []
labels11 = []

for kk in range(length):
    #select 1 turn and 1 turn transformers
   if((tabular_data[kk,2] !=1) or (tabular_data[kk,3]!=1)):
       #geoparas only includes the variable parameters in our designs. 
       #Constants at this design stages are excluded 
        geoparas.append(tabular_data[kk,(0,1,2,3,4,5,4,5,6,7,12,13)])
        images11.append(images[kk])
        labels11.append(labels[kk])
print(np.shape(geoparas))
# Out:
# (1202, 12)

# %%
#load data from the second folder
#geometrical parameters stored in log.txt
#order of geopara (radiusA,radiusB,turnsA,turnsB,openA,openB,outA,outB,extA,extB,ratio,outbound)
logfile = open("/rdf/shared/design_automation/Data/2409Air_2/log.txt","r")
listall = list(map(lambda item: list(map(lambda jtem: eval(jtem.strip()), item[1:-1].split(','))), logfile.read().strip().split('\n')))
tabular_data = np.array(listall)

#load images and s-parameters
#length = len(listall)-3
length = 900
images, labels = load_images_from_path('/rdf/shared/design_automation/Data/2409Air_2/PNG/', '/rdf/shared/design_automation/Data/2409Air_2/SPData/',length)


for kk in range(length):
    #select 1 turn and 1 turn transformers
   if((tabular_data[kk,2] !=1) or (tabular_data[kk,3]!=1)):
       #geoparas only includes the variable parameters in our designs. 
       #Constants at this design stages are excluded 
        geoparas.append(tabular_data[kk,(0,1,2,3,4,5,4,5,6,7,12,13)])
        images11.append(images[kk])
        labels11.append(labels[kk])
print(np.shape(geoparas))
# Out:
# (1478, 12)

# %%
#normalize geometrical inputs
geoparas_temp = np.array(geoparas)
geoparas = np.zeros(np.shape(geoparas_temp))
for i in range(len(geoparas)):
    for j in range(12):
        geoparas[i,j]= (geoparas_temp[i,j]-np.mean(geoparas_temp[:,j]))/np.std(geoparas_temp[:,j])

# %%
#construct the datasets
class item:
  def __init__(self, image,geopara,label ):
    self.image = image
    self.geopara = geopara
    self.label = label

data = []
for i in range(len(images11)):
    data.append(item(images11[i],geoparas[i],labels11[i]))

np.random.shuffle(data)

# %%
#define the split length for training, validation and test datasets
length = len(images11)
split1 = int(0.6*length)
split2 = int(0.8*length)
data_train = data[0:split1]
data_valid = data[split1:split2]
data_test = data[split2:]

# %%
#Separate the training, validation and test datasets 
train_images = []
train_labels = []
train_geoparas = []
valid_images = []
valid_labels = []
valid_geoparas = []
test_images = []
test_labels = []
test_geoparas = []


#The targeted frequency span up to fmax, with 1GHz step
s_max = np.zeros((fmax,12))
s_min = np.zeros((fmax,12))
srange = np.zeros((fmax,12))


for i in range(len(data_train)):
    train_images.append(data_train[i].image)
    train_geoparas.append(data_train[i].geopara)
    train_labels.append(data_train[i].label)
x_train_img = np.array(train_images) / 255
x_train_geopara = np.array(train_geoparas)
y_train_encoded = np.array(train_labels)[:,1:fmax+1,:]


for i in range(len(data_valid)):
    valid_images.append(data_valid[i].image)
    valid_geoparas.append(data_valid[i].geopara)
    valid_labels.append(data_valid[i].label)
x_valid_img = np.array(valid_images) / 255
x_valid_geopara = np.array(valid_geoparas)
y_valid_encoded = np.array(valid_labels)[:,1:fmax+1,:]


for i in range(len(data_test)):
    test_images.append(data_test[i].image)
    test_geoparas.append(data_test[i].geopara)
    test_labels.append(data_test[i].label)
x_test_img = np.array(test_images) / 255
x_test_geopara = np.array(test_geoparas)
y_test_encoded = np.array(test_labels)[:,1:fmax+1,:]

#normalize the s-parameters for each frequency point
for z in range(fmax):
    for i in range(12):
        s_max[z,i] = max(max(y_train_encoded[:,z,i]),max(y_valid_encoded[:,z,i]),max(y_test_encoded[:,z,i]))
        s_min[z,i] = min(min(y_train_encoded[:,z,i]),min(y_valid_encoded[:,z,i]),min(y_test_encoded[:,z,i]))
        srange[z,i] = s_max[z,i]-s_min[z,i]
    
    for i in range(12):
        y_train_encoded[:,z,i] = 2*(y_train_encoded[:,z,i]-s_min[z,i])/srange[z,i]-1

    for i in range(12):
        y_valid_encoded[:,z,i] = 2*(y_valid_encoded[:,z,i]-s_min[z,i])/srange[z,i]-1
    
    for i in range(12):
        y_test_encoded[:,z,i] = 2*(y_test_encoded[:,z,i]-s_min[z,i])/srange[z,i]-1

# %%
def custom_loss(y_true, y_pred):
    Lf = tf.math.sqrt(tf.reduce_mean(tf.square(y_true - y_pred),axis=1))
    return (tf.reduce_mean(Lf))

# %%
from keras import Sequential, Input, Model, regularizers
from keras.layers import Conv2D, MaxPooling2D,Dropout, Reshape, BatchNormalization,Conv1DTranspose,Conv1D
from keras.layers import Flatten, Dense, Concatenate
learning_rate = 2e-4
n_unet = 8

models = []

inp1 = Input((224,224,3),)
'''
model1 = (Conv2D(n_unet,(3,3),padding='same', activation='relu', input_shape=(224, 224, 3), kernel_regularizer=regularizers.l2(0.01)))(inp1)
model1 = (MaxPooling2D(2, 2))(model1)
model1 = (Conv2D(n_unet*2, (3, 3), padding='same',activation='relu'))(model1)

model1 = (MaxPooling2D(2, 2))(model1)
#model1 = BatchNormalization()(model1)
model1 = (Conv2D(n_unet*2, (3, 3),  padding='same',activation='relu'))(model1)

model1 = (MaxPooling2D(2, 2))(model1)
#model1 = BatchNormalization()(model1)
model1 = (Conv2D(n_unet*4, (3, 3), padding='same', activation='relu'))(model1)

layer1 = (MaxPooling2D(2, 2))(model1)
#model1 = Dropout(0.3)(model1)
#model1 = BatchNormalization()(model1)
layer2 = (Conv2D(n_unet*8, (3, 3),padding='same', activation='relu'))(layer1)
layer2 = (MaxPooling2D(2, 2))(layer2)

layer3 = (Conv2D(n_unet*16, (3, 3),padding='same', activation='relu'))(layer2)
layer3 = (MaxPooling2D(2, 2))(layer3)

layer4 = (Conv2D(n_unet*32, (3, 3),padding='same', activation='relu'))(layer3)
layer4 = (MaxPooling2D(2, 2))(layer4)


#backward
layer4 = Reshape((1,n_unet*32))(layer4)
layer4 = (Conv1DTranspose(n_unet*16,9,1, activation='relu'))(layer4)

layer3 = Reshape((9,n_unet*16))(layer3)
layer3 = Concatenate()([layer3,layer4])
layer3 = (Conv1D(n_unet*16,3,padding='same', activation='relu'))(layer3)
layer3 = (Conv1DTranspose(n_unet*8,9,5, activation='relu'))(layer3)


layer2 = Reshape((49,n_unet*8))(layer2)
layer2 = Concatenate()([layer2,layer3])
layer2 = (Conv1D(n_unet*8,3,padding='same', activation='relu'))(layer2)
layer2 = (Conv1DTranspose(n_unet*4,3,4, activation='relu'))(layer2)

layer1 = Reshape((196,n_unet*4))(layer1)
layer1 = Concatenate()([layer1,layer2])
layer1 = (Conv1D(n_unet*4,3,padding='same', activation='relu'))(layer2)
model1 = Flatten()(layer1)
models.append(model1)
'''
inp2 = Input(12,)
'''
model2=(Dense(512,activation='relu',input_shape = (8,),kernel_regularizer=regularizers.l2(0.10)))(inp2)
model2=(Dense(512,activation='relu'))(model2)
model2=(Dense(512,activation='relu'))(model2)
model2=(Dense(512,activation='relu'))(model2)
model2=(Dense(512,activation='relu'))(model2)
models.append(model2)
'''
model3 = (Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3), kernel_regularizer=regularizers.l2(0.05)))(inp1)
model3 = (MaxPooling2D(2, 2))(model3)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = BatchNormalization()(model1)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = BatchNormalization()(model1)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = Dropout(0.3)(model1)
#model1 = BatchNormalization()(model1)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = BatchNormalization()(model1)
#model1 = Dropout(0.3)(model1)
model3 = Flatten()(model3)
model3 = Dense(512,activation='relu')(model3)

models.append(model3)
out = Concatenate()(models)

out = (Dense(fmax*12, activation='tanh'))(out)
out = Reshape((fmax,12))(out)
model = Model([inp1,inp2],out)
model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=learning_rate), loss=custom_loss, metrics=['mae',custom_loss])
model.summary()
# Out:
# 2024-12-03 09:57:34.399393: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13397 MB memory:  -> device: 0, name: NVIDIA A2, pci bus id: 0000:21:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 222, 222, 32)         896       ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 32)         0         ['conv2d[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 128)        36992     ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 128)          0         ['conv2d_1[0][0]']
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)          147584    ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 26, 26, 128)          0         ['conv2d_2[0][0]']
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)          147584    ['max_pooling2d_2[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 12, 12, 128)          0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 128)          147584    ['max_pooling2d_3[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 5, 5, 128)            0         ['conv2d_4[0][0]']
#  g2D)
#
#  flatten (Flatten)           (None, 3200)                 0         ['max_pooling2d_4[0][0]']
#
#  dense (Dense)               (None, 512)                  1638912   ['flatten[0][0]']
#
#  concatenate (Concatenate)   (None, 512)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 2352)                 1206576   ['concatenate[0][0]']
#
#  input_2 (InputLayer)        [(None, 12)]                 0         []
#
#  reshape (Reshape)           (None, 196, 12)              0         ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 3326128 (12.69 MB)
# Trainable params: 3326128 (12.69 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
EPOCHS = 150
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: learning_rate * 0.95**(epoch/20))
hist = model.fit([x_train_img,x_train_geopara], y_train_encoded, validation_data=([x_valid_img,x_valid_geopara], y_valid_encoded), batch_size=30, epochs = EPOCHS,callbacks=[lr_schedule])
# Out:
# Epoch 1/150
# 2024-12-03 09:57:36.562746: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8907
# 2024-12-03 09:57:36.649960: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-12-03 09:57:37.505086: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-12-03 09:57:37.581748: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f69cca1260 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-12-03 09:57:37.581812: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A2, Compute Capability 8.6
# 2024-12-03 09:57:37.588922: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-03 09:57:37.664199: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-12-03 09:57:37.729580: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 30/30 [==============================] - 12s 186ms/step - loss: 0.6694 - mae: 0.3534 - custom_loss: 0.4162 - val_loss: 0.6319 - val_mae: 0.3335 - val_custom_loss: 0.3964 - lr: 2.0000e-04
# Epoch 2/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.6121 - mae: 0.3292 - custom_loss: 0.3911 - val_loss: 0.5951 - val_mae: 0.3281 - val_custom_loss: 0.3892 - lr: 1.9949e-04
# Epoch 3/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.5728 - mae: 0.3190 - custom_loss: 0.3793 - val_loss: 0.5505 - val_mae: 0.3110 - val_custom_loss: 0.3706 - lr: 1.9898e-04
# Epoch 4/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.5388 - mae: 0.3116 - custom_loss: 0.3699 - val_loss: 0.5212 - val_mae: 0.3060 - val_custom_loss: 0.3639 - lr: 1.9847e-04
# Epoch 5/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.5084 - mae: 0.3040 - custom_loss: 0.3610 - val_loss: 0.4955 - val_mae: 0.3004 - val_custom_loss: 0.3582 - lr: 1.9796e-04
# Epoch 6/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.4777 - mae: 0.2931 - custom_loss: 0.3484 - val_loss: 0.4644 - val_mae: 0.2884 - val_custom_loss: 0.3442 - lr: 1.9745e-04
# Epoch 7/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.4460 - mae: 0.2781 - custom_loss: 0.3327 - val_loss: 0.4303 - val_mae: 0.2695 - val_custom_loss: 0.3247 - lr: 1.9695e-04
# Epoch 8/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.4196 - mae: 0.2655 - custom_loss: 0.3201 - val_loss: 0.4067 - val_mae: 0.2593 - val_custom_loss: 0.3134 - lr: 1.9644e-04
# Epoch 9/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.3942 - mae: 0.2523 - custom_loss: 0.3056 - val_loss: 0.3846 - val_mae: 0.2475 - val_custom_loss: 0.3014 - lr: 1.9594e-04
# Epoch 10/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.3685 - mae: 0.2369 - custom_loss: 0.2897 - val_loss: 0.3649 - val_mae: 0.2374 - val_custom_loss: 0.2902 - lr: 1.9544e-04
# Epoch 11/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.3450 - mae: 0.2223 - custom_loss: 0.2738 - val_loss: 0.3409 - val_mae: 0.2207 - val_custom_loss: 0.2727 - lr: 1.9494e-04
# Epoch 12/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.3260 - mae: 0.2100 - custom_loss: 0.2604 - val_loss: 0.3260 - val_mae: 0.2123 - val_custom_loss: 0.2627 - lr: 1.9444e-04
# Epoch 13/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.3104 - mae: 0.2001 - custom_loss: 0.2487 - val_loss: 0.3170 - val_mae: 0.2064 - val_custom_loss: 0.2573 - lr: 1.9394e-04
# Epoch 14/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.2941 - mae: 0.1882 - custom_loss: 0.2359 - val_loss: 0.2998 - val_mae: 0.1940 - val_custom_loss: 0.2431 - lr: 1.9344e-04
# Epoch 15/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.2829 - mae: 0.1809 - custom_loss: 0.2273 - val_loss: 0.2922 - val_mae: 0.1898 - val_custom_loss: 0.2380 - lr: 1.9295e-04
# Epoch 16/150
# 30/30 [==============================] - 3s 86ms/step - loss: 0.2726 - mae: 0.1741 - custom_loss: 0.2191 - val_loss: 0.2805 - val_mae: 0.1813 - val_custom_loss: 0.2284 - lr: 1.9245e-04
# Epoch 17/150
# 30/30 [==============================] - 3s 87ms/step - loss: 0.2611 - mae: 0.1658 - custom_loss: 0.2100 - val_loss: 0.2739 - val_mae: 0.1767 - val_custom_loss: 0.2237 - lr: 1.9196e-04
# Epoch 18/150
# 30/30 [==============================] - 3s 85ms/step - loss: 0.2540 - mae: 0.1613 - custom_loss: 0.2042 - val_loss: 0.2719 - val_mae: 0.1770 - val_custom_loss: 0.2233 - lr: 1.9147e-04
# Epoch 19/150
# 30/30 [==============================] - 3s 87ms/step - loss: 0.2475 - mae: 0.1571 - custom_loss: 0.1998 - val_loss: 0.2622 - val_mae: 0.1696 - val_custom_loss: 0.2152 - lr: 1.9098e-04
# Epoch 20/150
# 30/30 [==============================] - 3s 86ms/step - loss: 0.2445 - mae: 0.1564 - custom_loss: 0.1981 - val_loss: 0.2650 - val_mae: 0.1734 - val_custom_loss: 0.2193 - lr: 1.9049e-04
# Epoch 21/150
# 30/30 [==============================] - 3s 87ms/step - loss: 0.2369 - mae: 0.1506 - custom_loss: 0.1917 - val_loss: 0.2637 - val_mae: 0.1739 - val_custom_loss: 0.2193 - lr: 1.9000e-04
# Epoch 22/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.2316 - mae: 0.1474 - custom_loss: 0.1875 - val_loss: 0.2534 - val_mae: 0.1653 - val_custom_loss: 0.2100 - lr: 1.8951e-04
# Epoch 23/150
# 30/30 [==============================] - 3s 88ms/step - loss: 0.2232 - mae: 0.1410 - custom_loss: 0.1802 - val_loss: 0.2453 - val_mae: 0.1588 - val_custom_loss: 0.2030 - lr: 1.8903e-04
# Epoch 24/150
# 30/30 [==============================] - 3s 85ms/step - loss: 0.2177 - mae: 0.1369 - custom_loss: 0.1757 - val_loss: 0.2429 - val_mae: 0.1579 - val_custom_loss: 0.2016 - lr: 1.8854e-04
# Epoch 25/150
# 30/30 [==============================] - 3s 85ms/step - loss: 0.2143 - mae: 0.1351 - custom_loss: 0.1736 - val_loss: 0.2414 - val_mae: 0.1575 - val_custom_loss: 0.2010 - lr: 1.8806e-04
# Epoch 26/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.2090 - mae: 0.1314 - custom_loss: 0.1688 - val_loss: 0.2360 - val_mae: 0.1538 - val_custom_loss: 0.1967 - lr: 1.8758e-04
# Epoch 27/150
# 30/30 [==============================] - 3s 84ms/step - loss: 0.2070 - mae: 0.1307 - custom_loss: 0.1681 - val_loss: 0.2341 - val_mae: 0.1527 - val_custom_loss: 0.1956 - lr: 1.8710e-04
# Epoch 28/150
# 30/30 [==============================] - 3s 84ms/step - loss: 0.2021 - mae: 0.1274 - custom_loss: 0.1645 - val_loss: 0.2329 - val_mae: 0.1525 - val_custom_loss: 0.1953 - lr: 1.8662e-04
# Epoch 29/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1977 - mae: 0.1245 - custom_loss: 0.1604 - val_loss: 0.2290 - val_mae: 0.1500 - val_custom_loss: 0.1922 - lr: 1.8614e-04
# Epoch 30/150
# 30/30 [==============================] - 3s 84ms/step - loss: 0.1964 - mae: 0.1241 - custom_loss: 0.1600 - val_loss: 0.2273 - val_mae: 0.1490 - val_custom_loss: 0.1914 - lr: 1.8566e-04
# Epoch 31/150
# 30/30 [==============================] - 3s 84ms/step - loss: 0.1926 - mae: 0.1216 - custom_loss: 0.1571 - val_loss: 0.2286 - val_mae: 0.1514 - val_custom_loss: 0.1933 - lr: 1.8519e-04
# Epoch 32/150
# 30/30 [==============================] - 3s 83ms/step - loss: 0.1892 - mae: 0.1194 - custom_loss: 0.1543 - val_loss: 0.2254 - val_mae: 0.1489 - val_custom_loss: 0.1910 - lr: 1.8471e-04
# Epoch 33/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1882 - mae: 0.1194 - custom_loss: 0.1540 - val_loss: 0.2235 - val_mae: 0.1478 - val_custom_loss: 0.1898 - lr: 1.8424e-04
# Epoch 34/150
# 30/30 [==============================] - 3s 84ms/step - loss: 0.1831 - mae: 0.1155 - custom_loss: 0.1497 - val_loss: 0.2254 - val_mae: 0.1504 - val_custom_loss: 0.1922 - lr: 1.8377e-04
# Epoch 35/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.1811 - mae: 0.1145 - custom_loss: 0.1485 - val_loss: 0.2204 - val_mae: 0.1463 - val_custom_loss: 0.1879 - lr: 1.8330e-04
# Epoch 36/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.1778 - mae: 0.1123 - custom_loss: 0.1456 - val_loss: 0.2175 - val_mae: 0.1442 - val_custom_loss: 0.1857 - lr: 1.8283e-04
# Epoch 37/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.1751 - mae: 0.1106 - custom_loss: 0.1435 - val_loss: 0.2177 - val_mae: 0.1446 - val_custom_loss: 0.1865 - lr: 1.8236e-04
# Epoch 38/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1743 - mae: 0.1106 - custom_loss: 0.1433 - val_loss: 0.2161 - val_mae: 0.1445 - val_custom_loss: 0.1855 - lr: 1.8189e-04
# Epoch 39/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.1700 - mae: 0.1075 - custom_loss: 0.1397 - val_loss: 0.2142 - val_mae: 0.1427 - val_custom_loss: 0.1842 - lr: 1.8143e-04
# Epoch 40/150
# 30/30 [==============================] - 3s 84ms/step - loss: 0.1668 - mae: 0.1052 - custom_loss: 0.1371 - val_loss: 0.2131 - val_mae: 0.1424 - val_custom_loss: 0.1836 - lr: 1.8096e-04
# Epoch 41/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1652 - mae: 0.1045 - custom_loss: 0.1359 - val_loss: 0.2098 - val_mae: 0.1403 - val_custom_loss: 0.1808 - lr: 1.8050e-04
# Epoch 42/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1634 - mae: 0.1035 - custom_loss: 0.1347 - val_loss: 0.2100 - val_mae: 0.1410 - val_custom_loss: 0.1816 - lr: 1.8004e-04
# Epoch 43/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1606 - mae: 0.1016 - custom_loss: 0.1324 - val_loss: 0.2108 - val_mae: 0.1420 - val_custom_loss: 0.1829 - lr: 1.7958e-04
# Epoch 44/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.1602 - mae: 0.1018 - custom_loss: 0.1325 - val_loss: 0.2093 - val_mae: 0.1414 - val_custom_loss: 0.1820 - lr: 1.7912e-04
# Epoch 45/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1583 - mae: 0.1008 - custom_loss: 0.1311 - val_loss: 0.2085 - val_mae: 0.1408 - val_custom_loss: 0.1816 - lr: 1.7866e-04
# Epoch 46/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.1551 - mae: 0.0985 - custom_loss: 0.1287 - val_loss: 0.2060 - val_mae: 0.1391 - val_custom_loss: 0.1796 - lr: 1.7820e-04
# Epoch 47/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1532 - mae: 0.0973 - custom_loss: 0.1272 - val_loss: 0.2052 - val_mae: 0.1389 - val_custom_loss: 0.1793 - lr: 1.7774e-04
# Epoch 48/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1515 - mae: 0.0964 - custom_loss: 0.1259 - val_loss: 0.2055 - val_mae: 0.1395 - val_custom_loss: 0.1800 - lr: 1.7729e-04
# Epoch 49/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1488 - mae: 0.0945 - custom_loss: 0.1237 - val_loss: 0.2048 - val_mae: 0.1391 - val_custom_loss: 0.1798 - lr: 1.7683e-04
# Epoch 50/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1469 - mae: 0.0934 - custom_loss: 0.1221 - val_loss: 0.2030 - val_mae: 0.1380 - val_custom_loss: 0.1783 - lr: 1.7638e-04
# Epoch 51/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1451 - mae: 0.0923 - custom_loss: 0.1206 - val_loss: 0.2037 - val_mae: 0.1388 - val_custom_loss: 0.1795 - lr: 1.7593e-04
# Epoch 52/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1436 - mae: 0.0914 - custom_loss: 0.1195 - val_loss: 0.2013 - val_mae: 0.1371 - val_custom_loss: 0.1775 - lr: 1.7548e-04
# Epoch 53/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1433 - mae: 0.0916 - custom_loss: 0.1201 - val_loss: 0.2022 - val_mae: 0.1381 - val_custom_loss: 0.1788 - lr: 1.7503e-04
# Epoch 54/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1411 - mae: 0.0901 - custom_loss: 0.1178 - val_loss: 0.2017 - val_mae: 0.1383 - val_custom_loss: 0.1786 - lr: 1.7458e-04
# Epoch 55/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1401 - mae: 0.0898 - custom_loss: 0.1172 - val_loss: 0.2005 - val_mae: 0.1373 - val_custom_loss: 0.1778 - lr: 1.7413e-04
# Epoch 56/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1373 - mae: 0.0878 - custom_loss: 0.1148 - val_loss: 0.2006 - val_mae: 0.1377 - val_custom_loss: 0.1783 - lr: 1.7369e-04
# Epoch 57/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1360 - mae: 0.0870 - custom_loss: 0.1139 - val_loss: 0.1988 - val_mae: 0.1365 - val_custom_loss: 0.1768 - lr: 1.7324e-04
# Epoch 58/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1336 - mae: 0.0853 - custom_loss: 0.1121 - val_loss: 0.1979 - val_mae: 0.1362 - val_custom_loss: 0.1763 - lr: 1.7280e-04
# Epoch 59/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1329 - mae: 0.0850 - custom_loss: 0.1116 - val_loss: 0.1988 - val_mae: 0.1371 - val_custom_loss: 0.1775 - lr: 1.7236e-04
# Epoch 60/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.1310 - mae: 0.0839 - custom_loss: 0.1099 - val_loss: 0.1984 - val_mae: 0.1371 - val_custom_loss: 0.1774 - lr: 1.7192e-04
# Epoch 61/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1292 - mae: 0.0827 - custom_loss: 0.1084 - val_loss: 0.1975 - val_mae: 0.1365 - val_custom_loss: 0.1769 - lr: 1.7147e-04
# Epoch 62/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.1271 - mae: 0.0812 - custom_loss: 0.1068 - val_loss: 0.1953 - val_mae: 0.1349 - val_custom_loss: 0.1750 - lr: 1.7104e-04
# Epoch 63/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1264 - mae: 0.0810 - custom_loss: 0.1061 - val_loss: 0.1962 - val_mae: 0.1361 - val_custom_loss: 0.1763 - lr: 1.7060e-04
# Epoch 64/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1246 - mae: 0.0798 - custom_loss: 0.1046 - val_loss: 0.1949 - val_mae: 0.1351 - val_custom_loss: 0.1752 - lr: 1.7016e-04
# Epoch 65/150
# 30/30 [==============================] - 2s 82ms/step - loss: 0.1230 - mae: 0.0788 - custom_loss: 0.1035 - val_loss: 0.1944 - val_mae: 0.1349 - val_custom_loss: 0.1751 - lr: 1.6972e-04
# Epoch 66/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1233 - mae: 0.0794 - custom_loss: 0.1040 - val_loss: 0.1940 - val_mae: 0.1348 - val_custom_loss: 0.1749 - lr: 1.6929e-04
# Epoch 67/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1207 - mae: 0.0775 - custom_loss: 0.1019 - val_loss: 0.1937 - val_mae: 0.1348 - val_custom_loss: 0.1748 - lr: 1.6886e-04
# Epoch 68/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.1194 - mae: 0.0768 - custom_loss: 0.1008 - val_loss: 0.1937 - val_mae: 0.1350 - val_custom_loss: 0.1752 - lr: 1.6842e-04
# Epoch 69/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.1182 - mae: 0.0759 - custom_loss: 0.1001 - val_loss: 0.1928 - val_mae: 0.1343 - val_custom_loss: 0.1746 - lr: 1.6799e-04
# Epoch 70/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1174 - mae: 0.0756 - custom_loss: 0.0996 - val_loss: 0.1934 - val_mae: 0.1351 - val_custom_loss: 0.1755 - lr: 1.6756e-04
# Epoch 71/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1161 - mae: 0.0748 - custom_loss: 0.0983 - val_loss: 0.1930 - val_mae: 0.1350 - val_custom_loss: 0.1753 - lr: 1.6713e-04
# Epoch 72/150
# 30/30 [==============================] - 3s 84ms/step - loss: 0.1145 - mae: 0.0737 - custom_loss: 0.0969 - val_loss: 0.1920 - val_mae: 0.1343 - val_custom_loss: 0.1746 - lr: 1.6671e-04
# Epoch 73/150
# 30/30 [==============================] - 3s 85ms/step - loss: 0.1129 - mae: 0.0727 - custom_loss: 0.0958 - val_loss: 0.1917 - val_mae: 0.1344 - val_custom_loss: 0.1745 - lr: 1.6628e-04
# Epoch 74/150
# 30/30 [==============================] - 3s 84ms/step - loss: 0.1126 - mae: 0.0727 - custom_loss: 0.0959 - val_loss: 0.1931 - val_mae: 0.1357 - val_custom_loss: 0.1761 - lr: 1.6585e-04
# Epoch 75/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.1120 - mae: 0.0726 - custom_loss: 0.0952 - val_loss: 0.1917 - val_mae: 0.1347 - val_custom_loss: 0.1750 - lr: 1.6543e-04
# Epoch 76/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1105 - mae: 0.0714 - custom_loss: 0.0939 - val_loss: 0.1900 - val_mae: 0.1336 - val_custom_loss: 0.1736 - lr: 1.6500e-04
# Epoch 77/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1091 - mae: 0.0706 - custom_loss: 0.0932 - val_loss: 0.1912 - val_mae: 0.1348 - val_custom_loss: 0.1750 - lr: 1.6458e-04
# Epoch 78/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1084 - mae: 0.0703 - custom_loss: 0.0924 - val_loss: 0.1914 - val_mae: 0.1355 - val_custom_loss: 0.1755 - lr: 1.6416e-04
# Epoch 79/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1097 - mae: 0.0717 - custom_loss: 0.0941 - val_loss: 0.1906 - val_mae: 0.1347 - val_custom_loss: 0.1748 - lr: 1.6374e-04
# Epoch 80/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.1076 - mae: 0.0701 - custom_loss: 0.0919 - val_loss: 0.1919 - val_mae: 0.1356 - val_custom_loss: 0.1763 - lr: 1.6332e-04
# Epoch 81/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1058 - mae: 0.0688 - custom_loss: 0.0905 - val_loss: 0.1896 - val_mae: 0.1341 - val_custom_loss: 0.1742 - lr: 1.6290e-04
# Epoch 82/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.1040 - mae: 0.0674 - custom_loss: 0.0887 - val_loss: 0.1898 - val_mae: 0.1342 - val_custom_loss: 0.1747 - lr: 1.6248e-04
# Epoch 83/150
# 30/30 [==============================] - 3s 84ms/step - loss: 0.1029 - mae: 0.0668 - custom_loss: 0.0880 - val_loss: 0.1890 - val_mae: 0.1337 - val_custom_loss: 0.1740 - lr: 1.6207e-04
# Epoch 84/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1017 - mae: 0.0661 - custom_loss: 0.0869 - val_loss: 0.1892 - val_mae: 0.1343 - val_custom_loss: 0.1745 - lr: 1.6165e-04
# Epoch 85/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.1016 - mae: 0.0662 - custom_loss: 0.0869 - val_loss: 0.1890 - val_mae: 0.1340 - val_custom_loss: 0.1744 - lr: 1.6124e-04
# Epoch 86/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0995 - mae: 0.0646 - custom_loss: 0.0851 - val_loss: 0.1887 - val_mae: 0.1340 - val_custom_loss: 0.1744 - lr: 1.6083e-04
# Epoch 87/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0983 - mae: 0.0638 - custom_loss: 0.0842 - val_loss: 0.1883 - val_mae: 0.1336 - val_custom_loss: 0.1741 - lr: 1.6041e-04
# Epoch 88/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.0982 - mae: 0.0639 - custom_loss: 0.0842 - val_loss: 0.1882 - val_mae: 0.1338 - val_custom_loss: 0.1742 - lr: 1.6000e-04
# Epoch 89/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0979 - mae: 0.0640 - custom_loss: 0.0843 - val_loss: 0.1885 - val_mae: 0.1345 - val_custom_loss: 0.1748 - lr: 1.5959e-04
# Epoch 90/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0968 - mae: 0.0633 - custom_loss: 0.0831 - val_loss: 0.1883 - val_mae: 0.1341 - val_custom_loss: 0.1747 - lr: 1.5918e-04
# Epoch 91/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0954 - mae: 0.0622 - custom_loss: 0.0821 - val_loss: 0.1880 - val_mae: 0.1341 - val_custom_loss: 0.1746 - lr: 1.5878e-04
# Epoch 92/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0945 - mae: 0.0617 - custom_loss: 0.0813 - val_loss: 0.1869 - val_mae: 0.1333 - val_custom_loss: 0.1736 - lr: 1.5837e-04
# Epoch 93/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0933 - mae: 0.0608 - custom_loss: 0.0803 - val_loss: 0.1872 - val_mae: 0.1336 - val_custom_loss: 0.1741 - lr: 1.5796e-04
# Epoch 94/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0926 - mae: 0.0605 - custom_loss: 0.0799 - val_loss: 0.1877 - val_mae: 0.1343 - val_custom_loss: 0.1748 - lr: 1.5756e-04
# Epoch 95/150
# 30/30 [==============================] - 2s 82ms/step - loss: 0.0926 - mae: 0.0607 - custom_loss: 0.0799 - val_loss: 0.1879 - val_mae: 0.1346 - val_custom_loss: 0.1752 - lr: 1.5716e-04
# Epoch 96/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0918 - mae: 0.0602 - custom_loss: 0.0792 - val_loss: 0.1877 - val_mae: 0.1346 - val_custom_loss: 0.1752 - lr: 1.5675e-04
# Epoch 97/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0919 - mae: 0.0605 - custom_loss: 0.0796 - val_loss: 0.1874 - val_mae: 0.1346 - val_custom_loss: 0.1749 - lr: 1.5635e-04
# Epoch 98/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0910 - mae: 0.0598 - custom_loss: 0.0786 - val_loss: 0.1880 - val_mae: 0.1349 - val_custom_loss: 0.1757 - lr: 1.5595e-04
# Epoch 99/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0892 - mae: 0.0585 - custom_loss: 0.0770 - val_loss: 0.1873 - val_mae: 0.1346 - val_custom_loss: 0.1752 - lr: 1.5555e-04
# Epoch 100/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0891 - mae: 0.0586 - custom_loss: 0.0771 - val_loss: 0.1863 - val_mae: 0.1339 - val_custom_loss: 0.1743 - lr: 1.5515e-04
# Epoch 101/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0878 - mae: 0.0577 - custom_loss: 0.0761 - val_loss: 0.1862 - val_mae: 0.1337 - val_custom_loss: 0.1743 - lr: 1.5476e-04
# Epoch 102/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0881 - mae: 0.0581 - custom_loss: 0.0765 - val_loss: 0.1864 - val_mae: 0.1340 - val_custom_loss: 0.1746 - lr: 1.5436e-04
# Epoch 103/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0877 - mae: 0.0579 - custom_loss: 0.0762 - val_loss: 0.1880 - val_mae: 0.1356 - val_custom_loss: 0.1764 - lr: 1.5396e-04
# Epoch 104/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0875 - mae: 0.0579 - custom_loss: 0.0761 - val_loss: 0.1871 - val_mae: 0.1348 - val_custom_loss: 0.1756 - lr: 1.5357e-04
# Epoch 105/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0858 - mae: 0.0566 - custom_loss: 0.0744 - val_loss: 0.1862 - val_mae: 0.1342 - val_custom_loss: 0.1748 - lr: 1.5318e-04
# Epoch 106/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0841 - mae: 0.0553 - custom_loss: 0.0731 - val_loss: 0.1862 - val_mae: 0.1344 - val_custom_loss: 0.1750 - lr: 1.5278e-04
# Epoch 107/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0842 - mae: 0.0556 - custom_loss: 0.0729 - val_loss: 0.1857 - val_mae: 0.1339 - val_custom_loss: 0.1746 - lr: 1.5239e-04
# Epoch 108/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0835 - mae: 0.0550 - custom_loss: 0.0725 - val_loss: 0.1865 - val_mae: 0.1346 - val_custom_loss: 0.1755 - lr: 1.5200e-04
# Epoch 109/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0830 - mae: 0.0548 - custom_loss: 0.0722 - val_loss: 0.1868 - val_mae: 0.1350 - val_custom_loss: 0.1759 - lr: 1.5161e-04
# Epoch 110/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0824 - mae: 0.0545 - custom_loss: 0.0717 - val_loss: 0.1860 - val_mae: 0.1343 - val_custom_loss: 0.1753 - lr: 1.5123e-04
# Epoch 111/150
# 30/30 [==============================] - 3s 84ms/step - loss: 0.0810 - mae: 0.0534 - custom_loss: 0.0704 - val_loss: 0.1854 - val_mae: 0.1342 - val_custom_loss: 0.1748 - lr: 1.5084e-04
# Epoch 112/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.0804 - mae: 0.0531 - custom_loss: 0.0699 - val_loss: 0.1853 - val_mae: 0.1339 - val_custom_loss: 0.1748 - lr: 1.5045e-04
# Epoch 113/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0792 - mae: 0.0521 - custom_loss: 0.0690 - val_loss: 0.1851 - val_mae: 0.1339 - val_custom_loss: 0.1747 - lr: 1.5007e-04
# Epoch 114/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0788 - mae: 0.0519 - custom_loss: 0.0686 - val_loss: 0.1865 - val_mae: 0.1351 - val_custom_loss: 0.1762 - lr: 1.4968e-04
# Epoch 115/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0804 - mae: 0.0535 - custom_loss: 0.0702 - val_loss: 0.1853 - val_mae: 0.1343 - val_custom_loss: 0.1751 - lr: 1.4930e-04
# Epoch 116/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0783 - mae: 0.0518 - custom_loss: 0.0683 - val_loss: 0.1852 - val_mae: 0.1341 - val_custom_loss: 0.1751 - lr: 1.4892e-04
# Epoch 117/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.0772 - mae: 0.0510 - custom_loss: 0.0676 - val_loss: 0.1849 - val_mae: 0.1341 - val_custom_loss: 0.1749 - lr: 1.4853e-04
# Epoch 118/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.0767 - mae: 0.0507 - custom_loss: 0.0671 - val_loss: 0.1850 - val_mae: 0.1342 - val_custom_loss: 0.1751 - lr: 1.4815e-04
# Epoch 119/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0766 - mae: 0.0508 - custom_loss: 0.0669 - val_loss: 0.1845 - val_mae: 0.1339 - val_custom_loss: 0.1747 - lr: 1.4777e-04
# Epoch 120/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0767 - mae: 0.0510 - custom_loss: 0.0671 - val_loss: 0.1857 - val_mae: 0.1349 - val_custom_loss: 0.1761 - lr: 1.4740e-04
# Epoch 121/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.0762 - mae: 0.0507 - custom_loss: 0.0666 - val_loss: 0.1850 - val_mae: 0.1344 - val_custom_loss: 0.1755 - lr: 1.4702e-04
# Epoch 122/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0753 - mae: 0.0500 - custom_loss: 0.0658 - val_loss: 0.1848 - val_mae: 0.1343 - val_custom_loss: 0.1754 - lr: 1.4664e-04
# Epoch 123/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0741 - mae: 0.0491 - custom_loss: 0.0651 - val_loss: 0.1847 - val_mae: 0.1343 - val_custom_loss: 0.1753 - lr: 1.4627e-04
# Epoch 124/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0747 - mae: 0.0498 - custom_loss: 0.0657 - val_loss: 0.1849 - val_mae: 0.1347 - val_custom_loss: 0.1756 - lr: 1.4589e-04
# Epoch 125/150
# 30/30 [==============================] - 2s 82ms/step - loss: 0.0753 - mae: 0.0504 - custom_loss: 0.0661 - val_loss: 0.1857 - val_mae: 0.1352 - val_custom_loss: 0.1765 - lr: 1.4552e-04
# Epoch 126/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0729 - mae: 0.0484 - custom_loss: 0.0639 - val_loss: 0.1847 - val_mae: 0.1346 - val_custom_loss: 0.1756 - lr: 1.4515e-04
# Epoch 127/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0724 - mae: 0.0481 - custom_loss: 0.0635 - val_loss: 0.1855 - val_mae: 0.1353 - val_custom_loss: 0.1765 - lr: 1.4477e-04
# Epoch 128/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0717 - mae: 0.0476 - custom_loss: 0.0626 - val_loss: 0.1842 - val_mae: 0.1341 - val_custom_loss: 0.1753 - lr: 1.4440e-04
# Epoch 129/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0714 - mae: 0.0476 - custom_loss: 0.0627 - val_loss: 0.1862 - val_mae: 0.1360 - val_custom_loss: 0.1774 - lr: 1.4403e-04
# Epoch 130/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0741 - mae: 0.0501 - custom_loss: 0.0653 - val_loss: 0.1875 - val_mae: 0.1375 - val_custom_loss: 0.1788 - lr: 1.4366e-04
# Epoch 131/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0732 - mae: 0.0493 - custom_loss: 0.0645 - val_loss: 0.1851 - val_mae: 0.1349 - val_custom_loss: 0.1764 - lr: 1.4330e-04
# Epoch 132/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0710 - mae: 0.0475 - custom_loss: 0.0623 - val_loss: 0.1841 - val_mae: 0.1343 - val_custom_loss: 0.1755 - lr: 1.4293e-04
# Epoch 133/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0693 - mae: 0.0461 - custom_loss: 0.0608 - val_loss: 0.1841 - val_mae: 0.1343 - val_custom_loss: 0.1755 - lr: 1.4256e-04
# Epoch 134/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0687 - mae: 0.0457 - custom_loss: 0.0602 - val_loss: 0.1843 - val_mae: 0.1345 - val_custom_loss: 0.1758 - lr: 1.4220e-04
# Epoch 135/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0685 - mae: 0.0456 - custom_loss: 0.0602 - val_loss: 0.1844 - val_mae: 0.1346 - val_custom_loss: 0.1760 - lr: 1.4183e-04
# Epoch 136/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0685 - mae: 0.0457 - custom_loss: 0.0604 - val_loss: 0.1849 - val_mae: 0.1351 - val_custom_loss: 0.1765 - lr: 1.4147e-04
# Epoch 137/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0682 - mae: 0.0456 - custom_loss: 0.0603 - val_loss: 0.1839 - val_mae: 0.1344 - val_custom_loss: 0.1756 - lr: 1.4111e-04
# Epoch 138/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0682 - mae: 0.0456 - custom_loss: 0.0600 - val_loss: 0.1838 - val_mae: 0.1344 - val_custom_loss: 0.1756 - lr: 1.4075e-04
# Epoch 139/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0672 - mae: 0.0448 - custom_loss: 0.0592 - val_loss: 0.1841 - val_mae: 0.1345 - val_custom_loss: 0.1759 - lr: 1.4039e-04
# Epoch 140/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0663 - mae: 0.0442 - custom_loss: 0.0583 - val_loss: 0.1844 - val_mae: 0.1349 - val_custom_loss: 0.1763 - lr: 1.4003e-04
# Epoch 141/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0655 - mae: 0.0436 - custom_loss: 0.0575 - val_loss: 0.1841 - val_mae: 0.1346 - val_custom_loss: 0.1761 - lr: 1.3967e-04
# Epoch 142/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0659 - mae: 0.0441 - custom_loss: 0.0580 - val_loss: 0.1864 - val_mae: 0.1367 - val_custom_loss: 0.1785 - lr: 1.3931e-04
# Epoch 143/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0673 - mae: 0.0454 - custom_loss: 0.0596 - val_loss: 0.1842 - val_mae: 0.1349 - val_custom_loss: 0.1763 - lr: 1.3895e-04
# Epoch 144/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0663 - mae: 0.0445 - custom_loss: 0.0586 - val_loss: 0.1841 - val_mae: 0.1350 - val_custom_loss: 0.1763 - lr: 1.3860e-04
# Epoch 145/150
# 30/30 [==============================] - 3s 84ms/step - loss: 0.0664 - mae: 0.0448 - custom_loss: 0.0587 - val_loss: 0.1841 - val_mae: 0.1350 - val_custom_loss: 0.1763 - lr: 1.3824e-04
# Epoch 146/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0659 - mae: 0.0444 - custom_loss: 0.0582 - val_loss: 0.1841 - val_mae: 0.1351 - val_custom_loss: 0.1764 - lr: 1.3789e-04
# Epoch 147/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0650 - mae: 0.0437 - custom_loss: 0.0575 - val_loss: 0.1842 - val_mae: 0.1350 - val_custom_loss: 0.1766 - lr: 1.3753e-04
# Epoch 148/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0639 - mae: 0.0429 - custom_loss: 0.0566 - val_loss: 0.1843 - val_mae: 0.1352 - val_custom_loss: 0.1767 - lr: 1.3718e-04
# Epoch 149/150
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0629 - mae: 0.0421 - custom_loss: 0.0555 - val_loss: 0.1839 - val_mae: 0.1350 - val_custom_loss: 0.1764 - lr: 1.3683e-04
# Epoch 150/150
# 30/30 [==============================] - 2s 84ms/step - loss: 0.0629 - mae: 0.0422 - custom_loss: 0.0556 - val_loss: 0.1854 - val_mae: 0.1364 - val_custom_loss: 0.1779 - lr: 1.3648e-04

# %%
np.shape(y_train_encoded)
# Out:
# (886, 196, 12)

# %%
test_prediction = model.predict([x_test_img,x_test_geopara])
# Out:
# 10/10 [==============================] - 2s 57ms/step

# %%
np.shape(test_prediction)
# Out:
# (296, 196, 12)

# %%
mae = hist.history['mae']
val_mae = hist.history['val_mae']
epochs = range(1, len(mae) + 1)

plt.plot(epochs, mae, '-', label='Training mae')
plt.plot(epochs, val_mae, ':', label='Validation mae')
plt.title('Training and Validation mae')
plt.xlabel('Epoch')
plt.ylabel('mae')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %%
from sklearn.metrics import r2_score
r2_result = []
for z in range(fmax):
    r2 = 0
    for i in range(12):
        temp = r2_score(y_test_encoded[:,z,i], test_prediction[:,z,i], force_finite=False)
        r2 = r2+temp
    r2_result.append(r2/12)
plt.plot(range(fmax),r2_result)

# %%
np.mean(r2_result)
# Out:
# 0.7374900914108656

# %%
mae_all = np.zeros((fmax,12))
mae_mean = np.zeros(fmax)
for z in range(fmax):
    for i in range(12):
        mae_all[z][i] = np.mean(abs(test_prediction[:,z,i]-y_test_encoded[:,z,i]))*0.5*srange[z,i]
    mae_mean[z] = np.mean(mae_all[z][:])

# %%
freq = range(fmax)
for i in range(12):
    if (i%2==0):
        plt.plot(freq,mae_all[:,i])
plt.legend(["Re[S11]","Re[S12]","Re[S13]","Re[S14]","Re[S33]","Re[S34]"])
plt.xlabel('Frequency/GHz')
plt.ylabel('S-parameter mae')
# Out:
# Text(0, 0.5, 'S-parameter mae')

# %%
mae_all = np.zeros((fmax,12))
mae_mean = np.zeros(fmax)
for z in range(fmax):
    for i in range(12):
        mae_all[z][i] = np.mean(abs(test_prediction[:,z,i]-y_test_encoded[:,z,i]))*0.5*srange[z,i]
    mae_mean[z] = np.mean(mae_all[z][:])

# %%
plt.plot(range(fmax),mae_mean)
plt.xlabel('Frequency/GHz')
plt.ylabel('Average S-parameter mae')
# Out:
# Text(0, 0.5, 'Average S-parameter mae')

# %%
freq = range(fmax)
for i in range(12):
    if (i%2==1):
        plt.plot(freq,mae_all[:,i])
plt.legend(["Im[S11]","Im[S12]","Im[S13]","Im[S14]","Im[S33]","Im[S34]"])        
plt.xlabel('Frequency/GHz')
plt.ylabel('S-parameter mae')
# Out:
# Text(0, 0.5, 'S-parameter mae')

# %%
np.mean(mae_mean)
# Out:
# 0.08359634410853682

# %%
def R_squared(y, y_pred):
  residual = tf.reduce_sum(tf.square(tf.subtract(y, y_pred)))
  total = tf.reduce_sum(tf.square(tf.subtract(y, tf.reduce_mean(y))))
  r2 = tf.subtract(1.0, tf.divide(residual, total))
  return r2
print(R_squared(y_test_encoded,test_prediction))
# Out:
# tf.Tensor(0.8223784937701745, shape=(), dtype=float64)

# %%
model.save('./models/air/mturn_196G_CNN.h5')
# Out:
# /home/hh68/.conda/envs/tensorflow/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
