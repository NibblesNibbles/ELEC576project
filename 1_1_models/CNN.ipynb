# %%
import os
import numpy as np
from keras.preprocessing import image
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
import pandas as pd
import skrf as rf

#define the targeted max frequency
fmax = 196
#define function for loading images and s-parameters
#"path" is the path for images of transformer layout
#"label" is the path for labels. In this case, labels are S-parameter associated with each images 
def load_images_from_path(path, label,length):
    images = []
    labels = []
    
    for i in range(length):
        #load images
        img = image.load_img(path+str(i)+'.png', target_size=(500, 500, 3))
        images.append(image.img_to_array(img)[138:362,138:362,:])#trim the ground margin

        #load S-parameters
        #According to symmerty, only S11,S12,S13,S14,S33,S34 are considered
        #Each S-parameter has real and imaginary parts, and hence 12 real values in total.
        results = []
        datafile = label+str(i)+".s4p"
        spt = rf.Network(datafile)
        for i in range(fmax+1):
            results.append([spt.s[i][0][0].real,spt.s[i][0][0].imag,
                            spt.s[i][0][1].real,spt.s[i][0][1].imag,
                            spt.s[i][0][2].real,spt.s[i][0][2].imag,
                            spt.s[i][0][3].real,spt.s[i][0][3].imag,
                            spt.s[i][2][2].real,spt.s[i][2][2].imag,
                            spt.s[i][2][3].real,spt.s[i][2][3].imag])     
        labels.append(results) 
    return images, labels

def show_images(images):
    fig, axes = plt.subplots(1, 8, figsize=(20, 20), subplot_kw={'xticks': [], 'yticks': []})

    for i, ax in enumerate(axes.flat):
        ax.imshow(images[i] / 255)
# Out:
# 2024-12-02 18:57:06.486354: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#load data
#geometrical parameters stored in log.txt
#order of geopara (radiusA,radiusB,turnsA,turnsB,openA,openB,outA,outB,extA,extB,ratio,outbound)
logfile = open("/rdf/shared/design_automation/Data/2409/log.txt","r")
listall = list(map(lambda item: list(map(lambda jtem: eval(jtem.strip()), item[1:-1].split(','))), logfile.read().strip().split('\n')))
tabular_data = np.array(listall)

#load images and s-parameters
length = 4100
images, labels = load_images_from_path('/rdf/shared/design_automation/Data/2409/PNG/', '/rdf/shared/design_automation/Data/2409/SPData/',length)
show_images(images)
geoparas = []
images11 = []
labels11 = []

for kk in range(length):
    #select 1 turn and 1 turn transformers
   if((tabular_data[kk,2]==1) and (tabular_data[kk,3]==1)):
       #geoparas only includes the variable parameters in our designs. 
       #Constants at this design stages are excluded 
        geoparas.append(tabular_data[kk,(0,1,4,5,4,5,6,7,12,13)])
        images11.append(images[kk])
        labels11.append(labels[kk])
print(np.shape(geoparas))
# Out:
# (2177, 10)

# %%
#load data from the second folder
#geometrical parameters stored in log.txt
#order of geopara (radiusA,radiusB,turnsA,turnsB,openA,openB,outA,outB,extA,extB,ratio,outbound)
logfile = open("/rdf/shared/design_automation/Data/2409_2/log.txt","r")
listall = list(map(lambda item: list(map(lambda jtem: eval(jtem.strip()), item[1:-1].split(','))), logfile.read().strip().split('\n')))
tabular_data = np.array(listall)

#load images and s-parameters
#length = len(listall)-3
length = 2500
images, labels = load_images_from_path('/rdf/shared/design_automation/Data/2409_2/PNG/', '/rdf/shared/design_automation/Data/2409_2/SPData/',length)


for kk in range(length):
    #select 1 turn and 1 turn transformers
   if((tabular_data[kk,2]==1) and (tabular_data[kk,3]==1)):
       #geoparas only includes the variable parameters in our designs. 
       #Constants at this design stages are excluded 
        geoparas.append(tabular_data[kk,(0,1,4,5,4,5,6,7,12,13)])
        images11.append(images[kk])
        labels11.append(labels[kk])
print(np.shape(geoparas))
# Out:
# (2651, 10)

# %%
#normalize geometrical inputs
geoparas_temp = np.array(geoparas)
geoparas = np.zeros(np.shape(geoparas_temp))
for i in range(len(geoparas)):
    for j in range(8):
        geoparas[i,j]= (geoparas_temp[i,j]-np.mean(geoparas_temp[:,j]))/np.std(geoparas_temp[:,j])

# %%
#construct the datasets
class item:
  def __init__(self, image,geopara,label ):
    self.image = image
    self.geopara = geopara
    self.label = label

data = []
for i in range(len(images11)):
    data.append(item(images11[i],geoparas[i],labels11[i]))

#np.random.shuffle(data)

# %%
#define the split length for training, validation and test datasets
length = len(images11)
split1 = int(0.6*length)
split2 = int(0.8*length)
data_train = data[0:split1]
data_valid = data[split1:split2]
data_test = data[split2:]

# %%
#Separate the training, validation and test datasets 
train_images = []
train_labels = []
train_geoparas = []
valid_images = []
valid_labels = []
valid_geoparas = []
test_images = []
test_labels = []
test_geoparas = []


#The targeted frequency span up to fmax, with 1GHz step
s_max = np.zeros((fmax,12))
s_min = np.zeros((fmax,12))
srange = np.zeros((fmax,12))


for i in range(len(data_train)):
    train_images.append(data_train[i].image)
    train_geoparas.append(data_train[i].geopara)
    train_labels.append(data_train[i].label)
x_train_img = np.array(train_images) / 255
x_train_geopara = np.array(train_geoparas)
y_train_encoded = np.array(train_labels)[:,1:fmax+1,:]


for i in range(len(data_valid)):
    valid_images.append(data_valid[i].image)
    valid_geoparas.append(data_valid[i].geopara)
    valid_labels.append(data_valid[i].label)
x_valid_img = np.array(valid_images) / 255
x_valid_geopara = np.array(valid_geoparas)
y_valid_encoded = np.array(valid_labels)[:,1:fmax+1,:]


for i in range(len(data_test)):
    test_images.append(data_test[i].image)
    test_geoparas.append(data_test[i].geopara)
    test_labels.append(data_test[i].label)
x_test_img = np.array(test_images) / 255
x_test_geopara = np.array(test_geoparas)
y_test_encoded = np.array(test_labels)[:,1:fmax+1,:]

#normalize the s-parameters for each frequency point
for z in range(fmax):
    for i in range(12):
        s_max[z,i] = max(max(y_train_encoded[:,z,i]),max(y_valid_encoded[:,z,i]),max(y_test_encoded[:,z,i]))
        s_min[z,i] = min(min(y_train_encoded[:,z,i]),min(y_valid_encoded[:,z,i]),min(y_test_encoded[:,z,i]))
        srange[z,i] = s_max[z,i]-s_min[z,i]
    
    for i in range(12):
        y_train_encoded[:,z,i] = 2*(y_train_encoded[:,z,i]-s_min[z,i])/srange[z,i]-1

    for i in range(12):
        y_valid_encoded[:,z,i] = 2*(y_valid_encoded[:,z,i]-s_min[z,i])/srange[z,i]-1
    
    for i in range(12):
        y_test_encoded[:,z,i] = 2*(y_test_encoded[:,z,i]-s_min[z,i])/srange[z,i]-1

# %%
def custom_loss(y_true, y_pred):
    Lf = tf.math.sqrt(tf.reduce_mean(tf.square(y_true - y_pred),axis=1))
#    return tf.math.log(tf.reduce_mean(Lf))
    return (tf.reduce_mean(Lf))

# %%
from keras import Sequential, Input, Model, regularizers
from keras.layers import Conv2D, MaxPooling2D,Dropout, Reshape, BatchNormalization,Conv1DTranspose,Conv1D
from keras.layers import Flatten, Dense, Concatenate
learning_rate = 2e-4
n_unet = 8

models = []

inp1 = Input((224,224,3),)
'''
model1 = (Conv2D(n_unet,(3,3),padding='same', activation='relu', input_shape=(224, 224, 3), kernel_regularizer=regularizers.l2(0.01)))(inp1)
model1 = (MaxPooling2D(2, 2))(model1)
model1 = (Conv2D(n_unet*2, (3, 3), padding='same',activation='relu'))(model1)

model1 = (MaxPooling2D(2, 2))(model1)
#model1 = BatchNormalization()(model1)
model1 = (Conv2D(n_unet*2, (3, 3),  padding='same',activation='relu'))(model1)

model1 = (MaxPooling2D(2, 2))(model1)
#model1 = BatchNormalization()(model1)
model1 = (Conv2D(n_unet*4, (3, 3), padding='same', activation='relu'))(model1)

layer1 = (MaxPooling2D(2, 2))(model1)
#model1 = Dropout(0.3)(model1)
#model1 = BatchNormalization()(model1)
layer2 = (Conv2D(n_unet*8, (3, 3),padding='same', activation='relu'))(layer1)
layer2 = (MaxPooling2D(2, 2))(layer2)

layer3 = (Conv2D(n_unet*16, (3, 3),padding='same', activation='relu'))(layer2)
layer3 = (MaxPooling2D(2, 2))(layer3)

layer4 = (Conv2D(n_unet*32, (3, 3),padding='same', activation='relu'))(layer3)
layer4 = (MaxPooling2D(2, 2))(layer4)


#backward
layer4 = Reshape((1,n_unet*32))(layer4)
layer4 = (Conv1DTranspose(n_unet*16,9,1, activation='relu'))(layer4)

layer3 = Reshape((9,n_unet*16))(layer3)
layer3 = Concatenate()([layer3,layer4])
layer3 = (Conv1D(n_unet*16,3,padding='same', activation='relu'))(layer3)
layer3 = (Conv1DTranspose(n_unet*8,9,5, activation='relu'))(layer3)


layer2 = Reshape((49,n_unet*8))(layer2)
layer2 = Concatenate()([layer2,layer3])
layer2 = (Conv1D(n_unet*8,3,padding='same', activation='relu'))(layer2)
layer2 = (Conv1DTranspose(n_unet*4,3,4, activation='relu'))(layer2)

layer1 = Reshape((196,n_unet*4))(layer1)
layer1 = Concatenate()([layer1,layer2])
layer1 = (Conv1D(n_unet*4,3,padding='same', activation='relu'))(layer2)
model1 = Flatten()(layer1)
models.append(model1)
'''
inp2 = Input(10,)
'''
model2=(Dense(512,activation='relu',input_shape = (8,),kernel_regularizer=regularizers.l2(0.10)))(inp2)
model2=(Dense(512,activation='relu'))(model2)
model2=(Dense(512,activation='relu'))(model2)
model2=(Dense(512,activation='relu'))(model2)
model2=(Dense(512,activation='relu'))(model2)
models.append(model2)
'''
model3 = (Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3), kernel_regularizer=regularizers.l2(0.05)))(inp1)
model3 = (MaxPooling2D(2, 2))(model3)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = BatchNormalization()(model1)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = BatchNormalization()(model1)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = Dropout(0.3)(model1)
#model1 = BatchNormalization()(model1)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = BatchNormalization()(model1)
#model1 = Dropout(0.3)(model1)
model3 = Flatten()(model3)
model3 = Dense(512,activation='relu')(model3)

models.append(model3)
out = Concatenate()(models)

out = (Dense(fmax*12, activation='tanh'))(out)
out = Reshape((fmax,12))(out)
model = Model([inp1,inp2],out)
model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=learning_rate), loss=custom_loss, metrics=['mae',custom_loss])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_5 (Conv2D)           (None, 222, 222, 32)         896       ['input_3[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 111, 111, 32)         0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 109, 109, 128)        36992     ['max_pooling2d_5[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 54, 54, 128)          0         ['conv2d_6[0][0]']
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 52, 52, 128)          147584    ['max_pooling2d_6[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 26, 26, 128)          0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 24, 24, 128)          147584    ['max_pooling2d_7[0][0]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 12, 12, 128)          0         ['conv2d_8[0][0]']
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 10, 10, 128)          147584    ['max_pooling2d_8[0][0]']
#
#  max_pooling2d_9 (MaxPoolin  (None, 5, 5, 128)            0         ['conv2d_9[0][0]']
#  g2D)
#
#  flatten_1 (Flatten)         (None, 3200)                 0         ['max_pooling2d_9[0][0]']
#
#  dense_2 (Dense)             (None, 512)                  1638912   ['flatten_1[0][0]']
#
#  concatenate_1 (Concatenate  (None, 512)                  0         ['dense_2[0][0]']
#  )
#
#  dense_3 (Dense)             (None, 2352)                 1206576   ['concatenate_1[0][0]']
#
#  input_4 (InputLayer)        [(None, 10)]                 0         []
#
#  reshape_1 (Reshape)         (None, 196, 12)              0         ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 3326128 (12.69 MB)
# Trainable params: 3326128 (12.69 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
EPOCHS = 300
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: learning_rate * 0.95**(epoch/20))
hist = model.fit([x_train_img,x_train_geopara], y_train_encoded, validation_data=([x_valid_img,x_valid_geopara], y_valid_encoded), batch_size=30, epochs = EPOCHS,callbacks=[lr_schedule])
# Out:
# Epoch 1/300
# 53/53 [==============================] - 11s 106ms/step - loss: 0.6185 - mae: 0.3162 - custom_loss: 0.3705 - val_loss: 0.5359 - val_mae: 0.2681 - val_custom_loss: 0.3160 - lr: 2.0000e-04
# Epoch 2/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.4763 - mae: 0.2336 - custom_loss: 0.2784 - val_loss: 0.4217 - val_mae: 0.2044 - val_custom_loss: 0.2459 - lr: 1.9949e-04
# Epoch 3/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.3850 - mae: 0.1873 - custom_loss: 0.2265 - val_loss: 0.3470 - val_mae: 0.1679 - val_custom_loss: 0.2047 - lr: 1.9898e-04
# Epoch 4/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.3175 - mae: 0.1529 - custom_loss: 0.1868 - val_loss: 0.2897 - val_mae: 0.1378 - val_custom_loss: 0.1703 - lr: 1.9847e-04
# Epoch 5/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.2724 - mae: 0.1309 - custom_loss: 0.1608 - val_loss: 0.2563 - val_mae: 0.1241 - val_custom_loss: 0.1528 - lr: 1.9796e-04
# Epoch 6/300
# 53/53 [==============================] - 5s 95ms/step - loss: 0.2412 - mae: 0.1164 - custom_loss: 0.1434 - val_loss: 0.2379 - val_mae: 0.1197 - val_custom_loss: 0.1466 - lr: 1.9745e-04
# Epoch 7/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.2191 - mae: 0.1075 - custom_loss: 0.1324 - val_loss: 0.2079 - val_mae: 0.1021 - val_custom_loss: 0.1264 - lr: 1.9695e-04
# Epoch 8/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.2009 - mae: 0.1000 - custom_loss: 0.1230 - val_loss: 0.1937 - val_mae: 0.0971 - val_custom_loss: 0.1199 - lr: 1.9644e-04
# Epoch 9/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.1856 - mae: 0.0931 - custom_loss: 0.1146 - val_loss: 0.1818 - val_mae: 0.0925 - val_custom_loss: 0.1143 - lr: 1.9594e-04
# Epoch 10/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.1740 - mae: 0.0884 - custom_loss: 0.1089 - val_loss: 0.1712 - val_mae: 0.0881 - val_custom_loss: 0.1090 - lr: 1.9544e-04
# Epoch 11/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.1656 - mae: 0.0855 - custom_loss: 0.1053 - val_loss: 0.1624 - val_mae: 0.0846 - val_custom_loss: 0.1047 - lr: 1.9494e-04
# Epoch 12/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.1556 - mae: 0.0807 - custom_loss: 0.0994 - val_loss: 0.1572 - val_mae: 0.0836 - val_custom_loss: 0.1033 - lr: 1.9444e-04
# Epoch 13/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.1502 - mae: 0.0793 - custom_loss: 0.0976 - val_loss: 0.1521 - val_mae: 0.0825 - val_custom_loss: 0.1016 - lr: 1.9394e-04
# Epoch 14/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.1459 - mae: 0.0784 - custom_loss: 0.0964 - val_loss: 0.1445 - val_mae: 0.0782 - val_custom_loss: 0.0967 - lr: 1.9344e-04
# Epoch 15/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.1399 - mae: 0.0756 - custom_loss: 0.0930 - val_loss: 0.1421 - val_mae: 0.0784 - val_custom_loss: 0.0967 - lr: 1.9295e-04
# Epoch 16/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.1337 - mae: 0.0724 - custom_loss: 0.0892 - val_loss: 0.1356 - val_mae: 0.0747 - val_custom_loss: 0.0924 - lr: 1.9245e-04
# Epoch 17/300
# 53/53 [==============================] - 5s 99ms/step - loss: 0.1301 - mae: 0.0711 - custom_loss: 0.0876 - val_loss: 0.1340 - val_mae: 0.0751 - val_custom_loss: 0.0928 - lr: 1.9196e-04
# Epoch 18/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.1258 - mae: 0.0692 - custom_loss: 0.0852 - val_loss: 0.1290 - val_mae: 0.0725 - val_custom_loss: 0.0896 - lr: 1.9147e-04
# Epoch 19/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.1237 - mae: 0.0689 - custom_loss: 0.0848 - val_loss: 0.1275 - val_mae: 0.0726 - val_custom_loss: 0.0897 - lr: 1.9098e-04
# Epoch 20/300
# 53/53 [==============================] - 5s 97ms/step - loss: 0.1189 - mae: 0.0662 - custom_loss: 0.0815 - val_loss: 0.1232 - val_mae: 0.0703 - val_custom_loss: 0.0869 - lr: 1.9049e-04
# Epoch 21/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.1157 - mae: 0.0647 - custom_loss: 0.0798 - val_loss: 0.1212 - val_mae: 0.0698 - val_custom_loss: 0.0862 - lr: 1.9000e-04
# Epoch 22/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.1134 - mae: 0.0641 - custom_loss: 0.0789 - val_loss: 0.1189 - val_mae: 0.0690 - val_custom_loss: 0.0853 - lr: 1.8951e-04
# Epoch 23/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.1103 - mae: 0.0625 - custom_loss: 0.0770 - val_loss: 0.1146 - val_mae: 0.0665 - val_custom_loss: 0.0822 - lr: 1.8903e-04
# Epoch 24/300
# 53/53 [==============================] - 5s 95ms/step - loss: 0.1081 - mae: 0.0617 - custom_loss: 0.0760 - val_loss: 0.1136 - val_mae: 0.0668 - val_custom_loss: 0.0824 - lr: 1.8854e-04
# Epoch 25/300
# 53/53 [==============================] - 5s 95ms/step - loss: 0.1054 - mae: 0.0604 - custom_loss: 0.0744 - val_loss: 0.1104 - val_mae: 0.0649 - val_custom_loss: 0.0803 - lr: 1.8806e-04
# Epoch 26/300
# 53/53 [==============================] - 5s 95ms/step - loss: 0.1034 - mae: 0.0597 - custom_loss: 0.0735 - val_loss: 0.1091 - val_mae: 0.0648 - val_custom_loss: 0.0800 - lr: 1.8758e-04
# Epoch 27/300
# 53/53 [==============================] - 5s 97ms/step - loss: 0.1017 - mae: 0.0591 - custom_loss: 0.0728 - val_loss: 0.1072 - val_mae: 0.0641 - val_custom_loss: 0.0791 - lr: 1.8710e-04
# Epoch 28/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0989 - mae: 0.0576 - custom_loss: 0.0710 - val_loss: 0.1061 - val_mae: 0.0639 - val_custom_loss: 0.0789 - lr: 1.8662e-04
# Epoch 29/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0989 - mae: 0.0584 - custom_loss: 0.0718 - val_loss: 0.1056 - val_mae: 0.0642 - val_custom_loss: 0.0792 - lr: 1.8614e-04
# Epoch 30/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0955 - mae: 0.0563 - custom_loss: 0.0693 - val_loss: 0.1043 - val_mae: 0.0639 - val_custom_loss: 0.0788 - lr: 1.8566e-04
# Epoch 31/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0946 - mae: 0.0562 - custom_loss: 0.0692 - val_loss: 0.1050 - val_mae: 0.0652 - val_custom_loss: 0.0803 - lr: 1.8519e-04
# Epoch 32/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0927 - mae: 0.0553 - custom_loss: 0.0680 - val_loss: 0.1020 - val_mae: 0.0633 - val_custom_loss: 0.0780 - lr: 1.8471e-04
# Epoch 33/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0928 - mae: 0.0560 - custom_loss: 0.0689 - val_loss: 0.1004 - val_mae: 0.0626 - val_custom_loss: 0.0771 - lr: 1.8424e-04
# Epoch 34/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0896 - mae: 0.0539 - custom_loss: 0.0663 - val_loss: 0.0992 - val_mae: 0.0620 - val_custom_loss: 0.0765 - lr: 1.8377e-04
# Epoch 35/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0886 - mae: 0.0536 - custom_loss: 0.0660 - val_loss: 0.0967 - val_mae: 0.0605 - val_custom_loss: 0.0747 - lr: 1.8330e-04
# Epoch 36/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0869 - mae: 0.0527 - custom_loss: 0.0649 - val_loss: 0.0968 - val_mae: 0.0612 - val_custom_loss: 0.0753 - lr: 1.8283e-04
# Epoch 37/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0852 - mae: 0.0519 - custom_loss: 0.0639 - val_loss: 0.0951 - val_mae: 0.0603 - val_custom_loss: 0.0743 - lr: 1.8236e-04
# Epoch 38/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0852 - mae: 0.0524 - custom_loss: 0.0645 - val_loss: 0.0941 - val_mae: 0.0600 - val_custom_loss: 0.0739 - lr: 1.8189e-04
# Epoch 39/300
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0835 - mae: 0.0514 - custom_loss: 0.0633 - val_loss: 0.0941 - val_mae: 0.0603 - val_custom_loss: 0.0743 - lr: 1.8143e-04
# Epoch 40/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0817 - mae: 0.0503 - custom_loss: 0.0620 - val_loss: 0.0929 - val_mae: 0.0599 - val_custom_loss: 0.0737 - lr: 1.8096e-04
# Epoch 41/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0814 - mae: 0.0506 - custom_loss: 0.0623 - val_loss: 0.0923 - val_mae: 0.0599 - val_custom_loss: 0.0736 - lr: 1.8050e-04
# Epoch 42/300
# 53/53 [==============================] - 5s 99ms/step - loss: 0.0802 - mae: 0.0499 - custom_loss: 0.0615 - val_loss: 0.0921 - val_mae: 0.0600 - val_custom_loss: 0.0739 - lr: 1.8004e-04
# Epoch 43/300
# 53/53 [==============================] - 6s 106ms/step - loss: 0.0783 - mae: 0.0488 - custom_loss: 0.0602 - val_loss: 0.0905 - val_mae: 0.0591 - val_custom_loss: 0.0728 - lr: 1.7958e-04
# Epoch 44/300
# 53/53 [==============================] - 6s 108ms/step - loss: 0.0778 - mae: 0.0488 - custom_loss: 0.0601 - val_loss: 0.0896 - val_mae: 0.0587 - val_custom_loss: 0.0723 - lr: 1.7912e-04
# Epoch 45/300
# 53/53 [==============================] - 5s 101ms/step - loss: 0.0775 - mae: 0.0490 - custom_loss: 0.0603 - val_loss: 0.0886 - val_mae: 0.0583 - val_custom_loss: 0.0718 - lr: 1.7866e-04
# Epoch 46/300
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0768 - mae: 0.0487 - custom_loss: 0.0600 - val_loss: 0.0885 - val_mae: 0.0588 - val_custom_loss: 0.0722 - lr: 1.7820e-04
# Epoch 47/300
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0755 - mae: 0.0480 - custom_loss: 0.0591 - val_loss: 0.0871 - val_mae: 0.0578 - val_custom_loss: 0.0711 - lr: 1.7774e-04
# Epoch 48/300
# 53/53 [==============================] - 5s 103ms/step - loss: 0.0739 - mae: 0.0470 - custom_loss: 0.0579 - val_loss: 0.0869 - val_mae: 0.0579 - val_custom_loss: 0.0713 - lr: 1.7729e-04
# Epoch 49/300
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0750 - mae: 0.0483 - custom_loss: 0.0594 - val_loss: 0.0867 - val_mae: 0.0580 - val_custom_loss: 0.0714 - lr: 1.7683e-04
# Epoch 50/300
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0723 - mae: 0.0462 - custom_loss: 0.0570 - val_loss: 0.0857 - val_mae: 0.0575 - val_custom_loss: 0.0708 - lr: 1.7638e-04
# Epoch 51/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0719 - mae: 0.0463 - custom_loss: 0.0570 - val_loss: 0.0852 - val_mae: 0.0574 - val_custom_loss: 0.0706 - lr: 1.7593e-04
# Epoch 52/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0712 - mae: 0.0459 - custom_loss: 0.0566 - val_loss: 0.0851 - val_mae: 0.0579 - val_custom_loss: 0.0709 - lr: 1.7548e-04
# Epoch 53/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0702 - mae: 0.0454 - custom_loss: 0.0559 - val_loss: 0.0832 - val_mae: 0.0564 - val_custom_loss: 0.0694 - lr: 1.7503e-04
# Epoch 54/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0712 - mae: 0.0466 - custom_loss: 0.0573 - val_loss: 0.0851 - val_mae: 0.0582 - val_custom_loss: 0.0715 - lr: 1.7458e-04
# Epoch 55/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0688 - mae: 0.0449 - custom_loss: 0.0552 - val_loss: 0.0831 - val_mae: 0.0568 - val_custom_loss: 0.0699 - lr: 1.7413e-04
# Epoch 56/300
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0679 - mae: 0.0443 - custom_loss: 0.0546 - val_loss: 0.0826 - val_mae: 0.0566 - val_custom_loss: 0.0696 - lr: 1.7369e-04
# Epoch 57/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0683 - mae: 0.0449 - custom_loss: 0.0553 - val_loss: 0.0824 - val_mae: 0.0568 - val_custom_loss: 0.0698 - lr: 1.7324e-04
# Epoch 58/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0670 - mae: 0.0440 - custom_loss: 0.0542 - val_loss: 0.0817 - val_mae: 0.0565 - val_custom_loss: 0.0693 - lr: 1.7280e-04
# Epoch 59/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0667 - mae: 0.0441 - custom_loss: 0.0542 - val_loss: 0.0811 - val_mae: 0.0562 - val_custom_loss: 0.0690 - lr: 1.7236e-04
# Epoch 60/300
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0656 - mae: 0.0434 - custom_loss: 0.0534 - val_loss: 0.0800 - val_mae: 0.0554 - val_custom_loss: 0.0681 - lr: 1.7192e-04
# Epoch 61/300
# 53/53 [==============================] - 5s 102ms/step - loss: 0.0669 - mae: 0.0447 - custom_loss: 0.0549 - val_loss: 0.0804 - val_mae: 0.0561 - val_custom_loss: 0.0688 - lr: 1.7147e-04
# Epoch 62/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0642 - mae: 0.0426 - custom_loss: 0.0525 - val_loss: 0.0806 - val_mae: 0.0563 - val_custom_loss: 0.0692 - lr: 1.7104e-04
# Epoch 63/300
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0647 - mae: 0.0432 - custom_loss: 0.0532 - val_loss: 0.0796 - val_mae: 0.0558 - val_custom_loss: 0.0685 - lr: 1.7060e-04
# Epoch 64/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0641 - mae: 0.0430 - custom_loss: 0.0529 - val_loss: 0.0791 - val_mae: 0.0556 - val_custom_loss: 0.0682 - lr: 1.7016e-04
# Epoch 65/300
# 53/53 [==============================] - 5s 97ms/step - loss: 0.0629 - mae: 0.0421 - custom_loss: 0.0519 - val_loss: 0.0797 - val_mae: 0.0563 - val_custom_loss: 0.0690 - lr: 1.6972e-04
# Epoch 66/300
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0626 - mae: 0.0421 - custom_loss: 0.0518 - val_loss: 0.0779 - val_mae: 0.0549 - val_custom_loss: 0.0675 - lr: 1.6929e-04
# Epoch 67/300
# 53/53 [==============================] - 5s 103ms/step - loss: 0.0612 - mae: 0.0411 - custom_loss: 0.0506 - val_loss: 0.0779 - val_mae: 0.0551 - val_custom_loss: 0.0677 - lr: 1.6886e-04
# Epoch 68/300
# 53/53 [==============================] - 5s 101ms/step - loss: 0.0610 - mae: 0.0411 - custom_loss: 0.0507 - val_loss: 0.0779 - val_mae: 0.0552 - val_custom_loss: 0.0678 - lr: 1.6842e-04
# Epoch 69/300
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0618 - mae: 0.0420 - custom_loss: 0.0516 - val_loss: 0.0773 - val_mae: 0.0550 - val_custom_loss: 0.0675 - lr: 1.6799e-04
# Epoch 70/300
# 53/53 [==============================] - 6s 105ms/step - loss: 0.0608 - mae: 0.0413 - custom_loss: 0.0509 - val_loss: 0.0769 - val_mae: 0.0548 - val_custom_loss: 0.0673 - lr: 1.6756e-04
# Epoch 71/300
# 53/53 [==============================] - 6s 114ms/step - loss: 0.0602 - mae: 0.0410 - custom_loss: 0.0505 - val_loss: 0.0766 - val_mae: 0.0547 - val_custom_loss: 0.0672 - lr: 1.6713e-04
# Epoch 72/300
# 53/53 [==============================] - 6s 102ms/step - loss: 0.0588 - mae: 0.0400 - custom_loss: 0.0493 - val_loss: 0.0765 - val_mae: 0.0549 - val_custom_loss: 0.0672 - lr: 1.6671e-04
# Epoch 73/300
# 53/53 [==============================] - 5s 97ms/step - loss: 0.0584 - mae: 0.0398 - custom_loss: 0.0490 - val_loss: 0.0761 - val_mae: 0.0546 - val_custom_loss: 0.0670 - lr: 1.6628e-04
# Epoch 74/300
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0576 - mae: 0.0392 - custom_loss: 0.0484 - val_loss: 0.0756 - val_mae: 0.0544 - val_custom_loss: 0.0667 - lr: 1.6585e-04
# Epoch 75/300
# 53/53 [==============================] - 6s 105ms/step - loss: 0.0581 - mae: 0.0399 - custom_loss: 0.0491 - val_loss: 0.0767 - val_mae: 0.0554 - val_custom_loss: 0.0680 - lr: 1.6543e-04
# Epoch 76/300
# 53/53 [==============================] - 5s 103ms/step - loss: 0.0572 - mae: 0.0392 - custom_loss: 0.0483 - val_loss: 0.0763 - val_mae: 0.0552 - val_custom_loss: 0.0677 - lr: 1.6500e-04
# Epoch 77/300
# 53/53 [==============================] - 5s 101ms/step - loss: 0.0570 - mae: 0.0392 - custom_loss: 0.0483 - val_loss: 0.0747 - val_mae: 0.0540 - val_custom_loss: 0.0663 - lr: 1.6458e-04
# Epoch 78/300
# 53/53 [==============================] - 5s 103ms/step - loss: 0.0560 - mae: 0.0385 - custom_loss: 0.0475 - val_loss: 0.0758 - val_mae: 0.0551 - val_custom_loss: 0.0676 - lr: 1.6416e-04
# Epoch 79/300
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0564 - mae: 0.0390 - custom_loss: 0.0480 - val_loss: 0.0749 - val_mae: 0.0545 - val_custom_loss: 0.0669 - lr: 1.6374e-04
# Epoch 80/300
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0552 - mae: 0.0381 - custom_loss: 0.0470 - val_loss: 0.0757 - val_mae: 0.0553 - val_custom_loss: 0.0678 - lr: 1.6332e-04
# Epoch 81/300
# 53/53 [==============================] - 5s 97ms/step - loss: 0.0556 - mae: 0.0386 - custom_loss: 0.0476 - val_loss: 0.0744 - val_mae: 0.0543 - val_custom_loss: 0.0666 - lr: 1.6290e-04
# Epoch 82/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0551 - mae: 0.0383 - custom_loss: 0.0472 - val_loss: 0.0734 - val_mae: 0.0536 - val_custom_loss: 0.0658 - lr: 1.6248e-04
# Epoch 83/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0557 - mae: 0.0389 - custom_loss: 0.0479 - val_loss: 0.0763 - val_mae: 0.0563 - val_custom_loss: 0.0688 - lr: 1.6207e-04
# Epoch 84/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0544 - mae: 0.0380 - custom_loss: 0.0468 - val_loss: 0.0739 - val_mae: 0.0543 - val_custom_loss: 0.0665 - lr: 1.6165e-04
# Epoch 85/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0532 - mae: 0.0370 - custom_loss: 0.0456 - val_loss: 0.0749 - val_mae: 0.0553 - val_custom_loss: 0.0677 - lr: 1.6124e-04
# Epoch 86/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0531 - mae: 0.0371 - custom_loss: 0.0458 - val_loss: 0.0739 - val_mae: 0.0544 - val_custom_loss: 0.0668 - lr: 1.6083e-04
# Epoch 87/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0527 - mae: 0.0368 - custom_loss: 0.0455 - val_loss: 0.0725 - val_mae: 0.0536 - val_custom_loss: 0.0656 - lr: 1.6041e-04
# Epoch 88/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0523 - mae: 0.0366 - custom_loss: 0.0452 - val_loss: 0.0733 - val_mae: 0.0542 - val_custom_loss: 0.0664 - lr: 1.6000e-04
# Epoch 89/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0520 - mae: 0.0364 - custom_loss: 0.0450 - val_loss: 0.0727 - val_mae: 0.0537 - val_custom_loss: 0.0659 - lr: 1.5959e-04
# Epoch 90/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0520 - mae: 0.0366 - custom_loss: 0.0451 - val_loss: 0.0728 - val_mae: 0.0540 - val_custom_loss: 0.0661 - lr: 1.5918e-04
# Epoch 91/300
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0515 - mae: 0.0362 - custom_loss: 0.0447 - val_loss: 0.0722 - val_mae: 0.0535 - val_custom_loss: 0.0657 - lr: 1.5878e-04
# Epoch 92/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0510 - mae: 0.0359 - custom_loss: 0.0443 - val_loss: 0.0715 - val_mae: 0.0531 - val_custom_loss: 0.0651 - lr: 1.5837e-04
# Epoch 93/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0509 - mae: 0.0359 - custom_loss: 0.0443 - val_loss: 0.0723 - val_mae: 0.0538 - val_custom_loss: 0.0660 - lr: 1.5796e-04
# Epoch 94/300
# 53/53 [==============================] - 5s 99ms/step - loss: 0.0512 - mae: 0.0362 - custom_loss: 0.0447 - val_loss: 0.0725 - val_mae: 0.0542 - val_custom_loss: 0.0663 - lr: 1.5756e-04
# Epoch 95/300
# 53/53 [==============================] - 5s 102ms/step - loss: 0.0504 - mae: 0.0356 - custom_loss: 0.0440 - val_loss: 0.0716 - val_mae: 0.0534 - val_custom_loss: 0.0655 - lr: 1.5716e-04
# Epoch 96/300
# 53/53 [==============================] - 5s 102ms/step - loss: 0.0497 - mae: 0.0352 - custom_loss: 0.0434 - val_loss: 0.0736 - val_mae: 0.0551 - val_custom_loss: 0.0676 - lr: 1.5675e-04
# Epoch 97/300
# 53/53 [==============================] - 5s 99ms/step - loss: 0.0493 - mae: 0.0349 - custom_loss: 0.0431 - val_loss: 0.0714 - val_mae: 0.0534 - val_custom_loss: 0.0654 - lr: 1.5635e-04
# Epoch 98/300
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0489 - mae: 0.0346 - custom_loss: 0.0428 - val_loss: 0.0713 - val_mae: 0.0534 - val_custom_loss: 0.0654 - lr: 1.5595e-04
# Epoch 99/300
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0485 - mae: 0.0344 - custom_loss: 0.0426 - val_loss: 0.0722 - val_mae: 0.0543 - val_custom_loss: 0.0664 - lr: 1.5555e-04
# Epoch 100/300
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0489 - mae: 0.0348 - custom_loss: 0.0430 - val_loss: 0.0709 - val_mae: 0.0532 - val_custom_loss: 0.0653 - lr: 1.5515e-04
# Epoch 101/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0485 - mae: 0.0346 - custom_loss: 0.0427 - val_loss: 0.0704 - val_mae: 0.0529 - val_custom_loss: 0.0648 - lr: 1.5476e-04
# Epoch 102/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0505 - mae: 0.0363 - custom_loss: 0.0448 - val_loss: 0.0722 - val_mae: 0.0545 - val_custom_loss: 0.0667 - lr: 1.5436e-04
# Epoch 103/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0483 - mae: 0.0345 - custom_loss: 0.0426 - val_loss: 0.0720 - val_mae: 0.0544 - val_custom_loss: 0.0665 - lr: 1.5396e-04
# Epoch 104/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0478 - mae: 0.0341 - custom_loss: 0.0422 - val_loss: 0.0699 - val_mae: 0.0527 - val_custom_loss: 0.0646 - lr: 1.5357e-04
# Epoch 105/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0466 - mae: 0.0332 - custom_loss: 0.0410 - val_loss: 0.0701 - val_mae: 0.0530 - val_custom_loss: 0.0649 - lr: 1.5318e-04
# Epoch 106/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0465 - mae: 0.0332 - custom_loss: 0.0410 - val_loss: 0.0717 - val_mae: 0.0543 - val_custom_loss: 0.0666 - lr: 1.5278e-04
# Epoch 107/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0472 - mae: 0.0338 - custom_loss: 0.0418 - val_loss: 0.0709 - val_mae: 0.0539 - val_custom_loss: 0.0658 - lr: 1.5239e-04
# Epoch 108/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0462 - mae: 0.0331 - custom_loss: 0.0409 - val_loss: 0.0707 - val_mae: 0.0536 - val_custom_loss: 0.0657 - lr: 1.5200e-04
# Epoch 109/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0459 - mae: 0.0329 - custom_loss: 0.0407 - val_loss: 0.0704 - val_mae: 0.0534 - val_custom_loss: 0.0655 - lr: 1.5161e-04
# Epoch 110/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0459 - mae: 0.0329 - custom_loss: 0.0407 - val_loss: 0.0709 - val_mae: 0.0539 - val_custom_loss: 0.0660 - lr: 1.5123e-04
# Epoch 111/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0451 - mae: 0.0324 - custom_loss: 0.0401 - val_loss: 0.0699 - val_mae: 0.0532 - val_custom_loss: 0.0651 - lr: 1.5084e-04
# Epoch 112/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0461 - mae: 0.0332 - custom_loss: 0.0411 - val_loss: 0.0705 - val_mae: 0.0538 - val_custom_loss: 0.0657 - lr: 1.5045e-04
# Epoch 113/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0452 - mae: 0.0326 - custom_loss: 0.0403 - val_loss: 0.0698 - val_mae: 0.0532 - val_custom_loss: 0.0651 - lr: 1.5007e-04
# Epoch 114/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0449 - mae: 0.0324 - custom_loss: 0.0400 - val_loss: 0.0701 - val_mae: 0.0534 - val_custom_loss: 0.0654 - lr: 1.4968e-04
# Epoch 115/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0444 - mae: 0.0320 - custom_loss: 0.0395 - val_loss: 0.0695 - val_mae: 0.0530 - val_custom_loss: 0.0649 - lr: 1.4930e-04
# Epoch 116/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0439 - mae: 0.0316 - custom_loss: 0.0391 - val_loss: 0.0691 - val_mae: 0.0527 - val_custom_loss: 0.0646 - lr: 1.4892e-04
# Epoch 117/300
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0438 - mae: 0.0315 - custom_loss: 0.0390 - val_loss: 0.0692 - val_mae: 0.0529 - val_custom_loss: 0.0647 - lr: 1.4853e-04
# Epoch 118/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0435 - mae: 0.0314 - custom_loss: 0.0389 - val_loss: 0.0700 - val_mae: 0.0537 - val_custom_loss: 0.0656 - lr: 1.4815e-04
# Epoch 119/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0439 - mae: 0.0318 - custom_loss: 0.0393 - val_loss: 0.0692 - val_mae: 0.0530 - val_custom_loss: 0.0649 - lr: 1.4777e-04
# Epoch 120/300
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0434 - mae: 0.0313 - custom_loss: 0.0388 - val_loss: 0.0700 - val_mae: 0.0537 - val_custom_loss: 0.0657 - lr: 1.4740e-04
# Epoch 121/300
# 53/53 [==============================] - 6s 104ms/step - loss: 0.0435 - mae: 0.0315 - custom_loss: 0.0390 - val_loss: 0.0696 - val_mae: 0.0534 - val_custom_loss: 0.0653 - lr: 1.4702e-04
# Epoch 122/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0430 - mae: 0.0311 - custom_loss: 0.0386 - val_loss: 0.0697 - val_mae: 0.0535 - val_custom_loss: 0.0655 - lr: 1.4664e-04
# Epoch 123/300
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0425 - mae: 0.0308 - custom_loss: 0.0381 - val_loss: 0.0690 - val_mae: 0.0530 - val_custom_loss: 0.0648 - lr: 1.4627e-04
# Epoch 124/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0422 - mae: 0.0306 - custom_loss: 0.0379 - val_loss: 0.0693 - val_mae: 0.0533 - val_custom_loss: 0.0652 - lr: 1.4589e-04
# Epoch 125/300
# 53/53 [==============================] - 5s 103ms/step - loss: 0.0418 - mae: 0.0302 - custom_loss: 0.0375 - val_loss: 0.0684 - val_mae: 0.0525 - val_custom_loss: 0.0644 - lr: 1.4552e-04
# Epoch 126/300
# 53/53 [==============================] - 6s 106ms/step - loss: 0.0418 - mae: 0.0302 - custom_loss: 0.0375 - val_loss: 0.0693 - val_mae: 0.0534 - val_custom_loss: 0.0653 - lr: 1.4515e-04
# Epoch 127/300
# 53/53 [==============================] - 6s 116ms/step - loss: 0.0428 - mae: 0.0312 - custom_loss: 0.0386 - val_loss: 0.0691 - val_mae: 0.0532 - val_custom_loss: 0.0651 - lr: 1.4477e-04
# Epoch 128/300
# 53/53 [==============================] - 5s 101ms/step - loss: 0.0414 - mae: 0.0301 - custom_loss: 0.0373 - val_loss: 0.0687 - val_mae: 0.0530 - val_custom_loss: 0.0648 - lr: 1.4440e-04
# Epoch 129/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0411 - mae: 0.0298 - custom_loss: 0.0370 - val_loss: 0.0688 - val_mae: 0.0531 - val_custom_loss: 0.0649 - lr: 1.4403e-04
# Epoch 130/300
# 53/53 [==============================] - 6s 104ms/step - loss: 0.0417 - mae: 0.0303 - custom_loss: 0.0376 - val_loss: 0.0685 - val_mae: 0.0528 - val_custom_loss: 0.0646 - lr: 1.4366e-04
# Epoch 131/300
# 53/53 [==============================] - 6s 108ms/step - loss: 0.0405 - mae: 0.0294 - custom_loss: 0.0365 - val_loss: 0.0692 - val_mae: 0.0535 - val_custom_loss: 0.0654 - lr: 1.4330e-04
# Epoch 132/300
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0402 - mae: 0.0292 - custom_loss: 0.0362 - val_loss: 0.0682 - val_mae: 0.0527 - val_custom_loss: 0.0644 - lr: 1.4293e-04
# Epoch 133/300
# 53/53 [==============================] - 5s 99ms/step - loss: 0.0407 - mae: 0.0297 - custom_loss: 0.0368 - val_loss: 0.0688 - val_mae: 0.0532 - val_custom_loss: 0.0651 - lr: 1.4256e-04
# Epoch 134/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0401 - mae: 0.0292 - custom_loss: 0.0362 - val_loss: 0.0682 - val_mae: 0.0528 - val_custom_loss: 0.0645 - lr: 1.4220e-04
# Epoch 135/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0401 - mae: 0.0292 - custom_loss: 0.0362 - val_loss: 0.0690 - val_mae: 0.0535 - val_custom_loss: 0.0654 - lr: 1.4183e-04
# Epoch 136/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0398 - mae: 0.0290 - custom_loss: 0.0360 - val_loss: 0.0682 - val_mae: 0.0529 - val_custom_loss: 0.0647 - lr: 1.4147e-04
# Epoch 137/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0393 - mae: 0.0286 - custom_loss: 0.0355 - val_loss: 0.0685 - val_mae: 0.0531 - val_custom_loss: 0.0650 - lr: 1.4111e-04
# Epoch 138/300
# 53/53 [==============================] - 5s 97ms/step - loss: 0.0387 - mae: 0.0281 - custom_loss: 0.0349 - val_loss: 0.0687 - val_mae: 0.0534 - val_custom_loss: 0.0652 - lr: 1.4075e-04
# Epoch 139/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0396 - mae: 0.0290 - custom_loss: 0.0359 - val_loss: 0.0695 - val_mae: 0.0540 - val_custom_loss: 0.0660 - lr: 1.4039e-04
# Epoch 140/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0393 - mae: 0.0287 - custom_loss: 0.0356 - val_loss: 0.0680 - val_mae: 0.0528 - val_custom_loss: 0.0646 - lr: 1.4003e-04
# Epoch 141/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0385 - mae: 0.0281 - custom_loss: 0.0349 - val_loss: 0.0675 - val_mae: 0.0525 - val_custom_loss: 0.0641 - lr: 1.3967e-04
# Epoch 142/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0394 - mae: 0.0288 - custom_loss: 0.0358 - val_loss: 0.0683 - val_mae: 0.0532 - val_custom_loss: 0.0649 - lr: 1.3931e-04
# Epoch 143/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0384 - mae: 0.0280 - custom_loss: 0.0348 - val_loss: 0.0676 - val_mae: 0.0526 - val_custom_loss: 0.0643 - lr: 1.3895e-04
# Epoch 144/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0382 - mae: 0.0280 - custom_loss: 0.0347 - val_loss: 0.0684 - val_mae: 0.0533 - val_custom_loss: 0.0652 - lr: 1.3860e-04
# Epoch 145/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0384 - mae: 0.0281 - custom_loss: 0.0349 - val_loss: 0.0696 - val_mae: 0.0544 - val_custom_loss: 0.0663 - lr: 1.3824e-04
# Epoch 146/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0377 - mae: 0.0275 - custom_loss: 0.0342 - val_loss: 0.0678 - val_mae: 0.0528 - val_custom_loss: 0.0646 - lr: 1.3789e-04
# Epoch 147/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0372 - mae: 0.0271 - custom_loss: 0.0338 - val_loss: 0.0681 - val_mae: 0.0531 - val_custom_loss: 0.0649 - lr: 1.3753e-04
# Epoch 148/300
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0372 - mae: 0.0271 - custom_loss: 0.0338 - val_loss: 0.0675 - val_mae: 0.0527 - val_custom_loss: 0.0644 - lr: 1.3718e-04
# Epoch 149/300
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0371 - mae: 0.0271 - custom_loss: 0.0337 - val_loss: 0.0677 - val_mae: 0.0529 - val_custom_loss: 0.0646 - lr: 1.3683e-04
# Epoch 150/300
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0370 - mae: 0.0271 - custom_loss: 0.0337 - val_loss: 0.0675 - val_mae: 0.0527 - val_custom_loss: 0.0645 - lr: 1.3648e-04
# Epoch 151/300
# 53/53 [==============================] - 5s 85ms/step - loss: 0.0369 - mae: 0.0270 - custom_loss: 0.0336 - val_loss: 0.0675 - val_mae: 0.0527 - val_custom_loss: 0.0645 - lr: 1.3613e-04
# Epoch 152/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0365 - mae: 0.0267 - custom_loss: 0.0332 - val_loss: 0.0677 - val_mae: 0.0529 - val_custom_loss: 0.0647 - lr: 1.3578e-04
# Epoch 153/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0371 - mae: 0.0273 - custom_loss: 0.0339 - val_loss: 0.0688 - val_mae: 0.0539 - val_custom_loss: 0.0658 - lr: 1.3543e-04
# Epoch 154/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0361 - mae: 0.0264 - custom_loss: 0.0329 - val_loss: 0.0673 - val_mae: 0.0526 - val_custom_loss: 0.0643 - lr: 1.3509e-04
# Epoch 155/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0362 - mae: 0.0265 - custom_loss: 0.0330 - val_loss: 0.0676 - val_mae: 0.0529 - val_custom_loss: 0.0647 - lr: 1.3474e-04
# Epoch 156/300
# 53/53 [==============================] - 5s 97ms/step - loss: 0.0361 - mae: 0.0264 - custom_loss: 0.0329 - val_loss: 0.0672 - val_mae: 0.0526 - val_custom_loss: 0.0643 - lr: 1.3440e-04
# Epoch 157/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0356 - mae: 0.0261 - custom_loss: 0.0325 - val_loss: 0.0676 - val_mae: 0.0530 - val_custom_loss: 0.0647 - lr: 1.3405e-04
# Epoch 158/300
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0361 - mae: 0.0265 - custom_loss: 0.0330 - val_loss: 0.0678 - val_mae: 0.0531 - val_custom_loss: 0.0650 - lr: 1.3371e-04
# Epoch 159/300
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0359 - mae: 0.0264 - custom_loss: 0.0329 - val_loss: 0.0671 - val_mae: 0.0527 - val_custom_loss: 0.0643 - lr: 1.3337e-04
# Epoch 160/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0359 - mae: 0.0264 - custom_loss: 0.0328 - val_loss: 0.0690 - val_mae: 0.0543 - val_custom_loss: 0.0663 - lr: 1.3302e-04
# Epoch 161/300
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0358 - mae: 0.0264 - custom_loss: 0.0328 - val_loss: 0.0675 - val_mae: 0.0529 - val_custom_loss: 0.0648 - lr: 1.3268e-04
# Epoch 162/300
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0353 - mae: 0.0259 - custom_loss: 0.0323 - val_loss: 0.0668 - val_mae: 0.0525 - val_custom_loss: 0.0641 - lr: 1.3234e-04
# Epoch 163/300
# 53/53 [==============================] - 5s 103ms/step - loss: 0.0350 - mae: 0.0257 - custom_loss: 0.0320 - val_loss: 0.0673 - val_mae: 0.0529 - val_custom_loss: 0.0646 - lr: 1.3201e-04
# Epoch 164/300
# 53/53 [==============================] - 5s 104ms/step - loss: 0.0345 - mae: 0.0253 - custom_loss: 0.0315 - val_loss: 0.0678 - val_mae: 0.0533 - val_custom_loss: 0.0651 - lr: 1.3167e-04
# Epoch 165/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0342 - mae: 0.0250 - custom_loss: 0.0313 - val_loss: 0.0674 - val_mae: 0.0530 - val_custom_loss: 0.0647 - lr: 1.3133e-04
# Epoch 166/300
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0341 - mae: 0.0250 - custom_loss: 0.0312 - val_loss: 0.0671 - val_mae: 0.0528 - val_custom_loss: 0.0645 - lr: 1.3099e-04
# Epoch 167/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0343 - mae: 0.0252 - custom_loss: 0.0314 - val_loss: 0.0673 - val_mae: 0.0529 - val_custom_loss: 0.0647 - lr: 1.3066e-04
# Epoch 168/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0338 - mae: 0.0248 - custom_loss: 0.0310 - val_loss: 0.0668 - val_mae: 0.0526 - val_custom_loss: 0.0643 - lr: 1.3032e-04
# Epoch 169/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0339 - mae: 0.0249 - custom_loss: 0.0311 - val_loss: 0.0670 - val_mae: 0.0527 - val_custom_loss: 0.0644 - lr: 1.2999e-04
# Epoch 170/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0341 - mae: 0.0251 - custom_loss: 0.0313 - val_loss: 0.0670 - val_mae: 0.0528 - val_custom_loss: 0.0645 - lr: 1.2966e-04
# Epoch 171/300
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0336 - mae: 0.0247 - custom_loss: 0.0309 - val_loss: 0.0674 - val_mae: 0.0531 - val_custom_loss: 0.0649 - lr: 1.2932e-04
# Epoch 172/300
# 53/53 [==============================] - 5s 86ms/step - loss: 0.0334 - mae: 0.0245 - custom_loss: 0.0306 - val_loss: 0.0669 - val_mae: 0.0527 - val_custom_loss: 0.0645 - lr: 1.2899e-04
# Epoch 173/300
# 53/53 [==============================] - 5s 85ms/step - loss: 0.0334 - mae: 0.0246 - custom_loss: 0.0307 - val_loss: 0.0674 - val_mae: 0.0531 - val_custom_loss: 0.0649 - lr: 1.2866e-04
# Epoch 174/300
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0336 - mae: 0.0248 - custom_loss: 0.0309 - val_loss: 0.0676 - val_mae: 0.0534 - val_custom_loss: 0.0651 - lr: 1.2833e-04
# Epoch 175/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0341 - mae: 0.0252 - custom_loss: 0.0314 - val_loss: 0.0673 - val_mae: 0.0532 - val_custom_loss: 0.0649 - lr: 1.2800e-04
# Epoch 176/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0334 - mae: 0.0246 - custom_loss: 0.0307 - val_loss: 0.0672 - val_mae: 0.0530 - val_custom_loss: 0.0648 - lr: 1.2768e-04
# Epoch 177/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0330 - mae: 0.0243 - custom_loss: 0.0303 - val_loss: 0.0674 - val_mae: 0.0533 - val_custom_loss: 0.0650 - lr: 1.2735e-04
# Epoch 178/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0333 - mae: 0.0246 - custom_loss: 0.0306 - val_loss: 0.0674 - val_mae: 0.0532 - val_custom_loss: 0.0650 - lr: 1.2702e-04
# Epoch 179/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0326 - mae: 0.0240 - custom_loss: 0.0300 - val_loss: 0.0669 - val_mae: 0.0529 - val_custom_loss: 0.0646 - lr: 1.2670e-04
# Epoch 180/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0323 - mae: 0.0238 - custom_loss: 0.0297 - val_loss: 0.0677 - val_mae: 0.0535 - val_custom_loss: 0.0654 - lr: 1.2637e-04
# Epoch 181/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0329 - mae: 0.0243 - custom_loss: 0.0303 - val_loss: 0.0682 - val_mae: 0.0540 - val_custom_loss: 0.0659 - lr: 1.2605e-04
# Epoch 182/300
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0327 - mae: 0.0241 - custom_loss: 0.0301 - val_loss: 0.0670 - val_mae: 0.0530 - val_custom_loss: 0.0647 - lr: 1.2573e-04
# Epoch 183/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0322 - mae: 0.0238 - custom_loss: 0.0297 - val_loss: 0.0678 - val_mae: 0.0536 - val_custom_loss: 0.0655 - lr: 1.2540e-04
# Epoch 184/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0322 - mae: 0.0238 - custom_loss: 0.0297 - val_loss: 0.0664 - val_mae: 0.0525 - val_custom_loss: 0.0642 - lr: 1.2508e-04
# Epoch 185/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0317 - mae: 0.0233 - custom_loss: 0.0292 - val_loss: 0.0666 - val_mae: 0.0527 - val_custom_loss: 0.0644 - lr: 1.2476e-04
# Epoch 186/300
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0313 - mae: 0.0230 - custom_loss: 0.0288 - val_loss: 0.0665 - val_mae: 0.0526 - val_custom_loss: 0.0643 - lr: 1.2444e-04
# Epoch 187/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0314 - mae: 0.0232 - custom_loss: 0.0290 - val_loss: 0.0674 - val_mae: 0.0535 - val_custom_loss: 0.0652 - lr: 1.2413e-04
# Epoch 188/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0311 - mae: 0.0229 - custom_loss: 0.0286 - val_loss: 0.0668 - val_mae: 0.0530 - val_custom_loss: 0.0646 - lr: 1.2381e-04
# Epoch 189/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0311 - mae: 0.0229 - custom_loss: 0.0286 - val_loss: 0.0666 - val_mae: 0.0528 - val_custom_loss: 0.0644 - lr: 1.2349e-04
# Epoch 190/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0311 - mae: 0.0229 - custom_loss: 0.0287 - val_loss: 0.0669 - val_mae: 0.0530 - val_custom_loss: 0.0647 - lr: 1.2317e-04
# Epoch 191/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0309 - mae: 0.0228 - custom_loss: 0.0285 - val_loss: 0.0667 - val_mae: 0.0528 - val_custom_loss: 0.0645 - lr: 1.2286e-04
# Epoch 192/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0316 - mae: 0.0234 - custom_loss: 0.0293 - val_loss: 0.0671 - val_mae: 0.0532 - val_custom_loss: 0.0650 - lr: 1.2254e-04
# Epoch 193/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0308 - mae: 0.0227 - custom_loss: 0.0285 - val_loss: 0.0675 - val_mae: 0.0536 - val_custom_loss: 0.0654 - lr: 1.2223e-04
# Epoch 194/300
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0308 - mae: 0.0227 - custom_loss: 0.0284 - val_loss: 0.0675 - val_mae: 0.0536 - val_custom_loss: 0.0654 - lr: 1.2192e-04
# Epoch 195/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0312 - mae: 0.0231 - custom_loss: 0.0289 - val_loss: 0.0669 - val_mae: 0.0531 - val_custom_loss: 0.0648 - lr: 1.2160e-04
# Epoch 196/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0306 - mae: 0.0226 - custom_loss: 0.0283 - val_loss: 0.0668 - val_mae: 0.0531 - val_custom_loss: 0.0648 - lr: 1.2129e-04
# Epoch 197/300
# 53/53 [==============================] - 5s 99ms/step - loss: 0.0306 - mae: 0.0226 - custom_loss: 0.0283 - val_loss: 0.0671 - val_mae: 0.0533 - val_custom_loss: 0.0651 - lr: 1.2098e-04
# Epoch 198/300
# 53/53 [==============================] - 5s 102ms/step - loss: 0.0303 - mae: 0.0224 - custom_loss: 0.0280 - val_loss: 0.0668 - val_mae: 0.0531 - val_custom_loss: 0.0648 - lr: 1.2067e-04
# Epoch 199/300
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0296 - mae: 0.0218 - custom_loss: 0.0273 - val_loss: 0.0671 - val_mae: 0.0533 - val_custom_loss: 0.0651 - lr: 1.2036e-04
# Epoch 200/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0297 - mae: 0.0219 - custom_loss: 0.0275 - val_loss: 0.0665 - val_mae: 0.0529 - val_custom_loss: 0.0646 - lr: 1.2005e-04
# Epoch 201/300
# 53/53 [==============================] - 5s 99ms/step - loss: 0.0297 - mae: 0.0219 - custom_loss: 0.0275 - val_loss: 0.0669 - val_mae: 0.0531 - val_custom_loss: 0.0650 - lr: 1.1975e-04
# Epoch 202/300
# 53/53 [==============================] - 5s 103ms/step - loss: 0.0299 - mae: 0.0221 - custom_loss: 0.0277 - val_loss: 0.0676 - val_mae: 0.0538 - val_custom_loss: 0.0656 - lr: 1.1944e-04
# Epoch 203/300
# 53/53 [==============================] - 6s 106ms/step - loss: 0.0299 - mae: 0.0221 - custom_loss: 0.0277 - val_loss: 0.0667 - val_mae: 0.0530 - val_custom_loss: 0.0648 - lr: 1.1913e-04
# Epoch 204/300
# 53/53 [==============================] - 5s 97ms/step - loss: 0.0295 - mae: 0.0218 - custom_loss: 0.0273 - val_loss: 0.0668 - val_mae: 0.0532 - val_custom_loss: 0.0649 - lr: 1.1883e-04
# Epoch 205/300
# 53/53 [==============================] - 5s 97ms/step - loss: 0.0295 - mae: 0.0218 - custom_loss: 0.0274 - val_loss: 0.0666 - val_mae: 0.0529 - val_custom_loss: 0.0647 - lr: 1.1853e-04
# Epoch 206/300
# 53/53 [==============================] - 5s 97ms/step - loss: 0.0292 - mae: 0.0216 - custom_loss: 0.0271 - val_loss: 0.0678 - val_mae: 0.0540 - val_custom_loss: 0.0659 - lr: 1.1822e-04
# Epoch 207/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0301 - mae: 0.0223 - custom_loss: 0.0279 - val_loss: 0.0670 - val_mae: 0.0533 - val_custom_loss: 0.0651 - lr: 1.1792e-04
# Epoch 208/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0297 - mae: 0.0220 - custom_loss: 0.0276 - val_loss: 0.0673 - val_mae: 0.0536 - val_custom_loss: 0.0655 - lr: 1.1762e-04
# Epoch 209/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0291 - mae: 0.0215 - custom_loss: 0.0270 - val_loss: 0.0668 - val_mae: 0.0532 - val_custom_loss: 0.0649 - lr: 1.1732e-04
# Epoch 210/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0289 - mae: 0.0214 - custom_loss: 0.0268 - val_loss: 0.0669 - val_mae: 0.0533 - val_custom_loss: 0.0651 - lr: 1.1702e-04
# Epoch 211/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0289 - mae: 0.0213 - custom_loss: 0.0268 - val_loss: 0.0669 - val_mae: 0.0533 - val_custom_loss: 0.0650 - lr: 1.1672e-04
# Epoch 212/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0288 - mae: 0.0213 - custom_loss: 0.0267 - val_loss: 0.0671 - val_mae: 0.0535 - val_custom_loss: 0.0653 - lr: 1.1642e-04
# Epoch 213/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0284 - mae: 0.0210 - custom_loss: 0.0263 - val_loss: 0.0676 - val_mae: 0.0539 - val_custom_loss: 0.0658 - lr: 1.1612e-04
# Epoch 214/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0288 - mae: 0.0213 - custom_loss: 0.0267 - val_loss: 0.0669 - val_mae: 0.0533 - val_custom_loss: 0.0651 - lr: 1.1582e-04
# Epoch 215/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0287 - mae: 0.0213 - custom_loss: 0.0267 - val_loss: 0.0668 - val_mae: 0.0532 - val_custom_loss: 0.0650 - lr: 1.1552e-04
# Epoch 216/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0281 - mae: 0.0208 - custom_loss: 0.0261 - val_loss: 0.0667 - val_mae: 0.0532 - val_custom_loss: 0.0650 - lr: 1.1523e-04
# Epoch 217/300
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0281 - mae: 0.0208 - custom_loss: 0.0261 - val_loss: 0.0664 - val_mae: 0.0530 - val_custom_loss: 0.0647 - lr: 1.1493e-04
# Epoch 218/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0283 - mae: 0.0209 - custom_loss: 0.0263 - val_loss: 0.0667 - val_mae: 0.0532 - val_custom_loss: 0.0650 - lr: 1.1464e-04
# Epoch 219/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0279 - mae: 0.0206 - custom_loss: 0.0259 - val_loss: 0.0670 - val_mae: 0.0535 - val_custom_loss: 0.0653 - lr: 1.1435e-04
# Epoch 220/300
# 53/53 [==============================] - 5s 97ms/step - loss: 0.0285 - mae: 0.0211 - custom_loss: 0.0265 - val_loss: 0.0672 - val_mae: 0.0536 - val_custom_loss: 0.0655 - lr: 1.1405e-04
# Epoch 221/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0286 - mae: 0.0212 - custom_loss: 0.0266 - val_loss: 0.0670 - val_mae: 0.0534 - val_custom_loss: 0.0653 - lr: 1.1376e-04
# Epoch 222/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0281 - mae: 0.0208 - custom_loss: 0.0261 - val_loss: 0.0667 - val_mae: 0.0533 - val_custom_loss: 0.0650 - lr: 1.1347e-04
# Epoch 223/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0276 - mae: 0.0204 - custom_loss: 0.0256 - val_loss: 0.0664 - val_mae: 0.0531 - val_custom_loss: 0.0648 - lr: 1.1318e-04
# Epoch 224/300
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0281 - mae: 0.0209 - custom_loss: 0.0262 - val_loss: 0.0667 - val_mae: 0.0533 - val_custom_loss: 0.0650 - lr: 1.1289e-04
# Epoch 225/300
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0273 - mae: 0.0202 - custom_loss: 0.0254 - val_loss: 0.0669 - val_mae: 0.0534 - val_custom_loss: 0.0652 - lr: 1.1260e-04
# Epoch 226/300
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0274 - mae: 0.0202 - custom_loss: 0.0254 - val_loss: 0.0668 - val_mae: 0.0533 - val_custom_loss: 0.0651 - lr: 1.1231e-04
# Epoch 227/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0277 - mae: 0.0205 - custom_loss: 0.0257 - val_loss: 0.0668 - val_mae: 0.0534 - val_custom_loss: 0.0652 - lr: 1.1202e-04
# Epoch 228/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0272 - mae: 0.0201 - custom_loss: 0.0253 - val_loss: 0.0666 - val_mae: 0.0533 - val_custom_loss: 0.0650 - lr: 1.1174e-04
# Epoch 229/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0272 - mae: 0.0201 - custom_loss: 0.0253 - val_loss: 0.0673 - val_mae: 0.0537 - val_custom_loss: 0.0657 - lr: 1.1145e-04
# Epoch 230/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0272 - mae: 0.0201 - custom_loss: 0.0253 - val_loss: 0.0671 - val_mae: 0.0536 - val_custom_loss: 0.0655 - lr: 1.1116e-04
# Epoch 231/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0276 - mae: 0.0205 - custom_loss: 0.0257 - val_loss: 0.0666 - val_mae: 0.0533 - val_custom_loss: 0.0650 - lr: 1.1088e-04
# Epoch 232/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0275 - mae: 0.0204 - custom_loss: 0.0256 - val_loss: 0.0673 - val_mae: 0.0538 - val_custom_loss: 0.0657 - lr: 1.1060e-04
# Epoch 233/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0276 - mae: 0.0205 - custom_loss: 0.0257 - val_loss: 0.0665 - val_mae: 0.0532 - val_custom_loss: 0.0650 - lr: 1.1031e-04
# Epoch 234/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0263 - mae: 0.0194 - custom_loss: 0.0244 - val_loss: 0.0666 - val_mae: 0.0533 - val_custom_loss: 0.0651 - lr: 1.1003e-04
# Epoch 235/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0262 - mae: 0.0193 - custom_loss: 0.0244 - val_loss: 0.0670 - val_mae: 0.0537 - val_custom_loss: 0.0655 - lr: 1.0975e-04
# Epoch 236/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0263 - mae: 0.0195 - custom_loss: 0.0245 - val_loss: 0.0669 - val_mae: 0.0535 - val_custom_loss: 0.0653 - lr: 1.0947e-04
# Epoch 237/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0263 - mae: 0.0194 - custom_loss: 0.0245 - val_loss: 0.0674 - val_mae: 0.0540 - val_custom_loss: 0.0658 - lr: 1.0919e-04
# Epoch 238/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0270 - mae: 0.0200 - custom_loss: 0.0251 - val_loss: 0.0674 - val_mae: 0.0540 - val_custom_loss: 0.0659 - lr: 1.0891e-04
# Epoch 239/300
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0268 - mae: 0.0198 - custom_loss: 0.0250 - val_loss: 0.0664 - val_mae: 0.0532 - val_custom_loss: 0.0649 - lr: 1.0863e-04
# Epoch 240/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0264 - mae: 0.0196 - custom_loss: 0.0247 - val_loss: 0.0665 - val_mae: 0.0533 - val_custom_loss: 0.0650 - lr: 1.0835e-04
# Epoch 241/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0258 - mae: 0.0190 - custom_loss: 0.0240 - val_loss: 0.0668 - val_mae: 0.0535 - val_custom_loss: 0.0653 - lr: 1.0807e-04
# Epoch 242/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0259 - mae: 0.0192 - custom_loss: 0.0242 - val_loss: 0.0665 - val_mae: 0.0532 - val_custom_loss: 0.0650 - lr: 1.0780e-04
# Epoch 243/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0256 - mae: 0.0189 - custom_loss: 0.0238 - val_loss: 0.0665 - val_mae: 0.0533 - val_custom_loss: 0.0650 - lr: 1.0752e-04
# Epoch 244/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0259 - mae: 0.0191 - custom_loss: 0.0241 - val_loss: 0.0665 - val_mae: 0.0533 - val_custom_loss: 0.0651 - lr: 1.0724e-04
# Epoch 245/300
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0257 - mae: 0.0190 - custom_loss: 0.0240 - val_loss: 0.0665 - val_mae: 0.0533 - val_custom_loss: 0.0650 - lr: 1.0697e-04
# Epoch 246/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0260 - mae: 0.0192 - custom_loss: 0.0242 - val_loss: 0.0664 - val_mae: 0.0532 - val_custom_loss: 0.0649 - lr: 1.0670e-04
# Epoch 247/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0256 - mae: 0.0190 - custom_loss: 0.0239 - val_loss: 0.0667 - val_mae: 0.0535 - val_custom_loss: 0.0653 - lr: 1.0642e-04
# Epoch 248/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0252 - mae: 0.0186 - custom_loss: 0.0234 - val_loss: 0.0670 - val_mae: 0.0537 - val_custom_loss: 0.0655 - lr: 1.0615e-04
# Epoch 249/300
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0251 - mae: 0.0185 - custom_loss: 0.0233 - val_loss: 0.0665 - val_mae: 0.0533 - val_custom_loss: 0.0650 - lr: 1.0588e-04
# Epoch 250/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0251 - mae: 0.0185 - custom_loss: 0.0234 - val_loss: 0.0668 - val_mae: 0.0535 - val_custom_loss: 0.0653 - lr: 1.0561e-04
# Epoch 251/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0252 - mae: 0.0187 - custom_loss: 0.0235 - val_loss: 0.0666 - val_mae: 0.0535 - val_custom_loss: 0.0652 - lr: 1.0534e-04
# Epoch 252/300
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0251 - mae: 0.0185 - custom_loss: 0.0234 - val_loss: 0.0666 - val_mae: 0.0534 - val_custom_loss: 0.0652 - lr: 1.0507e-04
# Epoch 253/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0251 - mae: 0.0185 - custom_loss: 0.0234 - val_loss: 0.0669 - val_mae: 0.0537 - val_custom_loss: 0.0655 - lr: 1.0480e-04
# Epoch 254/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0251 - mae: 0.0186 - custom_loss: 0.0234 - val_loss: 0.0668 - val_mae: 0.0536 - val_custom_loss: 0.0654 - lr: 1.0453e-04
# Epoch 255/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0256 - mae: 0.0190 - custom_loss: 0.0239 - val_loss: 0.0667 - val_mae: 0.0535 - val_custom_loss: 0.0653 - lr: 1.0426e-04
# Epoch 256/300
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0251 - mae: 0.0186 - custom_loss: 0.0235 - val_loss: 0.0665 - val_mae: 0.0534 - val_custom_loss: 0.0651 - lr: 1.0399e-04
# Epoch 257/300
# 53/53 [==============================] - 5s 86ms/step - loss: 0.0251 - mae: 0.0186 - custom_loss: 0.0235 - val_loss: 0.0667 - val_mae: 0.0535 - val_custom_loss: 0.0653 - lr: 1.0373e-04
# Epoch 258/300
# 53/53 [==============================] - 5s 101ms/step - loss: 0.0250 - mae: 0.0185 - custom_loss: 0.0233 - val_loss: 0.0665 - val_mae: 0.0534 - val_custom_loss: 0.0651 - lr: 1.0346e-04
# Epoch 259/300
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0249 - mae: 0.0185 - custom_loss: 0.0233 - val_loss: 0.0666 - val_mae: 0.0535 - val_custom_loss: 0.0652 - lr: 1.0320e-04
# Epoch 260/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0247 - mae: 0.0183 - custom_loss: 0.0231 - val_loss: 0.0666 - val_mae: 0.0535 - val_custom_loss: 0.0653 - lr: 1.0293e-04
# Epoch 261/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0245 - mae: 0.0181 - custom_loss: 0.0229 - val_loss: 0.0666 - val_mae: 0.0535 - val_custom_loss: 0.0653 - lr: 1.0267e-04
# Epoch 262/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0249 - mae: 0.0185 - custom_loss: 0.0233 - val_loss: 0.0663 - val_mae: 0.0532 - val_custom_loss: 0.0650 - lr: 1.0241e-04
# Epoch 263/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0245 - mae: 0.0182 - custom_loss: 0.0229 - val_loss: 0.0669 - val_mae: 0.0538 - val_custom_loss: 0.0656 - lr: 1.0214e-04
# Epoch 264/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0242 - mae: 0.0179 - custom_loss: 0.0226 - val_loss: 0.0667 - val_mae: 0.0536 - val_custom_loss: 0.0654 - lr: 1.0188e-04
# Epoch 265/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0243 - mae: 0.0180 - custom_loss: 0.0227 - val_loss: 0.0666 - val_mae: 0.0535 - val_custom_loss: 0.0653 - lr: 1.0162e-04
# Epoch 266/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0242 - mae: 0.0179 - custom_loss: 0.0226 - val_loss: 0.0667 - val_mae: 0.0536 - val_custom_loss: 0.0654 - lr: 1.0136e-04
# Epoch 267/300
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0242 - mae: 0.0179 - custom_loss: 0.0226 - val_loss: 0.0670 - val_mae: 0.0539 - val_custom_loss: 0.0657 - lr: 1.0110e-04
# Epoch 268/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0238 - mae: 0.0175 - custom_loss: 0.0222 - val_loss: 0.0665 - val_mae: 0.0535 - val_custom_loss: 0.0652 - lr: 1.0084e-04
# Epoch 269/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0240 - mae: 0.0177 - custom_loss: 0.0224 - val_loss: 0.0663 - val_mae: 0.0533 - val_custom_loss: 0.0651 - lr: 1.0058e-04
# Epoch 270/300
# 53/53 [==============================] - 5s 97ms/step - loss: 0.0240 - mae: 0.0178 - custom_loss: 0.0225 - val_loss: 0.0664 - val_mae: 0.0533 - val_custom_loss: 0.0651 - lr: 1.0033e-04
# Epoch 271/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0239 - mae: 0.0176 - custom_loss: 0.0223 - val_loss: 0.0665 - val_mae: 0.0534 - val_custom_loss: 0.0652 - lr: 1.0007e-04
# Epoch 272/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0237 - mae: 0.0175 - custom_loss: 0.0221 - val_loss: 0.0661 - val_mae: 0.0532 - val_custom_loss: 0.0648 - lr: 9.9812e-05
# Epoch 273/300
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0235 - mae: 0.0174 - custom_loss: 0.0220 - val_loss: 0.0665 - val_mae: 0.0535 - val_custom_loss: 0.0653 - lr: 9.9557e-05
# Epoch 274/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0235 - mae: 0.0173 - custom_loss: 0.0220 - val_loss: 0.0668 - val_mae: 0.0538 - val_custom_loss: 0.0656 - lr: 9.9302e-05
# Epoch 275/300
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0238 - mae: 0.0176 - custom_loss: 0.0223 - val_loss: 0.0662 - val_mae: 0.0532 - val_custom_loss: 0.0650 - lr: 9.9047e-05
# Epoch 276/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0239 - mae: 0.0177 - custom_loss: 0.0224 - val_loss: 0.0668 - val_mae: 0.0537 - val_custom_loss: 0.0655 - lr: 9.8794e-05
# Epoch 277/300
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0235 - mae: 0.0174 - custom_loss: 0.0220 - val_loss: 0.0665 - val_mae: 0.0535 - val_custom_loss: 0.0653 - lr: 9.8541e-05
# Epoch 278/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0236 - mae: 0.0175 - custom_loss: 0.0221 - val_loss: 0.0666 - val_mae: 0.0536 - val_custom_loss: 0.0654 - lr: 9.8288e-05
# Epoch 279/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0232 - mae: 0.0171 - custom_loss: 0.0217 - val_loss: 0.0665 - val_mae: 0.0535 - val_custom_loss: 0.0653 - lr: 9.8037e-05
# Epoch 280/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0236 - mae: 0.0175 - custom_loss: 0.0221 - val_loss: 0.0668 - val_mae: 0.0538 - val_custom_loss: 0.0656 - lr: 9.7785e-05
# Epoch 281/300
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0234 - mae: 0.0173 - custom_loss: 0.0219 - val_loss: 0.0665 - val_mae: 0.0536 - val_custom_loss: 0.0653 - lr: 9.7535e-05
# Epoch 282/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0231 - mae: 0.0171 - custom_loss: 0.0216 - val_loss: 0.0669 - val_mae: 0.0539 - val_custom_loss: 0.0657 - lr: 9.7285e-05
# Epoch 283/300
# 53/53 [==============================] - 5s 103ms/step - loss: 0.0230 - mae: 0.0170 - custom_loss: 0.0216 - val_loss: 0.0666 - val_mae: 0.0536 - val_custom_loss: 0.0654 - lr: 9.7036e-05
# Epoch 284/300
# 53/53 [==============================] - 5s 99ms/step - loss: 0.0231 - mae: 0.0171 - custom_loss: 0.0216 - val_loss: 0.0661 - val_mae: 0.0532 - val_custom_loss: 0.0649 - lr: 9.6787e-05
# Epoch 285/300
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0228 - mae: 0.0168 - custom_loss: 0.0213 - val_loss: 0.0664 - val_mae: 0.0535 - val_custom_loss: 0.0652 - lr: 9.6540e-05
# Epoch 286/300
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0232 - mae: 0.0172 - custom_loss: 0.0218 - val_loss: 0.0665 - val_mae: 0.0536 - val_custom_loss: 0.0654 - lr: 9.6292e-05
# Epoch 287/300
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0230 - mae: 0.0171 - custom_loss: 0.0216 - val_loss: 0.0668 - val_mae: 0.0538 - val_custom_loss: 0.0656 - lr: 9.6046e-05
# Epoch 288/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0227 - mae: 0.0168 - custom_loss: 0.0213 - val_loss: 0.0663 - val_mae: 0.0535 - val_custom_loss: 0.0652 - lr: 9.5800e-05
# Epoch 289/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0227 - mae: 0.0168 - custom_loss: 0.0213 - val_loss: 0.0667 - val_mae: 0.0538 - val_custom_loss: 0.0656 - lr: 9.5554e-05
# Epoch 290/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0228 - mae: 0.0169 - custom_loss: 0.0214 - val_loss: 0.0664 - val_mae: 0.0535 - val_custom_loss: 0.0652 - lr: 9.5309e-05
# Epoch 291/300
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0226 - mae: 0.0167 - custom_loss: 0.0211 - val_loss: 0.0664 - val_mae: 0.0535 - val_custom_loss: 0.0653 - lr: 9.5065e-05
# Epoch 292/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0222 - mae: 0.0164 - custom_loss: 0.0208 - val_loss: 0.0665 - val_mae: 0.0536 - val_custom_loss: 0.0654 - lr: 9.4822e-05
# Epoch 293/300
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0229 - mae: 0.0169 - custom_loss: 0.0215 - val_loss: 0.0668 - val_mae: 0.0539 - val_custom_loss: 0.0657 - lr: 9.4579e-05
# Epoch 294/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0226 - mae: 0.0168 - custom_loss: 0.0212 - val_loss: 0.0665 - val_mae: 0.0536 - val_custom_loss: 0.0654 - lr: 9.4337e-05
# Epoch 295/300
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0227 - mae: 0.0168 - custom_loss: 0.0213 - val_loss: 0.0665 - val_mae: 0.0537 - val_custom_loss: 0.0654 - lr: 9.4095e-05
# Epoch 296/300
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0222 - mae: 0.0164 - custom_loss: 0.0208 - val_loss: 0.0666 - val_mae: 0.0536 - val_custom_loss: 0.0655 - lr: 9.3854e-05
# Epoch 297/300
# 53/53 [==============================] - 5s 99ms/step - loss: 0.0223 - mae: 0.0165 - custom_loss: 0.0209 - val_loss: 0.0668 - val_mae: 0.0538 - val_custom_loss: 0.0657 - lr: 9.3614e-05
# Epoch 298/300
# 53/53 [==============================] - 6s 109ms/step - loss: 0.0226 - mae: 0.0167 - custom_loss: 0.0212 - val_loss: 0.0667 - val_mae: 0.0537 - val_custom_loss: 0.0656 - lr: 9.3374e-05
# Epoch 299/300
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0220 - mae: 0.0162 - custom_loss: 0.0206 - val_loss: 0.0665 - val_mae: 0.0536 - val_custom_loss: 0.0654 - lr: 9.3135e-05
# Epoch 300/300
# 53/53 [==============================] - 5s 102ms/step - loss: 0.0223 - mae: 0.0165 - custom_loss: 0.0209 - val_loss: 0.0669 - val_mae: 0.0539 - val_custom_loss: 0.0658 - lr: 9.2896e-05

# %%
np.shape(y_train_encoded)
# Out:
# (1590, 196, 12)

# %%
test_prediction = model.predict([x_test_img,x_test_geopara])
# Out:
# 17/17 [==============================] - 1s 32ms/step

# %%
np.shape(test_prediction)
# Out:
# (531, 196, 12)

# %%
mae = hist.history['mae']
val_mae = hist.history['val_mae']
epochs = range(1, len(mae) + 1)

plt.plot(epochs, mae, '-', label='Training mae')
plt.plot(epochs, val_mae, ':', label='Validation mae')
plt.title('Training and Validation mae')
plt.xlabel('Epoch')
plt.ylabel('mae')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %%
from sklearn.metrics import r2_score
r2_result = []
for z in range(fmax):
    r2 = 0
    for i in range(12):
        temp = r2_score(y_test_encoded[:,z,i], test_prediction[:,z,i], force_finite=False)
        r2 = r2+temp
    r2_result.append(r2/12)
plt.plot(range(fmax),r2_result)

# %%
np.mean(r2_result)
# Out:
# 0.9450701170353145

# %%
mae_all = np.zeros((fmax,12))
mae_mean = np.zeros(fmax)
for z in range(fmax):
    for i in range(12):
        mae_all[z][i] = np.mean(abs(test_prediction[:,z,i]-y_test_encoded[:,z,i]))*0.5*srange[z,i]
    mae_mean[z] = np.mean(mae_all[z][:])

# %%
freq = range(fmax)
for i in range(12):
    if (i%2==0):
        plt.plot(freq,mae_all[:,i])
plt.legend(["Re[S11]","Re[S12]","Re[S13]","Re[S14]","Re[S33]","Re[S34]"])
plt.xlabel('Frequency/GHz')
plt.ylabel('S-parameter mae')
# Out:
# Text(0, 0.5, 'S-parameter mae')

# %%
fmax = 196
mae_all = np.zeros((fmax,12))
mae_mean = np.zeros(fmax)
for z in range(fmax):
    for i in range(12):
        mae_all[z][i] = np.mean(abs(test_prediction[:,z,i]-y_test_encoded[:,z,i]))*0.5*srange[z,i]
    mae_mean[z] = np.mean(mae_all[z][:])

# %%
plt.plot(range(fmax),mae_mean)
plt.xlabel('Frequency/GHz')
plt.ylabel('Average S-parameter mae')
# Out:
# Text(0, 0.5, 'Average S-parameter mae')

# %%
freq = range(fmax)
for i in range(12):
    if (i%2==1):
        plt.plot(freq,mae_all[:,i])
plt.legend(["Im[S11]","Im[S12]","Im[S13]","Im[S14]","Im[S33]","Im[S34]"])        
plt.xlabel('Frequency/GHz')
plt.ylabel('S-parameter mae')
# Out:
# Text(0, 0.5, 'S-parameter mae')

# %%
np.mean(mae_mean)
# Out:
# 0.024050311575636384

# %%
def R_squared(y, y_pred):
  residual = tf.reduce_sum(tf.square(tf.subtract(y, y_pred)))
  total = tf.reduce_sum(tf.square(tf.subtract(y, tf.reduce_mean(y))))
  r2 = tf.subtract(1.0, tf.divide(residual, total))
  return r2
print(R_squared(y_test_encoded,test_prediction))
# Out:
# tf.Tensor(0.9638188003270757, shape=(), dtype=float64)

# %%
model.save('./models/substrate/1turn_196G_CNN.h5')
# Out:
# /home/hh68/.conda/envs/tensorflow/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
