# %%
import os
import numpy as np
from keras.preprocessing import image
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
import pandas as pd
import skrf as rf

#define the targeted max frequency
fmax = 196
#define function for loading images and s-parameters
#"path" is the path for images of transformer layout
#"label" is the path for labels. In this case, labels are S-parameter associated with each images 
def load_images_from_path(path, label,length):
    images = []
    labels = []
    
    for i in range(length):
        #load images
        img = image.load_img(path+str(i)+'.png', target_size=(500, 500, 3))
        images.append(image.img_to_array(img)[138:362,138:362,:])#trim the ground margin

        #load S-parameters
        #According to symmerty, only S11,S12,S13,S14,S33,S34 are considered
        #Each S-parameter has real and imaginary parts, and hence 12 real values in total.
        results = []
        datafile = label+str(i)+".s4p"
        spt = rf.Network(datafile)
        for i in range(fmax+1):
            results.append([spt.s[i][0][0].real,spt.s[i][0][0].imag,
                            spt.s[i][0][1].real,spt.s[i][0][1].imag,
                            spt.s[i][0][2].real,spt.s[i][0][2].imag,
                            spt.s[i][0][3].real,spt.s[i][0][3].imag,
                            spt.s[i][2][2].real,spt.s[i][2][2].imag,
                            spt.s[i][2][3].real,spt.s[i][2][3].imag])      
        labels.append(results) 
    return images, labels

def show_images(images):
    fig, axes = plt.subplots(1, 8, figsize=(20, 20), subplot_kw={'xticks': [], 'yticks': []})

    for i, ax in enumerate(axes.flat):
        ax.imshow(images[i] / 255)
# Out:
# 2024-12-02 18:38:14.282422: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#load data
#geometrical parameters stored in log.txt
#order of geopara (radiusA,radiusB,turnsA,turnsB,openA,openB,outA,outB,extA,extB,ratio,outbound)
logfile = open("/rdf/shared/design_automation/Data/2409/log.txt","r")
listall = list(map(lambda item: list(map(lambda jtem: eval(jtem.strip()), item[1:-1].split(','))), logfile.read().strip().split('\n')))
tabular_data = np.array(listall)

#load images and s-parameters
length = 4100
images, labels = load_images_from_path('/rdf/shared/design_automation/Data/2409/PNG/', '/rdf/shared/design_automation/Data/2409/SPData/',length)
show_images(images)
geoparas = []
images11 = []
labels11 = []

for kk in range(length):
    #select 1 turn and 1 turn transformers
   if((tabular_data[kk,2]==1) and (tabular_data[kk,3]==1)):
       #geoparas only includes the variable parameters in our designs. 
       #Constants at this design stages are excluded 
        geoparas.append(tabular_data[kk,(0,1,4,5,4,5,6,7,12,13)])
        images11.append(images[kk])
        labels11.append(labels[kk])
print(np.shape(geoparas))
# Out:
# (2177, 10)

# %%
#load data from the second folder
#geometrical parameters stored in log.txt
#order of geopara (radiusA,radiusB,turnsA,turnsB,openA,openB,outA,outB,extA,extB,ratio,outbound)
logfile = open("/rdf/shared/design_automation/Data/2409_2/log.txt","r")
listall = list(map(lambda item: list(map(lambda jtem: eval(jtem.strip()), item[1:-1].split(','))), logfile.read().strip().split('\n')))
tabular_data = np.array(listall)

#load images and s-parameters
#length = len(listall)-3
length = 2500
images, labels = load_images_from_path('/rdf/shared/design_automation/Data/2409_2/PNG/', '/rdf/shared/design_automation/Data/2409_2/SPData/',length)


for kk in range(length):
    #select 1 turn and 1 turn transformers
   if((tabular_data[kk,2]==1) and (tabular_data[kk,3]==1)):
       #geoparas only includes the variable parameters in our designs. 
       #Constants at this design stages are excluded 
        geoparas.append(tabular_data[kk,(0,1,4,5,4,5,6,7,12,13)])
        images11.append(images[kk])
        labels11.append(labels[kk])
print(np.shape(geoparas))
# Out:
# (2651, 10)

# %%
#normalize geometrical inputs
geoparas_temp = np.array(geoparas)
geoparas = np.zeros(np.shape(geoparas_temp))
for i in range(len(geoparas)):
    for j in range(10):
        geoparas[i,j]= (geoparas_temp[i,j]-np.mean(geoparas_temp[:,j]))/np.std(geoparas_temp[:,j])

# %%
#construct the datasets
class item:
  def __init__(self, image,geopara,label ):
    self.image = image
    self.geopara = geopara
    self.label = label

data = []
for i in range(len(images11)):
    data.append(item(images11[i],geoparas[i],labels11[i]))

#np.random.shuffle(data)

# %%
#define the split length for training, validation and test datasets
length = len(images11)
split1 = int(0.6*length)
split2 = int(0.8*length)
data_train = data[0:split1]
data_valid = data[split1:split2]
data_test = data[split2:]

# %%
#Separate the training, validation and test datasets 
train_images = []
train_labels = []
train_geoparas = []
valid_images = []
valid_labels = []
valid_geoparas = []
test_images = []
test_labels = []
test_geoparas = []


#The targeted frequency span up to fmax, with 1GHz step
s_max = np.zeros((fmax,12))
s_min = np.zeros((fmax,12))
srange = np.zeros((fmax,12))


for i in range(len(data_train)):
    train_images.append(data_train[i].image)
    train_geoparas.append(data_train[i].geopara)
    train_labels.append(data_train[i].label)
x_train_img = np.array(train_images) / 255
x_train_geopara = np.array(train_geoparas)
y_train_encoded = np.array(train_labels)[:,1:fmax+1,:]


for i in range(len(data_valid)):
    valid_images.append(data_valid[i].image)
    valid_geoparas.append(data_valid[i].geopara)
    valid_labels.append(data_valid[i].label)
x_valid_img = np.array(valid_images) / 255
x_valid_geopara = np.array(valid_geoparas)
y_valid_encoded = np.array(valid_labels)[:,1:fmax+1,:]


for i in range(len(data_test)):
    test_images.append(data_test[i].image)
    test_geoparas.append(data_test[i].geopara)
    test_labels.append(data_test[i].label)
x_test_img = np.array(test_images) / 255
x_test_geopara = np.array(test_geoparas)
y_test_encoded = np.array(test_labels)[:,1:fmax+1,:]

#normalize the s-parameters for each frequency point
for z in range(fmax):
    for i in range(12):
        s_max[z,i] = max(max(y_train_encoded[:,z,i]),max(y_valid_encoded[:,z,i]),max(y_test_encoded[:,z,i]))
        s_min[z,i] = min(min(y_train_encoded[:,z,i]),min(y_valid_encoded[:,z,i]),min(y_test_encoded[:,z,i]))
        srange[z,i] = s_max[z,i]-s_min[z,i]
    
    for i in range(12):
        y_train_encoded[:,z,i] = 2*(y_train_encoded[:,z,i]-s_min[z,i])/srange[z,i]-1

    for i in range(12):
        y_valid_encoded[:,z,i] = 2*(y_valid_encoded[:,z,i]-s_min[z,i])/srange[z,i]-1
    
    for i in range(12):
        y_test_encoded[:,z,i] = 2*(y_test_encoded[:,z,i]-s_min[z,i])/srange[z,i]-1

# %%
def custom_loss(y_true, y_pred):
    Lf = tf.math.sqrt(tf.reduce_mean(tf.square(y_true - y_pred),axis=1))
#    return tf.math.log(tf.reduce_mean(Lf))
    return (tf.reduce_mean(Lf))

# %%
from keras import Sequential, Input, Model, regularizers
from keras.layers import Conv2D, MaxPooling2D,Dropout, Reshape, BatchNormalization,Conv1DTranspose,Conv1D,Add
from keras.layers import Flatten, Dense, Concatenate
learning_rate = 1e-4
n_unet = 8

models = []

inp1 = Input((224,224,3),)
'''
model1 = (Conv2D(n_unet,(3,3),padding='same', activation='relu', input_shape=(224, 224, 3), kernel_regularizer=regularizers.l2(0.01)))(inp1)
model1 = (MaxPooling2D(2, 2))(model1)
model1 = (Conv2D(n_unet*2, (3, 3), padding='same',activation='relu'))(model1)

model1 = (MaxPooling2D(2, 2))(model1)
#model1 = BatchNormalization()(model1)
model1 = (Conv2D(n_unet*2, (3, 3),  padding='same',activation='relu'))(model1)

model1 = (MaxPooling2D(2, 2))(model1)
#model1 = BatchNormalization()(model1)
model1 = (Conv2D(n_unet*4, (3, 3), padding='same', activation='relu'))(model1)

layer1 = (MaxPooling2D(2, 2))(model1)
#model1 = Dropout(0.3)(model1)
#model1 = BatchNormalization()(model1)
layer2 = (Conv2D(n_unet*8, (3, 3),padding='same', activation='relu'))(layer1)
layer2 = (MaxPooling2D(2, 2))(layer2)

layer3 = (Conv2D(n_unet*16, (3, 3),padding='same', activation='relu'))(layer2)
layer3 = (MaxPooling2D(2, 2))(layer3)

layer4 = (Conv2D(n_unet*32, (3, 3),padding='same', activation='relu'))(layer3)
layer4 = (MaxPooling2D(2, 2))(layer4)


#backward
layer4 = Reshape((1,n_unet*32))(layer4)
layer4 = (Conv1DTranspose(n_unet*16,9,1, activation='relu'))(layer4)

layer3 = Reshape((9,n_unet*16))(layer3)
layer3 = Concatenate()([layer3,layer4])
layer3 = (Conv1D(n_unet*16,3,padding='same', activation='relu'))(layer3)
layer3 = (Conv1DTranspose(n_unet*8,9,5, activation='relu'))(layer3)


layer2 = Reshape((49,n_unet*8))(layer2)
layer2 = Concatenate()([layer2,layer3])
layer2 = (Conv1D(n_unet*8,3,padding='same', activation='relu'))(layer2)
layer2 = (Conv1DTranspose(n_unet*4,3,4, activation='relu'))(layer2)

layer1 = Reshape((196,n_unet*4))(layer1)
layer1 = Concatenate()([layer1,layer2])
layer1 = (Conv1D(n_unet*4,3,padding='same', activation='relu'))(layer2)
model1 = Flatten()(layer1)
models.append(model1)
'''
inp2 = Input(10,)

model2=(Dense(512,activation='relu',input_shape = (10,),kernel_regularizer=regularizers.l2(0.10)))(inp2)

model2=(Dense(512,activation='relu'))(model2)
#skip = model2
model2=(Dense(512,activation='relu'))(model2)
model2=(Dense(512,activation='relu'))(model2)
model2=(Dense(512,activation='relu'))(model2)
#model2 = Add()([skip,model2])
models.append(model2)
'''
model3 = (Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3), kernel_regularizer=regularizers.l2(0.05)))(inp1)
model3 = (MaxPooling2D(2, 2))(model3)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = BatchNormalization()(model1)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = BatchNormalization()(model1)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = Dropout(0.3)(model1)
#model1 = BatchNormalization()(model1)
model3 = (Conv2D(128, (3, 3), activation='relu'))(model3)

model3 = (MaxPooling2D(2, 2))(model3)
#model1 = BatchNormalization()(model1)
#model1 = Dropout(0.3)(model1)
model3 = Flatten()(model3)
model3 = Dense(512,activation='relu')(model3)

models.append(model3)
'''
out = Concatenate()(models)

out = (Dense(fmax*12, activation='tanh'))(out)
out = Reshape((fmax,12))(out)
model = Model([inp1,inp2],out)
model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=learning_rate), loss=custom_loss, metrics=['mae',custom_loss])
model.summary()
# Out:
# 2024-12-02 18:42:37.052299: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13397 MB memory:  -> device: 0, name: NVIDIA A2, pci bus id: 0000:21:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 10)]                 0         []
#
#  dense (Dense)               (None, 512)                  5632      ['input_2[0][0]']
#
#  dense_1 (Dense)             (None, 512)                  262656    ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 512)                  262656    ['dense_1[0][0]']
#
#  dense_3 (Dense)             (None, 512)                  262656    ['dense_2[0][0]']
#
#  dense_4 (Dense)             (None, 512)                  262656    ['dense_3[0][0]']
#
#  concatenate (Concatenate)   (None, 512)                  0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 2352)                 1206576   ['concatenate[0][0]']
#
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  reshape (Reshape)           (None, 196, 12)              0         ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 2262832 (8.63 MB)
# Trainable params: 2262832 (8.63 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
EPOCHS = 300
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: learning_rate * 0.95**(epoch/20))
hist = model.fit([x_train_img,x_train_geopara], y_train_encoded, validation_data=([x_valid_img,x_valid_geopara], y_valid_encoded), batch_size=30, epochs = EPOCHS,callbacks=[lr_schedule])
# Out:
# Epoch 1/300
# 2024-12-02 18:42:42.394254: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-12-02 18:42:42.530790: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f612f202070 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-12-02 18:42:42.530879: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A2, Compute Capability 8.6
# 2024-12-02 18:42:42.543236: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-02 18:42:42.620856: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8907
# 2024-12-02 18:42:42.769566: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-12-02 18:42:42.867645: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 53/53 [==============================] - 6s 34ms/step - loss: 2.2266 - mae: 0.3420 - custom_loss: 0.4005 - val_loss: 2.0243 - val_mae: 0.2855 - val_custom_loss: 0.3351 - lr: 1.0000e-04
# Epoch 2/300
# 53/53 [==============================] - 0s 9ms/step - loss: 1.8718 - mae: 0.2543 - custom_loss: 0.3013 - val_loss: 1.7159 - val_mae: 0.2202 - val_custom_loss: 0.2638 - lr: 9.9744e-05
# Epoch 3/300
# 53/53 [==============================] - 1s 11ms/step - loss: 1.5993 - mae: 0.2078 - custom_loss: 0.2500 - val_loss: 1.4838 - val_mae: 0.1965 - val_custom_loss: 0.2369 - lr: 9.9488e-05
# Epoch 4/300
# 53/53 [==============================] - 1s 12ms/step - loss: 1.3843 - mae: 0.1869 - custom_loss: 0.2264 - val_loss: 1.2858 - val_mae: 0.1780 - val_custom_loss: 0.2167 - lr: 9.9234e-05
# Epoch 5/300
# 53/53 [==============================] - 1s 12ms/step - loss: 1.1979 - mae: 0.1681 - custom_loss: 0.2057 - val_loss: 1.1129 - val_mae: 0.1609 - val_custom_loss: 0.1976 - lr: 9.8979e-05
# Epoch 6/300
# 53/53 [==============================] - 0s 9ms/step - loss: 1.0397 - mae: 0.1554 - custom_loss: 0.1909 - val_loss: 0.9686 - val_mae: 0.1511 - val_custom_loss: 0.1865 - lr: 9.8726e-05
# Epoch 7/300
# 53/53 [==============================] - 0s 8ms/step - loss: 0.9056 - mae: 0.1469 - custom_loss: 0.1809 - val_loss: 0.8455 - val_mae: 0.1449 - val_custom_loss: 0.1786 - lr: 9.8473e-05
# Epoch 8/300
# 53/53 [==============================] - 1s 11ms/step - loss: 0
300
# 53/53 [==============================] - 1s 14ms/step - loss: 0.1468 - mae: 0.0893 - custom_loss: 0.1102 - val_loss: 0.1448 - val_mae: 0.0895 - val_custom_loss: 0.1113 - lr: 9.4030e-05
# Epoch 26/300
# 53/53 [==============================] - 1s 11ms/step - loss: 0.1413 - mae: 0.0887 - custom_loss: 0.1095 - val_loss: 0.1377 - val_mae: 0.0877 - val_custom_loss: 0.1083 - lr: 9.3790e-05
# Epoch 27/300
# 53/53 [==============================] - 1s 11ms/step - loss: 0.1341 - mae: 0.0859 - custom_loss: 0.1061 - val_loss: 0.1309 - val_mae: 0.0847 - val_custom_loss: 0.1052 - lr: 9.3549e-05
# Epoch 28/300
# 53/53 [==============================] - 1s 10ms/step - loss: 0.1300 - mae: 0.0852 - custom_loss: 0.1053 - val_loss: 0.1282 - val_mae: 0.0850 - val_custom_loss: 0.1053 - lr: 9.3310e-05
# Epoch 29/300
# 53/53 [==============================] - 1s 10ms/step - loss: 0.1262 - mae: 0.0843 - custom_loss: 0.1041 - val_loss: 0.1252 - val_mae: 0.0842 - val_custom_loss: 0.1049 - lr: 9.3071e-05
# Epoch 30/300
# 53/53 [==============================] - 0s 9ms/step - loss: 0.1225 - mae: 0.0830 - custom_loss: 0.1026 - val_loss: 0.1186 - val_mae: 0.0804 - val_custom_loss: 0.1001 - lr: 9.2832e-05
# Epoch 31/300
# 53/53 [==============================] - 1s 10ms/step - loss: 0.1176 - mae: 0.0804 - custom_loss: 0.0995 - val_loss: 0.1186 - val_mae: 0.0821 - val_custom_loss: 0.1018 - lr: 9.2595e-05
# Epoch 32/300
# 53/53 [==============================] - 1s 12ms/step - loss: 0.1160 - mae: 0.0803 - custom_loss: 0.0993 - val_loss: 0.1160 - val_mae: 0.0807 - val_custom_loss: 0.1006 - lr: 9.2357e-05
# Epoch 33/300
# 53/53 [==============================] - 1s 10ms/step - loss: 0.1137 - mae: 0.0795 - custom_loss: 0.0983 - val_loss: 0.1108 - val_mae: 0.0774 - val_custom_loss: 0.0965 - lr: 9.2121e-05
# Epoch 34/300
# 53/53 [==============================] - 1s 13ms/step - loss: 0.1108 - mae: 0.0780 - custom_loss: 0.0965 - val_loss: 0.1103 - val_mae: 0.0780 - val_custom_loss: 0.0970 - lr: 9.1885e-05
# Epoch 35/300
# 53/53 [==============================] - 1s 12ms/step - loss: 0.1083 - mae: 0.0767 - custom_loss: 0.0949 - val_loss: 0.1109 - val_mae: 0.0794 - val_custom_loss: 0.0983 - lr: 9.1650e-05
# Epoch 36/300
# 53/53 [==============================] - 1s 11ms/step - loss: 0.1093 - mae: 0.0783 - custom_loss: 0.0966 - val_loss: 0.1073 - val_mae: 0.0766 - val_custom_loss: 0.0954 - lr: 9.1415e-05
# Epoch 37/300
# 53/53 [==============================] - 1s 10ms/step - loss: 0.1061 - mae: 0.0762 - custom_loss: 0.0941 - val_loss: 0.1057 - val_mae: 0.0760 - val_custom_loss: 0.0944 - lr: 9.1181e-05
# Epoch 38/300
# 53/53 [==============================] - 0s 9ms/step - loss: 0.1048 - mae: 0.0756 - custom_loss: 0.0934 - val_loss: 0.1084 - val_mae: 0.0787 - val_custom_loss: 0.0977 - lr: 9.0947e-05
# Epoch 39/300
# 53/53 [==============================] - 1s 14ms/step - loss: 0.1030 - mae: 0.0744 - custom_loss: 0.0921 - val_loss: 0.1010 - val_mae: 0.0729 - val_custom_loss: 0.0908 - lr: 9.0714e-05
# Epoch 40/300
# 53/53 [==============================] - 1s 13ms/step - loss: 0.1017 - mae: 0.0738 - custom_loss: 0.0912 - val_loss: 0.1001 - val_mae: 0.0725 - val_custom_loss: 0.0902 - lr: 9.0482e-05
# Epoch 41/300
# 53/53 [==============================] - 1s 12ms/step - loss: 0.1006 - mae: 0.0732 - custom_loss: 0.0905 - val_loss: 0.1030 - val_mae: 0.0754 - val_custom_loss: 0.0936 - lr: 9.0250e-05
# Epoch 42/300
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0995 - mae: 0.0725 - custom_loss: 0.0897 - val_loss: 0.0987 - val_mae: 0.0718 - val_custom_loss: 0.0896 - lr: 9.0019e-05
# Epoch 43/300
# 53/53 [==============================] - 1s 10ms/step - loss: 0.
300
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0778 - mae: 0.0584 - custom_loss: 0.0721 - val_loss: 0.0799 - val_mae: 0.0600 - val_custom_loss: 0.0746 - lr: 8.2080e-05
# Epoch 79/300
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0772 - mae: 0.0579 - custom_loss: 0.0715 - val_loss: 0.0802 - val_mae: 0.0602 - val_custom_loss: 0.0749 - lr: 8.1869e-05
# Epoch 80/300
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0775 - mae: 0.0582 - custom_loss: 0.0718 - val_loss: 0.0788 - val_mae: 0.0593 - val_custom_loss: 0.0735 - lr: 8.1660e-05
# Epoch 81/300
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0774 - mae: 0.0582 - custom_loss: 0.0717 - val_loss: 0.0816 - val_mae: 0.0616 - val_custom_loss: 0.0763 - lr: 8.1451e-05
# Epoch 82/300
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0769 - mae: 0.0579 - custom_loss: 0.0714 - val_loss: 0.0805 - val_mae: 0.0607 - val_custom_loss: 0.0752 - lr: 8.1242e-05
# Epoch 83/300
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0762 - mae: 0.0572 - custom_loss: 0.0706 - val_loss: 0.0785 - val_mae: 0.0589 - val_custom_loss: 0.0732 - lr: 8.1034e-05
# Epoch 84/300
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0756 - mae: 0.0568 - custom_loss: 0.0701 - val_loss: 0.0786 - val_mae: 0.0591 - val_custom_loss: 0.0734 - lr: 8.0826e-05
# Epoch 85/300
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0748 - mae: 0.0561 - custom_loss: 0.0693 - val_loss: 0.0767 - val_mae: 0.0575 - val_custom_loss: 0.0715 - lr: 8.0619e-05
# Epoch 86/300
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0746 - mae: 0.0560 - custom_loss: 0.0691 - val_loss: 0.0790 - val_mae: 0.0596 - val_custom_loss: 0.0739 - lr: 8.0413e-05
# Epoch 87/300
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0743 - mae: 0.0558 - custom_loss: 0.0689 - val_loss: 0.0780 - val_mae: 0.0589 - val_custom_loss: 0.0730 - lr: 8.0207e-05
# Epoch 88/300
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0743 - mae: 0.0558 - custom_loss: 0.0689 - val_loss: 0.0778 - val_mae: 0.0587 - val_custom_loss: 0.0728 - lr: 8.0001e-05
# Epoch 89/300
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0742 - mae: 0.0557 - custom_loss: 0.0688 - val_loss: 0.0761 - val_mae: 0.0572 - val_custom_loss: 0.0711 - lr: 7.9797e-05
# Epoch 90/300
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0735 - mae: 0.0553 - custom_loss: 0.0682 - val_loss: 0.0760 - val_mae: 0.0572 - val_custom_loss: 0.0710 - lr: 7.9592e-05
# Epoch 91/300
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0725 - mae: 0.0544 - custom_loss: 0.0672 - val_loss: 0.0767 - val_mae: 0.0577 - val_custom_loss: 0.0717 - lr: 7.9388e-05
# Epoch 92/300
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0731 - mae: 0.0549 - custom_loss: 0.0679 - val_loss: 0.0760 - val_mae: 0.0572 - val_custom_loss: 0.0710 - lr: 7.9185e-05
# Epoch 93/300
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0730 - mae: 0.0549 - custom_loss: 0.0678 - val_loss: 0.0770 - val_mae: 0.0580 - val_custom_loss: 0.0721 - lr: 7.8982e-05
# Epoch 94/300
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0719 - mae: 0.0541 - custom_loss: 0.0668 - val_loss: 0.0754 - val_mae: 0.0569 - val_custom_loss: 0.0706 - lr: 7.8780e-05
# Epoch 95/300
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0727 - mae: 0.0547 - custom_loss: 0.0676 - val_loss: 0.0775 - val_mae: 0.0587 - val_custom_loss: 0.0727 - lr: 7.8578e-05
# Epoch 96/300
# 53/53 [==============================] - 0s 8ms/step - loss: 0.
300
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0552 - mae: 0.0419 - custom_loss: 0.0517 - val_loss: 0.0611 - val_mae: 0.0468 - val_custom_loss: 0.0580 - lr: 5.4593e-05
# Epoch 238/300
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0551 - mae: 0.0419 - custom_loss: 0.0516 - val_loss: 0.0615 - val_mae: 0.0472 - val_custom_loss: 0.0584 - lr: 5.4453e-05
# Epoch 239/300
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0550 - mae: 0.0418 - custom_loss: 0.0516 - val_loss: 0.0617 - val_mae: 0.0473 - val_custom_loss: 0.0586 - lr: 5.4314e-05
# Epoch 240/300
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0545 - mae: 0.0414 - custom_loss: 0.0511 - val_loss: 0.0621 - val_mae: 0.0478 - val_custom_loss: 0.0590 - lr: 5.4175e-05
# Epoch 241/300
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0552 - mae: 0.0420 - custom_loss: 0.0518 - val_loss: 0.0616 - val_mae: 0.0472 - val_custom_loss: 0.0585 - lr: 5.4036e-05
# Epoch 242/300
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0557 - mae: 0.0425 - custom_loss: 0.0523 - val_loss: 0.0628 - val_mae: 0.0484 - val_custom_loss: 0.0597 - lr: 5.3898e-05
# Epoch 243/300
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0557 - mae: 0.0424 - custom_loss: 0.0523 - val_loss: 0.0618 - val_mae: 0.0474 - val_custom_loss: 0.0587 - lr: 5.3760e-05
# Epoch 244/300
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0543 - mae: 0.0413 - custom_loss: 0.0509 - val_loss: 0.0609 - val_mae: 0.0467 - val_custom_loss: 0.0578 - lr: 5.3622e-05
# Epoch 245/300
# 53/53 [==============================] - 1s 15ms/step - loss: 0.0556 - mae: 0.0424 - custom_loss: 0.0522 - val_loss: 0.0650 - val_mae: 0.0502 - val_custom_loss: 0.0619 - lr: 5.3485e-05
# Epoch 246/300
# 53/53 [==============================] - 1s 15ms/step - loss: 0.0551 - mae: 0.0419 - custom_loss: 0.0517 - val_loss: 0.0625 - val_mae: 0.0481 - val_custom_loss: 0.0594 - lr: 5.3348e-05
# Epoch 247/300
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0555 - mae: 0.0423 - custom_loss: 0.0522 - val_loss: 0.0615 - val_mae: 0.0472 - val_custom_loss: 0.0584 - lr: 5.3211e-05
# Epoch 248/300
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0553 - mae: 0.0421 - custom_loss: 0.0520 - val_loss: 0.0611 - val_mae: 0.0468 - val_custom_loss: 0.0580 - lr: 5.3075e-05
# Epoch 249/300
# 53/53 [==============================] - 1s 15ms/step - loss: 0.0552 - mae: 0.0420 - custom_loss: 0.0518 - val_loss: 0.0626 - val_mae: 0.0482 - val_custom_loss: 0.0595 - lr: 5.2939e-05
# Epoch 250/300
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0561 - mae: 0.0428 - custom_loss: 0.0527 - val_loss: 0.0627 - val_mae: 0.0482 - val_custom_loss: 0.0596 - lr: 5.2803e-05
# Epoch 251/300
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0545 - mae: 0.0415 - custom_loss: 0.0511 - val_loss: 0.0612 - val_mae: 0.0470 - val_custom_loss: 0.0581 - lr: 5.2668e-05
# Epoch 252/300
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0544 - mae: 0.0414 - custom_loss: 0.0511 - val_loss: 0.0618 - val_mae: 0.0475 - val_custom_loss: 0.0586 - lr: 5.2533e-05
# Epoch 253/300
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0548 - mae: 0.0417 - custom_loss: 0.0514 - val_loss: 0.0612 - val_mae: 0.0470 - val_custom_loss: 0.0581 - lr: 5.2398e-05
# Epoch 254/300
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0548 - mae: 0.0417 - custom_loss: 0.0515 - val_loss: 0.0609 - val_mae: 0.0468 - val_custom_loss: 0.0579 - lr: 5.2264e-05
# Epoch 255/300
# 53/53 [==============================] - 1s 15ms/step - loss: 0.0539 - mae: 0.0410 - custom_loss: 0.0505 - val_loss: 0.0615 - val_mae: 0.0472 - val_custom_loss: 0.0584 - lr: 5.2130e-05
# Epoch 256/300
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0539 - mae: 0.0410 - custom_loss: 0.0505 - val_loss: 0.0607 - val_mae: 0.0466 - val_custom_loss: 0.0577 - lr: 5.1997e-05
# Epoch 257/300
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0537 - mae: 0.0409 - custom_loss: 0.0504 - val_loss: 0.0612 - val_mae: 0.0470 - val_custom_loss: 0.0582 - lr: 5.1864e-05
# Epoch 258/300
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0543 - mae: 0.0414 - custom_loss: 0.0510 - val_loss: 0.0613 - val_mae: 0.0472 - val_custom_loss: 0.0583 - lr: 5.1731e-05
# Epoch 259/300
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0543 - mae: 0.0413 - custom_loss: 0.0510 - val_loss: 0.0606 - val_mae: 0.0466 - val_custom_loss: 0.0576 - lr: 5.1598e-05
# Epoch 260/300
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0539 - mae: 0.0410 - custom_loss: 0.0506 - val_loss: 0.0608 - val_mae: 0.0467 - val_custom_loss: 0.0578 - lr: 5.1466e-05
# Epoch 261/300
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0539 - mae: 0.0411 - custom_loss: 0.0506 - val_loss: 0.0607 - val_mae: 0.0466 - val_custom_loss: 0.0576 - lr: 5.1334e-05
# Epoch 262/300
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0557 - mae: 0.0425 - custom_loss: 0.0524 - val_loss: 0.0618 - val_mae: 0.0477 - val_custom_loss: 0.0588 - lr: 5.1203e-05
# Epoch 263/300
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0548 - mae: 0.0418 - custom_loss: 0.0515 - val_loss: 0.0620 - val_mae: 0.0476 - val_custom_loss: 0.0590 - lr: 5.1072e-05
# Epoch 264/300
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0549 - mae: 0.0419 - custom_loss: 0.0516 - val_loss: 0.0612 - val_mae: 0.0471 - val_custom_loss: 0.0582 - lr: 5.0941e-05
# Epoch 265/300
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0548 - mae: 0.0418 - custom_loss: 0.0515 - val_loss: 0.0610 - val_mae: 0.0469 - val_custom_loss: 0.0580 - lr: 5.0810e-05
# Epoch 266/300
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0539 - mae: 0.0411 - custom_loss: 0.0506 - val_loss: 0.0612 - val_mae: 0.0471 - val_custom_loss: 0.0581 - lr: 5.0680e-05
# Epoch 267/300
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0536 - mae: 0.0408 - custom_loss: 0.0503 - val_loss: 0.0607 - val_mae: 0.0467 - val_custom_loss: 0.0577 - lr: 5.0550e-05
# Epoch 268/300
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0534 - mae: 0.0407 - custom_loss: 0.0501 - val_loss: 0.0613 - val_mae: 0.0471 - val_custom_loss: 0.0583 - lr: 5.0421e-05
# Epoch 269/300
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0543 - mae: 0.0414 - custom_loss: 0.0511 - val_loss: 0.0615 - val_mae: 0.0473 - val_custom_loss: 0.0585 - lr: 5.0292e-05
# Epoch 270/300
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0544 - mae: 0.0415 - custom_loss: 0.0511 - val_loss: 0.0607 - val_mae: 0.0468 - val_custom_loss: 0.0577 - lr: 5.0163e-05
# Epoch 271/300
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0534 - mae: 0.0407 - custom_loss: 0.0501 - val_loss: 0.0603 - val_mae: 0.0464 - val_custom_loss: 0.0573 - lr: 5.0034e-05
# Epoch 272/300
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0533 - mae: 0.0406 - custom_loss: 0.0501 - val_loss: 0.0613 - val_mae: 0.0472 - val_custom_loss: 0.0583 - lr: 4.9906e-05
# Epoch 273/300
# 53/53 [==============================] - 1s 14ms/step - loss: 0.
300
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0521 - mae: 0.0397 - custom_loss: 0.0489 - val_loss: 0.0598 - val_mae: 0.0460 - val_custom_loss: 0.0569 - lr: 4.7411e-05
# Epoch 293/300
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0528 - mae: 0.0402 - custom_loss: 0.0496 - val_loss: 0.0604 - val_mae: 0.0465 - val_custom_loss: 0.0575 - lr: 4.7289e-05
# Epoch 294/300
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0527 - mae: 0.0402 - custom_loss: 0.0495 - val_loss: 0.0594 - val_mae: 0.0456 - val_custom_loss: 0.0565 - lr: 4.7168e-05
# Epoch 295/300
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0524 - mae: 0.0399 - custom_loss: 0.0493 - val_loss: 0.0601 - val_mae: 0.0462 - val_custom_loss: 0.0572 - lr: 4.7048e-05
# Epoch 296/300
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0521 - mae: 0.0397 - custom_loss: 0.0490 - val_loss: 0.0597 - val_mae: 0.0460 - val_custom_loss: 0.0568 - lr: 4.6927e-05
# Epoch 297/300
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0522 - mae: 0.0398 - custom_loss: 0.0490 - val_loss: 0.0598 - val_mae: 0.0460 - val_custom_loss: 0.0569 - lr: 4.6807e-05
# Epoch 298/300
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0527 - mae: 0.0401 - custom_loss: 0.0495 - val_loss: 0.0590 - val_mae: 0.0454 - val_custom_loss: 0.0561 - lr: 4.6687e-05
# Epoch 299/300
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0520 - mae: 0.0396 - custom_loss: 0.0488 - val_loss: 0.0604 - val_mae: 0.0466 - val_custom_loss: 0.0576 - lr: 4.6567e-05
# Epoch 300/300
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0522 - mae: 0.0398 - custom_loss: 0.0491 - val_loss: 0.0596 - val_mae: 0.0458 - val_custom_loss: 0.0567 - lr: 4.6448e-05

# %%
np.shape(y_train_encoded)
# Out:
# (1590, 196, 12)

# %%
test_prediction = model.predict([x_test_img,x_test_geopara])
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
np.shape(test_prediction)
# Out:
# (531, 196, 12)

# %%
mae = hist.history['mae']
val_mae = hist.history['val_mae']
epochs = range(1, len(mae) + 1)

plt.plot(epochs, mae, '-', label='Training mae')
plt.plot(epochs, val_mae, ':', label='Validation mae')
plt.title('Training and Validation mae')
plt.xlabel('Epoch')
plt.ylabel('mae')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %%
from sklearn.metrics import r2_score
r2_result = []
for z in range(fmax):
    r2 = 0
    for i in range(12):
        temp = r2_score(y_test_encoded[:,z,i], test_prediction[:,z,i], force_finite=False)
        r2 = r2+temp
    r2_result.append(r2/12)
plt.plot(range(fmax),r2_result)

# %%
np.mean(r2_result)
# Out:
# 0.9565659780631934

# %%
mae_all = np.zeros((fmax,12))
mae_mean = np.zeros(fmax)
for z in range(fmax):
    for i in range(12):
        mae_all[z][i] = np.mean(abs(test_prediction[:,z,i]-y_test_encoded[:,z,i]))*0.5*srange[z,i]
    mae_mean[z] = np.mean(mae_all[z][:])

# %%
freq = range(fmax)
for i in range(12):
    if (i%2==0):
        plt.plot(freq,mae_all[:,i])
plt.legend(["Re[S11]","Re[S12]","Re[S13]","Re[S14]","Re[S33]","Re[S34]"])
plt.xlabel('Frequency/GHz')
plt.ylabel('S-parameter mae')
# Out:
# Text(0, 0.5, 'S-parameter mae')

# %%
fmax = 196
mae_all = np.zeros((fmax,12))
mae_mean = np.zeros(fmax)
for z in range(fmax):
    for i in range(12):
        mae_all[z][i] = np.mean(abs(test_prediction[:,z,i]-y_test_encoded[:,z,i]))*0.5*srange[z,i]
    mae_mean[z] = np.mean(mae_all[z][:])

# %%
plt.plot(range(fmax),mae_mean)
plt.xlabel('Frequency/GHz')
plt.ylabel('Average S-parameter mae')
# Out:
# Text(0, 0.5, 'Average S-parameter mae')

# %%
freq = range(fmax)
for i in range(12):
    if (i%2==1):
        plt.plot(freq,mae_all[:,i])
plt.legend(["Im[S11]","Im[S12]","Im[S13]","Im[S14]","Im[S33]","Im[S34]"])        
plt.xlabel('Frequency/GHz')
plt.ylabel('S-parameter mae')
# Out:
# Text(0, 0.5, 'S-parameter mae')

# %%
np.mean(mae_mean)
# Out:
# 0.02110650764085695

# %%
def R_squared(y, y_pred):
  residual = tf.reduce_sum(tf.square(tf.subtract(y, y_pred)))
  total = tf.reduce_sum(tf.square(tf.subtract(y, tf.reduce_mean(y))))
  r2 = tf.subtract(1.0, tf.divide(residual, total))
  return r2
print(R_squared(y_test_encoded,test_prediction))
# Out:
# tf.Tensor(0.9713730807272447, shape=(), dtype=float64)

# %%
model.save('./models/substrate/1turn_196G_MLP.h5')
# Out:
# /home/hh68/.conda/envs/tensorflow/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
